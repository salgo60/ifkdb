# %% [markdown]
# * [#17](https://github.com/salgo60/ifkdb/issues/17) "Vandra igenom alla Kategorier och skapa koppling wdt:P54"

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2026-02-26 08:02:29.601381

# %%
get_team_qid_from_category

# %%
import requests
import time
import pandas as pd

# ---------------------------------------------------
# Session setup
# ---------------------------------------------------
S = requests.Session()
S.headers.update({
    "User-Agent": "Soccer wiki/1.0 (https://github.com/salgo60/ifkdb; contact: salgo60@msn.com)"
})

WIKI_API = "https://sv.wikipedia.org/w/api.php"
SPARQL_ENDPOINT = "https://query.wikidata.org/sparql"


# ---------------------------------------------------
# 1. Hämta underkategorier (klubbar)
# ---------------------------------------------------
def get_subcategories(category_title):
    members = []
    cmcontinue = None

    while True:
        params = {
            "action": "query",
            "list": "categorymembers",
            "cmtitle": category_title,
            "cmtype": "subcat",
            "cmlimit": "500",
            "format": "json",
            "formatversion": "2"
        }

        if cmcontinue:
            params["cmcontinue"] = cmcontinue

        r = S.get(WIKI_API, params=params)
        r.raise_for_status()
        data = r.json()

        members.extend(data["query"]["categorymembers"])

        if "continue" in data:
            cmcontinue = data["continue"]["cmcontinue"]
            time.sleep(0.5)
        else:
            break

    return [m["title"] for m in members]


# ---------------------------------------------------
# 2. Hämta spelare + QID från en klubbkategori
# ---------------------------------------------------
def get_category_players(category_title):
    members = []
    gcmcontinue = None

    while True:
        params = {
            "action": "query",
            "generator": "categorymembers",
            "gcmtitle": category_title,
            "gcmlimit": "max",
            "gcmnamespace": 0,
            "prop": "pageprops",
            "format": "json",
            "formatversion": "2"
        }

        if gcmcontinue:
            params["gcmcontinue"] = gcmcontinue

        r = S.get(WIKI_API, params=params)
        r.raise_for_status()
        data = r.json()

        if "query" in data:
            for page in data["query"]["pages"]:
                qid = page.get("pageprops", {}).get("wikibase_item")
                if qid:
                    members.append(qid)

        if "continue" in data:
            gcmcontinue = data["continue"]["gcmcontinue"]
            time.sleep(0.5)
        else:
            break

    return set(members)


# ---------------------------------------------------
# 3. Hämta klubbens QID
# ---------------------------------------------------

def get_team_qid_from_category(category_title):
    """
    Hittar rätt klubb-QID från en kategori som t.ex.
    'Kategori:Fotbollsspelare i AIK'
    
    Logik:
    1) Hämta kategori-QID
    2) Läs P971 (category combines topics)
    3) Filtrera fram football club (P31=Q476028)
    4) Fallback till P301 (main topic)
    """

    # ---------------------------------------------------
    # 1. Hämta kategori-QID
    # ---------------------------------------------------
    params = {
        "action": "query",
        "titles": category_title,
        "prop": "pageprops",
        "format": "json",
        "formatversion": "2"
    }

    r = S.get(WIKI_API, params=params)
    r.raise_for_status()
    data = r.json()

    pages = data.get("query", {}).get("pages", [])
    if not pages or "pageprops" not in pages[0]:
        return None

    category_qid = pages[0]["pageprops"].get("wikibase_item")
    if not category_qid:
        return None

    headers = {
        "User-Agent": S.headers["User-Agent"],
        "Accept": "application/sparql-results+json"
    }

    # ---------------------------------------------------
    # 2. Försök med P971
    # ---------------------------------------------------
    query_p971 = f"""
    SELECT ?topic WHERE {{
      wd:{category_qid} wdt:P971 ?topic.
    }}
    """

    r = requests.get(SPARQL_ENDPOINT, params={"query": query_p971}, headers=headers)
    r.raise_for_status()
    data = r.json()

    topics = [
        row["topic"]["value"].split("/")[-1]
        for row in data["results"]["bindings"]
    ]

    if topics:

        values = " ".join(f"wd:{qid}" for qid in topics)

        query_filter = f"""
        SELECT ?club WHERE {{
          VALUES ?club {{ {values} }}
          # ?club wdt:P31/wdt:P279* wd:Q476028.
        }}
        """

        r2 = requests.get(SPARQL_ENDPOINT, params={"query": query_filter}, headers=headers)
        r2.raise_for_status()
        data2 = r2.json()

        results = data2["results"]["bindings"]
        if results:
            return results[0]["club"]["value"].split("/")[-1]

    # ---------------------------------------------------
    # 3. Fallback: P301 (main topic)
    # ---------------------------------------------------
    query_p301 = f"""
    SELECT ?club WHERE {{
      wd:{category_qid} wdt:P301 ?club.
      # ?club wdt:P31/wdt:P279* wd:Q476028.
    }}
    """

    r3 = requests.get(SPARQL_ENDPOINT, params={"query": query_p301}, headers=headers)
    r3.raise_for_status()
    data3 = r3.json()

    results = data3["results"]["bindings"]
    if results:
        return results[0]["club"]["value"].split("/")[-1]

    return None
    
def get_category_qid(category_title):
    params = {
        "action": "query",
        "titles": category_title,
        "prop": "pageprops",
        "format": "json",
        "formatversion": "2"
    }

    r = S.get(WIKI_API, params=params)
    r.raise_for_status()
    data = r.json()

    pages = data.get("query", {}).get("pages", [])
    if pages and "pageprops" in pages[0]:
        return pages[0]["pageprops"].get("wikibase_item")

    return None


# ---------------------------------------------------
# 4. SPARQL: spelare via P54
# ---------------------------------------------------
def get_players_via_p54(team_qid):

    query = f"""
    SELECT ?player WHERE {{
      # ?player wdt:P54 wd:{team_qid}.
    }}
    """

    headers = {
        "User-Agent": "Soccer wiki/1.0 (https://github.com/salgo60/ifkdb; contact: salgo60@msn.com)",
        "Accept": "application/sparql-results+json"
    }

    r = requests.get(SPARQL_ENDPOINT, params={"query": query}, headers=headers)
    r.raise_for_status()
    data = r.json()

    players = {
        row["player"]["value"].split("/")[-1]
        for row in data["results"]["bindings"]
    }

    return players


# ---------------------------------------------------
# 5. Huvudflöde
# ---------------------------------------------------
def compare_all_clubs(main_category):

    clubs = get_subcategories(main_category)
    print("Antal klubbar:", len(clubs))

    results = []

    for club_cat in clubs:
        print("Analyserar:", club_cat)

        wiki_players = get_category_players(club_cat)
        team_qid = get_team_qid_from_category(club_cat)

        if not team_qid:
            continue

        wd_players = get_players_via_p54(team_qid)

        only_in_wiki = wiki_players - wd_players
        only_in_wd = wd_players - wiki_players

        results.append({
            "club_category": club_cat,
            "club_qid": team_qid,
            "wiki_count": len(wiki_players),
            "wikidata_count": len(wd_players),
            "only_in_wiki": len(only_in_wiki),
            "only_in_wikidata": len(only_in_wd)
        })

        time.sleep(0.5)

    return pd.DataFrame(results)


# ---------------------------------------------------
# 6. Kör analysen
# ---------------------------------------------------
category = "Kategori:Fotbollsspelare_i_klubblag_i_Sverige"

df_diff = compare_all_clubs(category)

df_diff.sort_values("only_in_wiki", ascending=False).head()
# Out:
# Antal klubbar: 346
# Analyserar: Kategori:Fotbollsspelare i AFC Eskilstuna
# Analyserar: Kategori:Fotbollsspelare i AFC United
# Analyserar: Kategori:Fotbollsspelare i Ahlafors IF
# Analyserar: Kategori:Fotbollsspelare i AIK
# Analyserar: Kategori:Fotbollsspelare i AIK:s damlag
# Analyserar: Kategori:Fotbollsspelare i Akropolis IF
# Analyserar: Kategori:Fotbollsspelare i Alingsås IF
# Analyserar: Kategori:Fotbollsspelare i Alnö IF
# Analyserar: Kategori:Fotbollsspelare i Alvesta GIF
# Analyserar: Kategori:Fotbollsspelare i Angered MBIK
# Analyserar: Kategori:Fotbollsspelare i Annebergs IF
# Analyserar: Kategori:Fotbollsspelare i Arameisk-Syrianska Botkyrka IF
# Analyserar: Kategori:Fotbollsspelare i Ariana FC
# Analyserar: Kategori:Fotbollsspelare i Asarums IF
# Analyserar: Kategori:Fotbollsspelare i Askims IK
# Analyserar: Kategori:Fotbollsspelare i IFK Aspudden-Tellus
# Analyserar: Kategori:Fotbollsspelare i Assyriska BK
# Analyserar: Kategori:Fotbollsspelare i Assyriska FF
# Analyserar: Kategori:Fotbollsspelare i Assyriska IK
# Analyserar: Kategori:Fotbollsspelare i BK Astrio
# Analyserar: Kategori:Fotbollsspelare i Azalea BK
# Analyserar: Kategori:Fotbollsspelare i Bankeryds SK
# Analyserar: Kategori:Fotbollsspelare i IFK Berga
# Analyserar: Kategori:Fotbollsspelare i BK Häcken FF
# Analyserar: Kategori:Fotbollsspelare i BK Olympic
# Analyserar: Kategori:Fotbollsspelare i BKV Norrtälje
# Analyserar: Kategori:Fotbollsspelare i Bodens BK
# Analyserar: Kategori:Fotbollsspelare i Bollstanäs SK
# Analyserar: Kategori:Fotbollsspelare i Boo FF
# Analyserar: Kategori:Fotbollsspelare i IK Brage
# Analyserar: Kategori:Fotbollsspelare i Bro IK
# Analyserar: Kategori:Fotbollsspelare i IF Brommapojkarna
# Analyserar: Kategori:Fotbollsspelare i IF Brommapojkarna (damer)
# Analyserar: Kategori:Fotbollsspelare i Brynäs IF
# Analyserar: Kategori:Fotbollsspelare i Bräcke SK
# Analyserar: Kategori:Fotbollsspelare i BW 90 IF
# Analyserar: Kategori:Fotbollsspelare i Byttorps IF
# Analyserar: Kategori:Fotbollsspelare i Bälinge IF
# Analyserar: Kategori:Fotbollsspelare i Carlstad United BK
# Analyserar: Kategori:Fotbollsspelare i Dalkurd FF
# Analyserar: Kategori:Fotbollsspelare i Degerfors IF
# Analyserar: Kategori:Fotbollsspelare i BK Derby
# Analyserar: Kategori:Fotbollsspelare i Djurgårdens IF:s damlag
# Analyserar: Kategori:Fotbollsspelare i Djurgårdens IF
# Analyserar: Kategori:Fotbollsspelare i IF Elfsborg
# Analyserar: Kategori:Fotbollsspelare i Emmaboda IS
# Analyserar: Kategori:Fotbollsspelare i Enhörna IF
# Analyserar: Kategori:Fotbollsspelare i Enköpings SK
# Analyserar: Kategori:Fotbollsspelare i Enskede IK
# Analyserar: Kategori:Fotbollsspelare i Eskilsminne IF
# Analyserar: Kategori:Fotbollsspelare i Eskilstuna City FK
# Analyserar: Kategori:Fotbollsspelare i Eskilstuna United DFF
# Analyserar: Kategori:Fotbollsspelare i IFK Eskilstuna
# Analyserar: Kategori:Fotbollsspelare i Falkenbergs FF
# Analyserar: Kategori:Fotbollsspelare i Falköpings KIK
# Analyserar: Kategori:Fotbollsspelare i Falu BS
# Analyserar: Kategori:Fotbollsspelare i Fanna BK
# Analyserar: Kategori:Fotbollsspelare i FBK Karlstad
# Analyserar: Kategori:Fotbollsspelare i FC Café Opera
# Analyserar: Kategori:Spelare i FC Stockholm Internazionale
# Analyserar: Kategori:Fotbollsspelare i Finspångs AIK
# Analyserar: Kategori:Fotbollsspelare i FK Karlskrona
# Analyserar: Kategori:Fotbollsspelare i Floda BoIF
# Analyserar: Kategori:Fotbollsspelare i FoC Farsta
# Analyserar: Kategori:Fotbollsspelare i Forssa BK
# Analyserar: Kategori:Fotbollsspelare i BK Forward
# Analyserar: Kategori:Fotbollsspelare i Korsnäs IF
# Analyserar: Kategori:Fotbollsspelare i Landala IF
# Analyserar: Kategori:Fotbollsspelare i Snöstorp Nyhem FF
# Analyserar: Kategori:Fotbollsspelare i IK Frej
# Analyserar: Kategori:Fotbollsspelare i Friska Viljor FC
# Analyserar: Kategori:Fotbollsspelare i Fässbergs IF
# Analyserar: Kategori:Fotbollsspelare i Gais
# Analyserar: Kategori:Fotbollsspelare i Gais (damer)
# Analyserar: Kategori:Fotbollsspelare i Gamla Upsala SK
# Analyserar: Kategori:Fotbollsspelare i Gamleby IF
# Analyserar: Kategori:Fotbollsspelare i IK Gauthiod
# Analyserar: Kategori:Fotbollsspelare i Gefle IF
# Analyserar: Kategori:Fotbollsspelare i Gideonsbergs IF
# Analyserar: Kategori:Fotbollsspelare i Grimsås IF
# Analyserar: Kategori:Fotbollsspelare i Gröndals IK
# Analyserar: Kategori:Fotbollsspelare i Gunnilse IS
# Analyserar: Kategori:Fotbollsspelare i FC Gute
# Analyserar: Kategori:Fotbollsspelare i Gårda BK
# Analyserar: Kategori:Fotbollsspelare i Gävle GIK
# Analyserar: Kategori:Fotbollsspelare i IFK Göteborg
# Analyserar: Kategori:Fotbollsspelare i Göteborgs FF
# Analyserar: Kategori:Fotbollsspelare i Habo IF
# Analyserar: Kategori:Fotbollsspelare i Hallstahammars SK
# Analyserar: Kategori:Fotbollsspelare i IS Halmia
# Analyserar: Kategori:Fotbollsspelare i Halmstads BK
# Analyserar: Kategori:Fotbollsspelare i Hammarby IF:s damlag
# Analyserar: Kategori:Fotbollsspelare i Hammarby IF
# Analyserar: Kategori:Fotbollsspelare i Hammarby TFF
# Analyserar: Kategori:Fotbollsspelare i Hammenhögs IF
# Analyserar: Kategori:Fotbollsspelare i IFK Haninge
# Analyserar: Kategori:Fotbollsspelare i Hanvikens SK
# Analyserar: Kategori:Fotbollsspelare i Helsingborgs IF
# Analyserar: Kategori:Fotbollsspelare i Hittarps IK
# Analyserar: Kategori:Fotbollsspelare i Holmalunds IF
# Analyserar: Kategori:Fotbollsspelare i IFK Holmsund
# Analyserar: Kategori:Fotbollsspelare i Hovås Billdal IF
# Analyserar: Kategori:Fotbollsspelare i Hovås IF
# Analyserar: Kategori:Fotbollsspelare i Huddinge IF
# Analyserar: Kategori:Fotbollsspelare i Hudiksvalls FF
# Analyserar: Kategori:Fotbollsspelare i Husie IF
# Analyserar: Kategori:Fotbollsspelare i Husqvarna FF
# Analyserar: Kategori:Fotbollsspelare i Husqvarna IF
# Analyserar: Kategori:Fotbollsspelare i Husums IF
# Analyserar: Kategori:Fotbollsspelare i BK Häcken
# Analyserar: Kategori:Fotbollsspelare i Häljarps IF
# Analyserar: Kategori:Fotbollsspelare i IFK Hässleholm
# Analyserar: Kategori:Fotbollsspelare i Hässleholms IF
# Analyserar: Kategori:Fotbollsspelare i Högaborgs BK
# Analyserar: Kategori:Fotbollsspelare i Högadals IS
# Analyserar: Kategori:Fotbollsspelare i Höganäs BK
# Analyserar: Kategori:Fotbollsspelare i FC Höllviken
# Analyserar: Kategori:Fotbollsspelare i Hönö IS
# Analyserar: Kategori:Fotbollsspelare i IFK Fjärås
# Analyserar: Kategori:Fotbollsspelare i IFK Jönköping
# Analyserar: Kategori:Fotbollsspelare i IFK Skövde
# Analyserar: Kategori:Fotbollsspelare i IFK Uppsala
# Analyserar: Kategori:Fotbollsspelare i IFK Västerås
# Analyserar: Kategori:Fotbollsspelare i IFK Ölme
# Analyserar: Kategori:Fotbollsspelare i Ifö/Bromölla IF
# Analyserar: Kategori:Fotbollsspelare i Jakobsbergs GoIF
# Analyserar: Kategori:Fotbollsspelare i Jitex BK
# Analyserar: Kategori:Fotbollsspelare i Jonsereds IF
# Analyserar: Kategori:Fotbollsspelare i Jönköpings Södra IF
# Analyserar: Kategori:Fotbollsspelare i IFK Kalmar
# Analyserar: Kategori:Fotbollsspelare i Kalmar AIK
# Analyserar: Kategori:Fotbollsspelare i Kalmar FF
# Analyserar: Kategori:Fotbollsspelare i Karlbergs BK
# Analyserar: Kategori:Fotbollsspelare i IFK Karlshamn
# Analyserar: Kategori:Fotbollsspelare i Karlskoga IF
# Analyserar: Kategori:Fotbollsspelare i Karlskoga SK
# Analyserar: Kategori:Fotbollsspelare i KB Karlskoga
# Analyserar: Kategori:Fotbollsspelare i Karlskrona AIF
# Analyserar: Kategori:Fotbollsspelare i Karlslunds IF
# Analyserar: Kategori:Fotbollsspelare i Karlstad BK
# Analyserar: Kategori:Fotbollsspelare i IF Karlstad Fotboll
# Analyserar: Kategori:Fotbollsspelare i BK Kenty
# Analyserar: Kategori:Fotbollsspelare i Kinna IF
# Analyserar: Kategori:Fotbollsspelare i Kiruna FF
# Analyserar: Kategori:Fotbollsspelare i IFK Klagshamn
# Analyserar: Kategori:Fotbollsspelare i IK Kongahälla
# Analyserar: Kategori:Fotbollsspelare i Kortedala IF
# Analyserar: Kategori:Fotbollsspelare i IFK Kristianstad
# Analyserar: Kategori:Fotbollsspelare i Kristianstads DFF
# Analyserar: Kategori:Fotbollsspelare i Kristianstad FC
# Analyserar: Kategori:Fotbollsspelare i Kristianstads FF
# Analyserar: Kategori:Fotbollsspelare i Kubikenborgs IF
# Analyserar: Kategori:Fotbollsspelare i Kulladals FF
# Analyserar: Kategori:Fotbollsspelare i Kungsbacka BI
# Analyserar: Kategori:Fotbollsspelare i Kungsbacka DFF
# Analyserar: Kategori:Fotbollsspelare i Kungshamns IF
# Analyserar: Kategori:Fotbollsspelare i Kvarnsvedens IK
# Analyserar: Kategori:Fotbollsspelare i Köpings IS
# Analyserar: Kategori:Fotbollsspelare i Laholms FK
# Analyserar: Kategori:Fotbollsspelare i Landskrona BoIS
# Analyserar: Kategori:Fotbollsspelare i Landvetter IF
# Analyserar: Kategori:Fotbollsspelare i Lidköpings FK
# Analyserar: Kategori:Fotbollsspelare i IF Limhamn Bunkeflo
# Analyserar: Kategori:Fotbollsspelare i Lindome GIF
# Analyserar: Kategori:Fotbollsspelare i FC Linköping City
# Analyserar: Kategori:Fotbollsspelare i Linköping FC
# Analyserar: Kategori:Fotbollsspelare i Linköpings FF
# Analyserar: Kategori:Fotbollsspelare i Ljungskile SK
# Analyserar: Kategori:Fotbollsspelare i Lotorps IF
# Analyserar: Kategori:Fotbollsspelare i Ludvika FfI
# Analyserar: Kategori:Fotbollsspelare i IFK Luleå
# Analyserar: Kategori:Fotbollsspelare i Luleå SK
# Analyserar: Kategori:Fotbollsspelare i Lundby IF
# Analyserar: Kategori:Fotbollsspelare i Lunds BK
# Analyserar: Kategori:Fotbollsspelare i Lunds BoIS
# Analyserar: Kategori:Fotbollsspelare i Lärje/Angered IF
# Analyserar: Kategori:Fotbollsspelare i Majornas IK
# Analyserar: Kategori:Fotbollsspelare i Mallbackens IF
# Analyserar: Kategori:Fotbollsspelare i Malmö FF
# Analyserar: Kategori:Fotbollsspelare i Malmö FF (damer)
# Analyserar: Kategori:Fotbollsspelare i IFK Malmö
# Analyserar: Kategori:Fotbollsspelare i Mariestad BoIS
# Analyserar: Kategori:Fotbollsspelare i Markaryds IF
# Analyserar: Kategori:Fotbollsspelare i Melleruds IF
# Analyserar: Kategori:Fotbollsspelare i Mjällby AIF
# Analyserar: Kategori:Fotbollsspelare i Mossens BK
# Analyserar: Kategori:Fotbollsspelare i Motala AIF
# Analyserar: Kategori:Fotbollsspelare i Myresjö IF
# Analyserar: Kategori:Fotbollsspelare i Mölnlycke IF
# Analyserar: Kategori:Fotbollsspelare i Nacka FF
# Analyserar: Kategori:Fotbollsspelare i Newroz FC
# Analyserar: Kategori:Fotbollsspelare i Nora BK
# Analyserar: Kategori:Fotbollsspelare i Nordic United FC
# Analyserar: Kategori:Fotbollsspelare i Norrby IF
# Analyserar: Kategori:Fotbollsspelare i IFK Norrköping DFK
# Analyserar: Kategori:Fotbollsspelare i IFK Norrköping
# Analyserar: Kategori:Fotbollsspelare i Nosaby IF
# Analyserar: Kategori:Fotbollsspelare i Nybro IF
# Analyserar: Kategori:Fotbollsspelare i Nyköpings BIS
# Analyserar: Kategori:Fotbollsspelare i IK Oddevold
# Analyserar: Kategori:Fotbollsspelare i Onsala BK
# Analyserar: Kategori:Fotbollsspelare i Ope IF
# Analyserar: Kategori:Fotbollsspelare i Ornäs BK
# Analyserar: Kategori:Fotbollsspelare i Oskarshamns AIK
# Analyserar: Kategori:Fotbollsspelare i Oskarströms IS
# Analyserar: Kategori:Fotbollsspelare i Partille IF
# Analyserar: Kategori:Fotbollsspelare i Piteå IF
# Analyserar: Kategori:Fotbollsspelare i Piteå IF Dam
# Analyserar: Kategori:Fotbollsspelare i KSF Prespa Birlik
# Analyserar: Kategori:Fotbollsspelare i Qviding FIF
# Analyserar: Kategori:Fotbollsspelare i Redbergslids IK
# Analyserar: Kategori:Fotbollsspelare i Reymersholms IK
# Analyserar: Kategori:Fotbollsspelare i Ronneby BK
# Analyserar: Kategori:Fotbollsspelare i FC Rosengård
# Analyserar: Kategori:Fotbollsspelare i FC Rosengård (damer)
# Analyserar: Kategori:Fotbollsspelare i Rydaholms GoIF
# Analyserar: Kategori:Fotbollsspelare i Rynninge IK
# Analyserar: Kategori:Fotbollsspelare i Rågsveds IF
# Analyserar: Kategori:Fotbollsspelare i Råslätts SK
# Analyserar: Kategori:Fotbollsspelare i Råsunda IS
# Analyserar: Kategori:Fotbollsspelare i Råå IF
# Analyserar: Kategori:Fotbollsspelare i Räppe GoIF
# Analyserar: Kategori:Fotbollsspelare i IF Saab
# Analyserar: Kategori:Fotbollsspelare i Saltsjö-Boo IF
# Analyserar: Kategori:Fotbollsspelare i Sandareds IF
# Analyserar: Kategori:Fotbollsspelare i Sandvikens AIK
# Analyserar: Kategori:Fotbollsspelare i Sandvikens IF
# Analyserar: Kategori:Fotbollsspelare i Saxemara IF
# Analyserar: Kategori:Fotbollsspelare i IK Sirius
# Analyserar: Kategori:Fotbollsspelare i Själevads IK
# Analyserar: Kategori:Fotbollsspelare i Skellefteå AIK
# Analyserar: Kategori:Fotbollsspelare i Skellefteå FF
# Analyserar: Kategori:Fotbollsspelare i Skene IF
# Analyserar: Kategori:Fotbollsspelare i Skiljebo SK
# Analyserar: Kategori:Fotbollsspelare i Skogens IF
# Analyserar: Kategori:Fotbollsspelare i Skärblacka IF
# Analyserar: Kategori:Fotbollsspelare i Skärhamns IK
# Analyserar: Kategori:Fotbollsspelare i Skövde AIK
# Analyserar: Kategori:Fotbollsspelare i IK Sleipner
# Analyserar: Kategori:Fotbollsspelare i Slätta SK
# Analyserar: Kategori:Fotbollsspelare i Smedby AIS
# Analyserar: Kategori:Fotbollsspelare i Sollentuna FK
# Analyserar: Kategori:Fotbollsspelare i Spånga IS
# Analyserar: Kategori:Fotbollsspelare i Spårvägens FF
# Analyserar: Kategori:Fotbollsspelare i Stattena IF
# Analyserar: Kategori:Fotbollsspelare i Stenungsunds IF
# Analyserar: Kategori:Fotbollsspelare i IFK Stockholm
# Analyserar: Kategori:Fotbollsspelare i IFK Stocksund
# Analyserar: Kategori:Fotbollsspelare i Strömsbergs IF
# Analyserar: Kategori:Fotbollsspelare i IFK Strömstad
# Analyserar: Kategori:Fotbollsspelare i IFK Strömsund
# Analyserar: Kategori:Fotbollsspelare i Stångenäs AIS
# Analyserar: Kategori:Fotbollsspelare i Sund IF
# Analyserar: Kategori:Fotbollsspelare i Sundbybergs IK
# Analyserar: Kategori:Fotbollsspelare i GIF Sundsvall
# Analyserar: Kategori:Fotbollsspelare i IFK Sundsvall
# Analyserar: Kategori:Fotbollsspelare i Sundsvalls DFF
# Analyserar: Kategori:Fotbollsspelare i Sunnanå SK
# Analyserar: Kategori:Fotbollsspelare i IF Sylvia
# Analyserar: Kategori:Fotbollsspelare i Syrianska Eskilstuna IF
# Analyserar: Kategori:Fotbollsspelare i Syrianska FC
# Analyserar: Kategori:Fotbollsspelare i Syrianska IF Kerburan
# Analyserar: Kategori:Fotbollsspelare i Sävedalens IF
# Analyserar: Kategori:Fotbollsspelare i Söderhamns FF
# Analyserar: Kategori:Fotbollsspelare i Södertälje FK
# Analyserar: Kategori:Fotbollsspelare i Sölvesborgs GoIF
# Analyserar: Kategori:Spelare i Team TG FF
# Analyserar: Kategori:Fotbollsspelare i Tegs SK
# Analyserar: Kategori:Fotbollsspelare i Tenhults IF
# Analyserar: Kategori:Fotbollsspelare i IFK Timrå
# Analyserar: Kategori:Fotbollsspelare i IK Tord
# Analyserar: Kategori:Fotbollsspelare i Torns IF
# Analyserar: Kategori:Fotbollsspelare i Torsby IF
# Analyserar: Kategori:Fotbollsspelare i Torslanda IK
# Analyserar: Kategori:Fotbollsspelare i Tranås BoIS
# Analyserar: Kategori:Fotbollsspelare i IFK Trelleborg
# Analyserar: Kategori:Fotbollsspelare i Trelleborgs FF
# Analyserar: Kategori:Fotbollsspelare i Trelleborgs FF (damer)
# Analyserar: Kategori:Fotbollsspelare i FC Trollhättan
# Analyserar: Kategori:Fotbollsspelare i IFK Trollhättan
# Analyserar: Kategori:Fotbollsspelare i Trollhättans FK
# Analyserar: Kategori:Fotbollsspelare i Trollhättans IF
# Analyserar: Kategori:Fotbollsspelare i Tvååkers IF
# Analyserar: Kategori:Fotbollsspelare i Tyresö FF
# Analyserar: Kategori:Fotbollsspelare i IFK Täby
# Analyserar: Kategori:Fotbollsspelare i Täby FK
# Analyserar: Kategori:Fotbollsspelare i Tölö IF
# Analyserar: Kategori:Fotbollsspelare i IFK Uddevalla
# Analyserar: Kategori:Fotbollsspelare i Umeå FC
# Analyserar: Kategori:Fotbollsspelare i Umeå IK FF
# Analyserar: Kategori:Fotbollsspelare i Umeå Södra FF
# Analyserar: Kategori:Fotbollsspelare i IK Uppsala Fotboll
# Analyserar: Kategori:Fotbollsspelare i Upsala IF
# Analyserar: Kategori:Fotbollsspelare i Utsiktens BK
# Analyserar: Kategori:Fotbollsspelare i Vallens IF
# Analyserar: Kategori:Fotbollsspelare i Vallentuna BK
# Analyserar: Kategori:Fotbollsspelare i Valsta Syrianska IK
# Analyserar: Kategori:Fotbollsspelare i Varbergs BoIS
# Analyserar: Kategori:Fotbollsspelare i Varbergs GIF
# Analyserar: Kategori:Fotbollsspelare i Vasalunds IF
# Analyserar: Kategori:Fotbollsspelare i Vessigebro BK
# Analyserar: Kategori:Fotbollsspelare i IF Viken
# Analyserar: Kategori:Fotbollsspelare i Vilans BoIF
# Analyserar: Kategori:Fotbollsspelare i Vinbergs IF
# Analyserar: Kategori:Fotbollsspelare i IK Virgo
# Analyserar: Kategori:Fotbollsspelare i Vittsjö GIK
# Analyserar: Kategori:Fotbollsspelare i Vårgårda IK
# Analyserar: Kategori:Fotbollsspelare i IFK Vänersborg
# Analyserar: Kategori:Fotbollsspelare i Vänersborgs FK
# Analyserar: Kategori:Fotbollsspelare i Vänersborgs IF
# Analyserar: Kategori:Fotbollsspelare i Värmbols FC
# Analyserar: Kategori:Fotbollsspelare i IFK Värnamo
# Analyserar: Kategori:Fotbollsspelare i Värtans IK
# Analyserar: Kategori:Fotbollsspelare i Väsby IK
# Analyserar: Kategori:Fotbollsspelare i FC Väsby United
# Analyserar: Kategori:Fotbollsspelare i Västerviks FF
# Analyserar: Kategori:Fotbollsspelare i Västerås BK30
# Analyserar: Kategori:Fotbollsspelare i Västerås SK
# Analyserar: Kategori:Fotbollsspelare i Västra Frölunda IF
# Analyserar: Kategori:Fotbollsspelare i Växjö BK
# Analyserar: Kategori:Fotbollsspelare i Växjö DFF
# Analyserar: Kategori:Fotbollsspelare i IF Warta
# Analyserar: Kategori:Fotbollsspelare i IK Wormo
# Analyserar: Kategori:Fotbollsspelare i Wä IF
# Analyserar: Kategori:Fotbollsspelare i Ystads IF
# Analyserar: Kategori:Fotbollsspelare i Ytterby IS
# Analyserar: Kategori:Fotbollsspelare i IFK Åmål
# Analyserar: Kategori:Fotbollsspelare i Åsa IF
# Analyserar: Kategori:Fotbollsspelare i Åstorps FF
# Analyserar: Kategori:Fotbollsspelare i Åtvidabergs FF
# Analyserar: Kategori:Fotbollsspelare i Älgarna-Härnösand IF
# Analyserar: Kategori:Fotbollsspelare i Älvsjö AIK
# Analyserar: Kategori:Fotbollsspelare i Älvängens IK
# Analyserar: Kategori:Fotbollsspelare i Ängelholms FF
# Analyserar: Kategori:Fotbollsspelare i Ödåkra IF
# Analyserar: Kategori:Fotbollsspelare i Örebro SK
# Analyserar: Kategori:Fotbollsspelare i Örebro Syrianska IF
# Analyserar: Kategori:Fotbollsspelare i KIF Örebro DFF
# Analyserar: Kategori:Fotbollsspelare i Örgryte IS
# Analyserar: Kategori:Fotbollsspelare i Österlen FF
# Analyserar: Kategori:Fotbollsspelare i Östers IF
# Analyserar: Kategori:Fotbollsspelare i IFK Östersund
# Analyserar: Kategori:Fotbollsspelare i Östersunds FK
# Analyserar: Kategori:Fotbollsspelare i Österåker United
# Analyserar: Kategori:Fotbollsspelare i Öxabäcks IF
# Analyserar: Kategori:Fotbollsspelare i IFK Öxnehaga
#                                     club_category    club_qid  wiki_count  \
# 252         Kategori:Fotbollsspelare i Örgryte IS   Q11903335         292
# 147     Kategori:Fotbollsspelare i IFK Norrköping  Q108001798         299
# 3                  Kategori:Fotbollsspelare i AIK     Q221602         442
# 23   Kategori:Fotbollsspelare i IF Brommapojkarna     Q754339         280
# 64        Kategori:Fotbollsspelare i IFK Göteborg     Q201567         431
#
#      wikidata_count  only_in_wiki  only_in_wikidata
# 252              99           222                29
# 147             126           211                38
# 3               402           145               105
# 23              162           142                24
# 64              431           123               123

# %%
df_diff.sort_values("only_in_wiki", ascending=False)
# Out:
#                                     club_category    club_qid  wiki_count  \
# 252         Kategori:Fotbollsspelare i Örgryte IS   Q11903335         292
# 147     Kategori:Fotbollsspelare i IFK Norrköping  Q108001798         299
# 3                  Kategori:Fotbollsspelare i AIK     Q221602         442
# 23   Kategori:Fotbollsspelare i IF Brommapojkarna     Q754339         280
# 64        Kategori:Fotbollsspelare i IFK Göteborg     Q201567         431
# ..                                            ...         ...         ...
# 66   Kategori:Fotbollsspelare i Hallstahammars SK    Q1571931           6
# 112       Kategori:Fotbollsspelare i Kortedala IF    Q6432695           2
# 92        Kategori:Fotbollsspelare i IFK Västerås    Q1653530           5
# 95    Kategori:Fotbollsspelare i Jakobsbergs GoIF    Q1679513           2
# 128         Kategori:Fotbollsspelare i Lotorps IF   Q10569876           1
#
#      wikidata_count  only_in_wiki  only_in_wikidata
# 252              99           222                29
# 147             126           211                38
# 3               402           145               105
# 23              162           142                24
# 64              431           123               123
# ..              ...           ...               ...
# 66               15             0                 9
# 112               5             0                 3
# 92               16             0                11
# 95                3             0                 1
# 128               1             0                 0
#
# [256 rows x 6 columns]

# %%
end_time = datetime.now()

duration = end_time - start_time

print("\n===== Körningsrapport =====")
print("Starttid :", start_time.strftime("%Y-%m-%d %H:%M:%S"))
print("Sluttid  :", end_time.strftime("%Y-%m-%d %H:%M:%S"))

total_seconds = int(duration.total_seconds())
hours = total_seconds // 3600
minutes = (total_seconds % 3600) // 60
seconds = total_seconds % 60

print(f"Körtid   : {hours}h {minutes}m {seconds}s")
print("===========================\n")
# Out:
# ===== Körningsrapport =====
# Starttid : 2026-02-26 08:02:29
# Sluttid  : 2026-02-26 09:49:29
# Körtid   : 1h 46m 59s
# ===========================
