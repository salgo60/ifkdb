# %% [markdown]
# ### 33_difhistoryplayer_3
#
# Script: build_mnm_pipeline.py
# * denna notebook [33_difhistoryplayer_3.ipynb](https://github.com/salgo60/ifkdb/blob/main/Notebook/33_difhistoryplayer_3.ipynb)
#    * [mnm_update_difplayers_3.csv](https://github.com/salgo60/ifkdb/blob/main/Notebook/mnm_update_difplayers_3.csv)
#    * [quickstatements_difplayers_3.txt](https://github.com/salgo60/ifkdb/blob/main/Notebook/quickstatements_difplayers_3.txt)
#
# * tidigare notebook test [33_difhistoryplayer_2.ipynb](https://github.com/salgo60/ifkdb/blob/main/Notebook/33_difhistoryplayer_2.ipynb)
#
# Vibekodad
# * 💡 Nästa förbättring som skulle vara väldigt värdefull för DIF-datasetet:
#    * extrahera moderklubb
#    * extrahera tröjnummer
#    * generera P413 (position played on team)
#
# Det går att göra ganska stabilt från samma infobox och ger mycket bättre Wikidata-data.

# %%
from datetime import datetime
import platform
import sys
import os

# Start timer
start_time = datetime.now()
print(f"Start time: {start_time:%Y-%m-%d %H:%M:%S}")
# Out:
# Start time: 2026-03-07 10:36:25

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm
import re
from datetime import date

INPUT="difplayers.json"
TEAM_Q="Q163131"  # Djurgårdens IF
mmupdatefile = "mnm_update_difplayers_3.csv"
qsfile = "quickstatements_difplayers_3.txt"

df=pd.read_json(INPUT)

session=requests.Session()
headers={"User-Agent":"dif-wikidata-bot salgo60@msn.com"}

# ---------------- SCRAPE INFOBOX ----------------

def scrape(url):
    try:
        r=session.get(url,timeout=10,headers=headers)
        soup=BeautifulSoup(r.text,"html.parser")
        box=soup.select_one("section.wp-block-uagb-section")
        return box.get_text("\n",strip=True) if box else ""
    except:
        return ""

with ThreadPoolExecutor(max_workers=12) as ex:
    df["infobox"]=list(tqdm(ex.map(scrape,df["external_url"]),total=len(df)))

# ---------------- EXTRACT DATA ----------------

df["born_year"]=df["infobox"].str.extract(r"Född:\s*\d+\s+\w+\s+(\d{4})")

df["position"]=df["infobox"].str.extract(r"Position:\s*([^\n]+)")

df["shirt"]=df["infobox"].str.extract(r"Nummer:\s*(\d+)")

df["youth"]=df["infobox"].str.extract(r"Moderklubb:\s*([^\n]+)")

# klubbår = sista årtal i infobox
df["years"]=df["infobox"].str.findall(r"\b(?:19|20)\d{2}\b")

def club_range(x):
    if len(x)>=2:
        return x[-2],x[-1]
    return None,None

df[["start","end"]]=pd.DataFrame(df["years"].apply(club_range).tolist(),index=df.index)

# ---------------- POSITION MAPPING ----------------

pos_map={
"målvakt":"Q201330",
"back":"Q230250",
"mittfältare":"Q193592",
"anfallare":"Q280658"
}

df["pos_q"]=df["position"].map(pos_map)

# ---------------- MIX'N'MATCH DESCRIPTION ----------------

df["desc"]="football "+df["position"].fillna("player")+" (born "+df["born_year"].fillna("")+")"

df.loc[df["start"].notna(),"desc"]+=", Djurgårdens IF player "+df["start"]+"–"+df["end"]

df["desc"]=df["desc"].str.replace(r"\s+"," ",regex=True).str.strip()

mnm=df[["external_id","name","desc"]].rename(columns={"external_id":"id"})

mnm["desc"]=mnm["desc"].str.slice(0,150)

mnm.to_csv(mmupdatefile,index=False)

# ---------------- QUICKSTATEMENTS ----------------

today=date.today().isoformat()

qs=[]

for _,r in df.iterrows():

    q=r["q"]

    if pd.isna(q):
        continue

    source=r["external_url"]

    # birth year
    if pd.notna(r["born_year"]):

        qs.append(
        f'{q}\tP569\t+{r["born_year"]}-00-00T00:00:00Z/9\tS854\t"{source}"\tS813\t+{today}T00:00:00Z/11'
        )

    # position
    if pd.notna(r["pos_q"]):

        qs.append(
        f'{q}\tP413\t{r["pos_q"]}\tS854\t"{source}"\tS813\t+{today}T00:00:00Z/11'
        )

    # shirt number
    if pd.notna(r["shirt"]):

        qs.append(
        f'{q}\tP1618\t"{r["shirt"]}"\tS854\t"{source}"\tS813\t+{today}T00:00:00Z/11'
        )

    # Djurgården membership
    if pd.notna(r["start"]):

        qs.append(
        f'{q}\tP54\t{TEAM_Q}\tP580\t+{r["start"]}-00-00T00:00:00Z/9\tP582\t+{r["end"]}-00-00T00:00:00Z/9\tS854\t"{source}"\tS813\t+{today}T00:00:00Z/11'
        )

with open(qsfile,"w") as f:
    for line in qs:
        f.write(line+"\n")

# ---------------- SUMMARY ----------------

print("Pipeline finished")
print("Mix'n'Match file: ", mmupdatefile)
print("QuickStatements file:", qsfile)
print("QuickStatements rows:",len(qs))
# Out:
# 100%|███████████████████████████████████████| 1105/1105 [03:02<00:00,  6.05it/s]
# Pipeline finished
# Mix'n'Match file:  mnm_update_difplayers_3.csv
# QuickStatements file: quickstatements_difplayers_3.txt
# QuickStatements rows: 1826

# %%
# End timer
end_time = datetime.now()
duration = end_time - start_time

print("\n--- Execution Summary ---")
print(f"End time:      {end_time:%Y-%m-%d %H:%M:%S}")
print(f"Duration:      {duration}")
print(f"Total seconds: {duration.total_seconds():.2f}")
print(f"Python ver:    {sys.version.split()[0]}")
print(f"Platform:      {platform.system()} {platform.release()}")
print(f"Process ID:    {os.getpid()}")
# Out:
# --- Execution Summary ---
# End time:      2026-03-07 10:39:28
# Duration:      0:03:03.300886
# Total seconds: 183.30
# Python ver:    3.12.2
# Platform:      Darwin 25.3.0
# Process ID:    14543
