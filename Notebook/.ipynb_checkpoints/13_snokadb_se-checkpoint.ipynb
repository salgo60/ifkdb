# %% [markdown]
# ### snokadb.se
# * [#13](https://github.com/salgo60/ifkdb/issues/13)
# * Notebook [13_snokadb_se](https://github.com/salgo60/ifkdb/blob/main/Notebook/13_snokadb_se.ipynb)

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2026-03-29 06:54:08.214256

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import asyncio
import re
import pandas as pd
from playwright.async_api import async_playwright

async def scrape_players():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        await page.goto(
            "https://snokadb.se/spelare",
            wait_until="domcontentloaded",
            timeout=60000
        )

        # ge React lite tid
        await page.wait_for_timeout(2000)

        await page.wait_for_selector("table")

        rows = await page.query_selector_all("table tbody tr")
        data = []

        for row in rows:
            cols = await row.query_selector_all("td")
            if len(cols) < 4:
                continue

            raw_name = await cols[0].inner_text()
            name = raw_name.strip()

            seasons = (await cols[1].inner_text()).strip()
            matches = (await cols[2].inner_text()).strip()
            goals = (await cols[3].inner_text()).strip()

            link = await row.query_selector("a")
            href = await link.get_attribute("href") if link else ""
            slug = href.split("/")[-1] if href else ""

            data.append({
                "snokadb_id": slug,
                "name": name,
                "seasons": seasons,
                "matches": matches,
                "goals": goals
            })

        await browser.close()

    return pd.DataFrame(data)

df = asyncio.run(scrape_players())
df.head(), len(df)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[3], line 44
#      40         await browser.close()
#      42     return pd.DataFrame(data)
# ---> 44 df = asyncio.run(scrape_players())
#      45 df.head(), len(df)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# Cell In[3], line 10, in scrape_players()
#       8 browser = await p.chromium.launch(headless=True)
#       9 page = await browser.new_page()
# ---> 10 await page.goto("https://snokadb.se/spelare", timeout=60000)
#      11 await page.wait_for_selector("table")
#      13 rows = await page.query_selector_all("table tbody tr")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/playwright/async_api/_generated.py:8992, in Page.goto(self, url, timeout, wait_until, referer)
#    8931 async def goto(
#    8932     self,
#    8933     url: str,
#    (...)
#    8939     referer: typing.Optional[str] = None,
#    8940 ) -> typing.Optional["Response"]:
#    8941     """Page.goto
#    8942
#    8943     Returns the main resource response. In case of multiple redirects, the navigation will resolve with the first
#    (...)
#    8988     Union[Response, None]
#    8989     """
#    8991     return mapping.from_impl_nullable(
# -> 8992         await self._impl_obj.goto(
#    8993             url=url, timeout=timeout, waitUntil=wait_until, referer=referer
#    8994         )
#    8995     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/playwright/_impl/_page.py:556, in Page.goto(self, url, timeout, waitUntil, referer)
#     549 async def goto(
#     550     self,
#     551     url: str,
#    (...)
#     554     referer: str = None,
#     555 ) -> Optional[Response]:
# --> 556     return await self._main_frame.goto(**locals_to_params(locals()))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/playwright/_impl/_frame.py:153, in Frame.goto(self, url, timeout, waitUntil, referer)
#     143 async def goto(
#     144     self,
#     145     url: str,
#    (...)
#     148     referer: str = None,
#     149 ) -> Optional[Response]:
#     150     return cast(
#     151         Optional[Response],
#     152         from_nullable_channel(
# --> 153             await self._channel.send(
#     154                 "goto", self._navigation_timeout, locals_to_params(locals())
#     155             )
#     156         ),
#     157     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/playwright/_impl/_connection.py:69, in Channel.send(self, method, timeout_calculator, params, is_internal, title)
#      61 async def send(
#      62     self,
#      63     method: str,
#    (...)
#      67     title: str = None,
#      68 ) -> Any:
# ---> 69     return await self._connection.wrap_api_call(
#      70         lambda: self._inner_send(method, timeout_calculator, params, False),
#      71         is_internal,
#      72         title,
#      73     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/playwright/_impl/_connection.py:558, in Connection.wrap_api_call(self, cb, is_internal, title)
#     556     return await cb()
#     557 except Exception as error:
# --> 558     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     559 finally:
#     560     self._api_zone.set(None)
#
# TimeoutError: Page.goto: Timeout 60000ms exceeded.
# Call log:
#   - navigating to "https://snokadb.se/spelare", waiting until "load"

# %%
import asyncio
import re
from playwright.async_api import async_playwright


async def fetch_birthdate(context, slug, semaphore):
    url = f"https://snokadb.se/spelare/{slug}"

    async with semaphore:
        page = await context.new_page()
        try:
            await page.goto("https://snokadb.se/spelare", wait_until="domcontentloaded", timeout=60000)
            # vänta lite extra (React)
            await page.wait_for_timeout(1000)

            content = await page.inner_text("body")

            match = re.search(r"Födelsedatum:\s*\"?(\d{4}-\d{2}-\d{2})\"?", content)

            birthdate = match.group(1) if match else ""
            print(slug, birthdate)

            return birthdate

        except Exception as e:
            print(f"Misslyckades för {slug}: {e}")
            return ""

        finally:
            await page.close()

        # liten paus mellan requests
        await asyncio.sleep(0.3)


async def enrich_parallel(df, max_concurrency=2):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        context = await browser.new_context()
        semaphore = asyncio.Semaphore(max_concurrency)

        tasks = [
            fetch_birthdate(context, slug, semaphore)
            for slug in df["snokadb_id"]
        ]

        results = await asyncio.gather(*tasks)
        await browser.close()

    df = df.copy()
    df["birthdate"] = results
    return df

# %%
df = await enrich_parallel(df)

# %%
df.to_csv("snokadb_players_raw.csv", index=False)

# %%
df

# %%
# Wikipedia/WIkidata  
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd

sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

query = """
SELECT ?item ?itemLabel ?birthdate ?svwiki WHERE {
  # ?item wdt:P54 wd:Q329607
  OPTIONAL { ?item wdt:P569 ?birthdate }
  OPTIONAL {
    # ?svwiki schema:about ?item ;
            schema:isPartOf <https://sv.wikipedia.org/> .
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "sv,en". }
}
"""

sparql.setQuery(query)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

rows = []
for r in results["results"]["bindings"]:
    rows.append({
        "wikidata_qid": r["item"]["value"].split("/")[-1],
        "name_wd": r["itemLabel"]["value"],
        "birthdate_wd": r.get("birthdate", {}).get("value", ""),
        "wikipedia_sv": r.get("svwiki", {}).get("value", "")
    })

wd_df = pd.DataFrame(rows)
wd_df.head(), len(wd_df)

# %%
# Matcha mot snokadb  
merged = df.merge(
    wd_df,
    left_on="name",
    right_on="name_wd",
    how="left"
)

merged[["snokadb_id","name","wikidata_qid","wikipedia_sv"]].head()

# %%
merged.info()

# %%
merged.head(20)

# %%
def normalize(n):
    return n.lower().replace('"','').strip()

df["name_norm"] = df["name"].apply(normalize)
wd_df["name_norm"] = wd_df["name_wd"].apply(normalize)

merged = df.merge(
    wd_df,
    on="name_norm",
    how="left"
)

# %%
merged.info()

# %%
final = merged[[
    "snokadb_id",
    "name",
    "wikidata_qid",
    "wikipedia_sv",
    "birthdate_wd"
]]

final.head()

# %%
final.info()

# %% [markdown]
# ### Wikipedia / Wikidata
# * [Kategorin har 283](https://sv.wikipedia.org/w/index.php?title=Kategori:Fotbollsspelare_i_IFK_Norrk%C3%B6ping&pagefrom=Nilsson%2C+David+Mitov%0ADavid+Mitov+Nilsson#mw-pages)
# * [Wikidata 202](https://w.wiki/Hx5x)

# %%
import requests
import time

S = requests.Session()
S.headers.update({
    "User-Agent": "IFK-POC/1.0 (https://github.com/yourrepo; contact: your@email)"
})

URL = "https://sv.wikipedia.org/w/api.php"

def get_category_members():
    members = []
    params = {
        "action": "query",
        "list": "categorymembers",
        "cmtitle": "Kategori:Fotbollsspelare i IFK Norrköping",
        "cmlimit": "500",
        "format": "json",
        "formatversion": "2"
    }

    while True:
        r = S.get(URL, params=params, timeout=30)
        r.raise_for_status()

        # debug om något går fel
        if "application/json" not in r.headers.get("Content-Type", ""):
            print("Fick inte JSON:")
            print(r.text[:500])
            break

        data = r.json()

        members.extend(data["query"]["categorymembers"])

        if "continue" in data:
            params.update(data["continue"])
            time.sleep(0.5)  # snäll mot API:t
        else:
            break

    return [m["title"] for m in members]

titles = get_category_members()
len(titles)

# %%
#titles

# %%
import requests
import time
import pandas as pd

WD_API = "https://www.wikidata.org/w/api.php"

session = requests.Session()
session.headers.update({
    "User-Agent": "IFK-Norrkoping-POC/1.0 (https://github.com/dittrepo; kontakt: salgö60@msn.com)"
})

# %%
# slå upp titles 
import requests
import pandas as pd
import time


def lookup_titles_in_batches(titles, batch_size=50):
    results = []

    for i in range(0, len(titles), batch_size):
        batch = titles[i:i+batch_size]
        titles_str = "|".join(batch)

        params = {
            "action": "wbgetentities",
            "sites": "svwiki",
            "titles": titles_str,
            "props": "claims|sitelinks",
            "redirects": "yes",
            "format": "json"
        }
        r = session.get(WD_API, params=params)
        r.raise_for_status()
        data = r.json()

        entities = data.get("entities", {})

        for title in batch:
            qid = None
            birthdate = None
            has_p54 = False

            # hitta rätt entity via sitelink
            for entity in entities.values():
                if entity.get("sitelinks", {}).get("svwiki", {}).get("title") == title:
                    qid = entity.get("id")
                    claims = entity.get("claims", {})

                    # birthdate
                    if "P569" in claims:
                        birthdate = claims["P569"][0]["mainsnak"]["datavalue"]["value"]["time"]

                    # P54 IFK
                    if "P54" in claims:
                        for c in claims["P54"]:
                            target = c["mainsnak"]["datavalue"]["value"]["id"]
                            if target == "Q329607":  # IFK Norrköping
                                has_p54 = True
                    break

            results.append({
                "wikipedia_sv": title,
                "wikidata_qid": qid,
                "birthdate_wd": birthdate,
                "has_P54_IFK": has_p54
            })

        time.sleep(0.5)  # var snäll mot API:t

    return pd.DataFrame(results)

df_wiki = lookup_titles_in_batches(titles)
df_wiki.head()

# %%
df_wiki.to_csv("ifkwikipedia.csv")

# %%
df_wiki["has_P54_IFK"].value_counts()

# %%
df_wiki.info()

# %% [markdown]
# ## Quickstatement
# * new property P14243

# %%
qs_rows = []

for _, row in merged.iterrows():
    qid = row["wikidata_qid"]
    
    if isinstance(qid, str) and qid.strip():
        snokadb_id = row["snokadb_id"]
        
        # utan referens
        qs = f'{qid}\tP14243\t"{snokadb_id}"'
        
        qs_rows.append(qs)

# skriv till fil
with open("snokadb_quickstatements.txt", "w", encoding="utf-8") as f:
    for line in qs_rows:
        f.write(line + "\n")

print("QuickStatements-fil skapad: snokadb_quickstatements.txt")
print("\nExempel:")
print("\n".join(qs_rows[:5]))

# %% [markdown]
# ## Status rapport

# %%
import pandas as pd

# Wikipedia-länk
from urllib.parse import quote

df_wiki["wikipedia_url"] = df_wiki["wikipedia_sv"].apply(
    lambda x: "https://sv.wikipedia.org/wiki/" + quote(x.replace(" ", "_"))
)
# Wikidata-länk
df_wiki["wikidata_url"] = "https://www.wikidata.org/wiki/" + df_wiki["wikidata_qid"]

# SnokaDb-länk (matcha på namn)
name_to_slug = dict(zip(df["name"], df["snokadb_id"]))
df_wiki["snokadb_id"] = df_wiki["wikipedia_sv"].map(name_to_slug)
df_wiki["snokadb_url"] = "https://snokadb.se/spelare/" + df_wiki["snokadb_id"].fillna("")

# %%
total_snokadb = len(df)
total_wikipedia = len(df_wiki)
total_p54 = df_wiki["has_P54_IFK"].sum()
missing_p54 = total_wikipedia - total_p54

coverage_percent = round((total_p54 / total_wikipedia) * 100, 1)

# %%
# ================================
# HÄMTA WIKIDATA P54 – BOIS
# ================================

from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

query = """
SELECT ?item ?itemLabel WHERE {
  # ?item wdt:P54 wd:Q863273 .
  SERVICE wikibase:label {
    bd:serviceParam wikibase:language "sv,en,mul" .
  }
}
"""

sparql.setQuery(query)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

wd_players = []

for r in results["results"]["bindings"]:
    wd_players.append({
        "qid": r["item"]["value"].split("/")[-1],
        "name": r["itemLabel"]["value"]
    })

print("Wikidata P54 spelare:", len(wd_players))

# %%
import requests
import pandas as pd
import mwclient
from datetime import datetime

# =====================================
# 1. HÄMTA WIKIDATA (P54 )
# =====================================

SPARQL = """
SELECT ?player ?playerLabel WHERE {
  # ?player wdt:P54 wd:Q329607 .
  SERVICE wikibase:label {
    bd:serviceParam wikibase:language "sv,en,mul".
  }
}
"""

session = requests.Session()
session.headers.update({
    "User-Agent": "SnokaDB Wikidata research script (salgo60@msn.com)",
    "Accept": "application/sparql-results+json"
})

url = "https://query.wikidata.org/sparql"
response = session.get(url, params={"query": SPARQL}, timeout=30)
response.raise_for_status()
data = response.json()

wd_rows = []
for item in data["results"]["bindings"]:
    wd_rows.append({
        "wikidata_id": item["player"]["value"].split("/")[-1],
        "wd_label": item["playerLabel"]["value"]
    })

df_wd = pd.DataFrame(wd_rows)
wd_qids = set(df_wd["wikidata_id"])

# =====================================
# 2. HÄMTA WIKIPEDIA-KATEGORI
# =====================================

site = mwclient.Site("sv.wikipedia.org")
category = site.categories["Fotbollsspelare i IFK Norrköping"]

def chunked(lst, size):
    for i in range(0, len(lst), size):
        yield lst[i:i + size]

pages = [p for p in category.members() if p.namespace == 0]
titles = [p.name for p in pages]

wiki_rows = []

for batch in chunked(titles, 50):
    result = site.api(
        action="query",
        titles="|".join(batch),
        prop="pageprops",
        ppprop="wikibase_item",
        format="json"
    )
    for page in result["query"]["pages"].values():
        wiki_rows.append({
            "wiki_name": page.get("title"),
            "wikidata_id": page.get("pageprops", {}).get("wikibase_item")
        })

df_wiki = pd.DataFrame(wiki_rows)

wiki_titles = list(df_wiki["wiki_name"])
wiki_qids = dict(zip(df_wiki["wiki_name"], df_wiki["wikidata_id"]))

wiki_with_p54 = {
    title for title in wiki_titles
    if wiki_qids.get(title) in wd_qids
}

wiki_without_p54 = [
    title for title in wiki_titles
    if wiki_qids.get(title) not in wd_qids
]

# =====================================
# 3. NYCKELTAL
# =====================================

total_wiki = len(wiki_titles)
total_p54 = len(wd_qids)
missing_p54 = len(wiki_without_p54)
coverage_percent = round((len(wiki_with_p54) / total_wiki) * 100, 1) if total_wiki else 0

# =====================================
# 4. BYGG HTML-RAPPORT
# =====================================

html = f"""
<html>
<head>
<meta charset="utf-8">
<title>Statusrapport AIK – Wikipedia / Wikidata</title>
<style>
body {{ font-family: Arial, sans-serif; }}
table {{ border-collapse: collapse; width: 100%; }}
th, td {{ border: 1px solid #ccc; padding: 6px; }}
th {{ background-color: #f2f2f2; }}
.bad {{ background-color: #ffe6e6; }}
.good {{ background-color: #e6ffe6; }}
</style>
</head>
<body>

<h1>Statusrapport AIK – Wikipedia / Wikidata</h1>
<p>Genererad: {datetime.now().strftime('%Y-%m-%d %H:%M')}</p>

<h2>Nyckeltal</h2>
<ul>
<li>Wikipedia-kategori: {total_wiki} spelare</li>
<li>Wikidata P54 AIK: {total_p54} spelare</li>
<li>Wikipedia-artiklar utan P54: {missing_p54}</li>
<li>Täckning (Wikipedia → WD P54): {coverage_percent} %</li>
</ul>

<hr>

<h2>Wikipedia-kategori – Identifieringsstatus</h2>

<table>
<tr>
<th>Spelare</th>
<th>Wikidata</th>
<th>P54</th>
</tr>
"""

# Sortera så ❌ kommer först
sorted_titles = sorted(
    wiki_titles,
    key=lambda t: t in wiki_with_p54
)

for title in sorted_titles:
    wiki_link = f'<a href="https://sv.wikipedia.org/wiki/{title.replace(" ", "_")}" target="_blank">{title}</a>'
    
    qid = wiki_qids.get(title)
    
    if qid:
        wd_link = f'<a href="https://www.wikidata.org/wiki/{qid}" target="_blank">{qid}</a>'
        has_p54 = qid in wd_qids
    else:
        wd_link = "–"
        has_p54 = False
    
    status = "✅" if has_p54 else "❌"
    row_class = "good" if has_p54 else "bad"
    
    html += f"""
    <tr class="{row_class}">
        <td>{wiki_link}</td>
        <td>{wd_link}</td>
        <td>{status}</td>
    </tr>
    """

html += """
</table>
</body>
</html>
"""
from datetime import datetime

today_str = datetime.now().strftime("%Y%m%d")
output_file = f"snokadb_statusrapport_{today_str}.html"

with open(output_file, "w", encoding="utf-8") as f:
    f.write(html)

print("Rapport skapad:", output_file)

# %%
df.info()

# %%
df

# %% [markdown]
# ## MixandMatch
# id,name,desc,type,url,wikidata

# %%
from datetime import datetime
end_time = datetime.now()

duration = end_time - start_time

print("\n===== Körningsrapport =====")
print("Starttid :", start_time.strftime("%Y-%m-%d %H:%M:%S"))
print("Sluttid  :", end_time.strftime("%Y-%m-%d %H:%M:%S"))

total_seconds = int(duration.total_seconds())
hours = total_seconds // 3600
minutes = (total_seconds % 3600) // 60
seconds = total_seconds % 60

print(f"Körtid   : {hours}h {minutes}m {seconds}s")
print("===========================\n")
