# %% [markdown]
# ### snokadb.se
# * [#13](https://github.com/salgo60/ifkdb/issues/13)
# * Notebook [13_snokadb_se](https://github.com/salgo60/ifkdb/blob/main/Notebook/13_snokadb_se.ipynb)

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2026-02-22 23:26:31.167061

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import asyncio
import re
import pandas as pd
from playwright.async_api import async_playwright

async def scrape_players():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()
        await page.goto("https://snokadb.se/spelare", timeout=60000)
        await page.wait_for_selector("table")

        rows = await page.query_selector_all("table tbody tr")
        data = []

        for row in rows:
            cols = await row.query_selector_all("td")
            if len(cols) < 4:
                continue

            raw_name = await cols[0].inner_text()
            name = re.sub(r"[^\w\s\-\"]", "", raw_name).strip()

            seasons = (await cols[1].inner_text()).strip()
            matches = (await cols[2].inner_text()).strip()
            goals = (await cols[3].inner_text()).strip()

            link = await row.query_selector("a")
            href = await link.get_attribute("href") if link else ""
            slug = href.split("/")[-1] if href else ""

            data.append({
                "snokadb_id": slug,
                "name": name,
                "seasons": seasons,
                "matches": matches,
                "goals": goals
            })

        await browser.close()

    return pd.DataFrame(data)

df = asyncio.run(scrape_players())
df.head(), len(df)
# Out:
# (          snokadb_id               name           seasons matches goals
#  0       abbas-hassan       Abbas Hassan  2010, 2011, 2012      32     0
#  1  abderahman-kabous  Abderahman Kabous              2005      18     1
#  2     abdoulie-tamba     Abdoulie Tamba              2025       5     0
#  3   abdulrazaq-ishaq   Abdulrazaq Ishaq  2020, 2021, 2022      54     2
#  4         adin-bukva         Adin Bukva              2016       3     0,
#  586)

# %%
import asyncio
from playwright.async_api import async_playwright

async def enrich_birthdates(df):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        context = await browser.new_context()
        page = await context.new_page()

        birthdates = []

        for slug in df["snokadb_id"]:
            url = f"https://snokadb.se/spelare/{slug}"

            try:
                await page.goto(url, timeout=60000)
                
                # Vänta tills React är färdig
                await page.wait_for_load_state("networkidle")

                # Vänta kortare på table (inte 30s)
                await page.wait_for_selector("table", timeout=5000)

                rows = await page.query_selector_all("table tr")
                birthdate = ""

                for row in rows:
                    text = await row.inner_text()
                    if "Födelsedatum" in text:
                        tds = await row.query_selector_all("td")
                        birthdate = (await tds[0].inner_text()).strip()
                        break

            except Exception as e:
                print(f"Misslyckades för {slug}")
                birthdate = ""

            birthdates.append(birthdate)

        await browser.close()

    df["birthdate"] = birthdates
    return df

# %%
df.to_csv("snokadb_players_raw.csv", index=False)

# %%
df
# Out:
#             snokadb_id               name                  seasons matches  \
# 0         abbas-hassan       Abbas Hassan         2010, 2011, 2012      32
# 1    abderahman-kabous  Abderahman Kabous                     2005      18
# 2       abdoulie-tamba     Abdoulie Tamba                     2025       5
# 3     abdulrazaq-ishaq   Abdulrazaq Ishaq         2020, 2021, 2022      54
# 4           adin-bukva         Adin Bukva                     2016       3
# ..                 ...                ...                      ...     ...
# 581         ake-brynje         Åke Brynje                  1939/40       1
# 582      ake-johansson      Åke Johansson  1949/50 och 15 säsonger     321
# 583        ake-larsson        Åke Larsson         1939/40, 1940/41       7
# 584         ake-skarin         Åke Skarin                  1939/40       2
# 585   orjan-martinsson   Örjan Martinsson      1959 och 8 säsonger     173
#
#     goals
# 0       0
# 1       1
# 2       0
# 3       2
# 4       0
# ..    ...
# 581     0
# 582     1
# 583     0
# 584     0
# 585    52
#
# [586 rows x 5 columns]

# %%
# Wikipedia/WIkidata  
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd

sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

query = """
SELECT ?item ?itemLabel ?birthdate ?svwiki WHERE {
  # ?item wdt:P54 wd:Q329607
  OPTIONAL { ?item wdt:P569 ?birthdate }
  OPTIONAL {
    # ?svwiki schema:about ?item ;
            schema:isPartOf <https://sv.wikipedia.org/> .
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "sv,en". }
}
"""

sparql.setQuery(query)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

rows = []
for r in results["results"]["bindings"]:
    rows.append({
        "wikidata_qid": r["item"]["value"].split("/")[-1],
        "name_wd": r["itemLabel"]["value"],
        "birthdate_wd": r.get("birthdate", {}).get("value", ""),
        "wikipedia_sv": r.get("svwiki", {}).get("value", "")
    })

wd_df = pd.DataFrame(rows)
wd_df.head(), len(wd_df)
# Out:
# (  wikidata_qid             name_wd          birthdate_wd wikipedia_sv
#  0      Q308080  Abderrahman Kabous  1983-04-24T00:00:00Z
#  1      Q576245    Kyle Lightbourne  1968-09-29T00:00:00Z
#  2      Q629453    Slobodan Marović  1964-07-13T00:00:00Z
#  3      Q634973      Janne Hietanen  1978-06-02T00:00:00Z
#  4      Q724829     Balázs Rabóczki  1978-01-09T00:00:00Z             ,
#  209)

# %%
# Matcha mot snokadb  
merged = df.merge(
    wd_df,
    left_on="name",
    right_on="name_wd",
    how="left"
)

merged[["snokadb_id","name","wikidata_qid","wikipedia_sv"]].head()
# Out:
#           snokadb_id               name wikidata_qid  \
# 0       abbas-hassan       Abbas Hassan      Q305870
# 1  abderahman-kabous  Abderahman Kabous          NaN
# 2     abdoulie-tamba     Abdoulie Tamba          NaN
# 3   abdulrazaq-ishaq   Abdulrazaq Ishaq          NaN
# 4         adin-bukva         Adin Bukva    Q27300004
#
#                                  wikipedia_sv
# 0  https://sv.wikipedia.org/wiki/Abbas_Hassan
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4    https://sv.wikipedia.org/wiki/Adin_Bukva

# %%
merged.info()

# %%
def normalize(n):
    return n.lower().replace('"','').strip()

df["name_norm"] = df["name"].apply(normalize)
wd_df["name_norm"] = wd_df["name_wd"].apply(normalize)

merged = df.merge(
    wd_df,
    on="name_norm",
    how="left"
)

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   snokadb_id    592 non-null    object
#  1   name          592 non-null    object
#  2   seasons       592 non-null    object
#  3   matches       592 non-null    object
#  4   goals         592 non-null    object
#  5   name_norm     592 non-null    object
#  6   wikidata_qid  150 non-null    object
#  7   name_wd       150 non-null    object
#  8   birthdate_wd  150 non-null    object
#  9   wikipedia_sv  150 non-null    object
# dtypes: object(10)
# memory usage: 46.4+ KB

# %%
final = merged[[
    "snokadb_id",
    "name",
    "wikidata_qid",
    "wikipedia_sv",
    "birthdate_wd"
]]

final.head()
# Out:
#           snokadb_id               name wikidata_qid  \
# 0       abbas-hassan       Abbas Hassan      Q305870
# 1  abderahman-kabous  Abderahman Kabous          NaN
# 2     abdoulie-tamba     Abdoulie Tamba          NaN
# 3   abdulrazaq-ishaq   Abdulrazaq Ishaq          NaN
# 4         adin-bukva         Adin Bukva    Q27300004
#
#                                  wikipedia_sv          birthdate_wd
# 0  https://sv.wikipedia.org/wiki/Abbas_Hassan  1985-05-10T00:00:00Z
# 1                                         NaN                   NaN
# 2                                         NaN                   NaN
# 3                                         NaN                   NaN
# 4    https://sv.wikipedia.org/wiki/Adin_Bukva  1998-01-11T00:00:00Z

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   snokadb_id    592 non-null    object
#  1   name          592 non-null    object
#  2   wikidata_qid  150 non-null    object
#  3   wikipedia_sv  150 non-null    object
#  4   birthdate_wd  150 non-null    object
# dtypes: object(5)
# memory usage: 23.3+ KB

# %% [markdown]
# ### Wikipedia / Wikidata
# * [Kategorin har 283](https://sv.wikipedia.org/w/index.php?title=Kategori:Fotbollsspelare_i_IFK_Norrk%C3%B6ping&pagefrom=Nilsson%2C+David+Mitov%0ADavid+Mitov+Nilsson#mw-pages)
# * [Wikidata 202](https://w.wiki/Hx5x)

# %%
import requests
import time

S = requests.Session()
S.headers.update({
    "User-Agent": "IFK-POC/1.0 (https://github.com/yourrepo; contact: your@email)"
})

URL = "https://sv.wikipedia.org/w/api.php"

def get_category_members():
    members = []
    params = {
        "action": "query",
        "list": "categorymembers",
        "cmtitle": "Kategori:Fotbollsspelare i IFK Norrköping",
        "cmlimit": "500",
        "format": "json",
        "formatversion": "2"
    }

    while True:
        r = S.get(URL, params=params, timeout=30)
        r.raise_for_status()

        # debug om något går fel
        if "application/json" not in r.headers.get("Content-Type", ""):
            print("Fick inte JSON:")
            print(r.text[:500])
            break

        data = r.json()

        members.extend(data["query"]["categorymembers"])

        if "continue" in data:
            params.update(data["continue"])
            time.sleep(0.5)  # snäll mot API:t
        else:
            break

    return [m["title"] for m in members]

titles = get_category_members()
len(titles)
# Out:
# 294

# %%
titles
# Out:
# ['Ishaq Abdulrazak',
#  'Samuel Adegbenro',
#  'Viktor Agardius',
#  'Enis Ahmetovic',
#  'Astrit Ajdarević',
#  'Ernst Albihn',
#  'Anders Alé',
#  'Albert Aleksanjan',
#  'Andreas Alm',
#  'Pontus Almqvist',
#  'Kevin Álvarez',
#  'Stefan Alvén',
#  'Kevin Amuneke',
#  'David Andersson (fotbollsspelare)',
#  'Kennet Andersson',
#  'Leif Andersson (fotbollsspelare född 1952)',
#  'Sebastian Andersson',
#  'Sune Andersson (fotbollsspelare)',
#  'Åke Andersson (fotbollsspelare född 2007)',
#  'Andri Guðjohnsen',
#  'Filip Apelstav',
#  'Ari Freyr Skúlason',
#  'Arnór Ingvi Traustason',
#  'Arnór Sigurðsson',
#  'Kristoffer Arvhage',
#  'Sven Axbom',
#  'Lennart Backman',
#  'Nuredin Bakiu',
#  'Daniel Bamberg',
#  'Modou Barrow',
#  'Sven-Olof "Berka" Bergman',
#  'Göran Bergort',
#  'Kristian Bergström',
#  'Fredrik Bild',
#  'Harry Bild',
#  'Egzon Binaku',
#  'Jóhannes Kristinn Bjarnason',
#  'Jonas Bjurström',
#  'Carl Björk (fotbollsspelare född 2000)',
#  'Pelle Blohm',
#  'Mikael Blomberg',
#  'Andreas Blomqvist',
#  'Stephen Bolma',
#  'David Boo Wiklander',
#  'Jean Carlos de Brito',
#  'Tomas Brolin',
#  'Axel Brönner',
#  'Adin Bukva',
#  'Marcin Burkhardt',
#  'Daniele Burubwa',
#  'Nicklas Bärkroth',
#  'Riki Cakić',
#  'Henrik Castegren',
#  'Jesper Ceesay',
#  'Joseph Ceesay',
#  'Hasan Cetinkaya',
#  'Emanuel Chabo',
#  'Viktor Christiansson',
#  'Gentrit Citaku',
#  'Filip Dagerstål',
#  'Andreas Dahlén',
#  'Inge Danielsson',
#  'Diogo Correa de Oliveira',
#  'Ranko Djordjic',
#  'Eirik Dybendal',
#  'Daniel Eid',
#  'Jörgen Ekengren',
#  'Godswill Ekpolo',
#  'Niclas Eliasson',
#  'Joel Enarsson',
#  'Georg Ericson',
#  'Jan Eriksson (fotbollsspelare)',
#  'Lasse Eriksson (fotbollsspelare)',
#  'Tomas Erixon',
#  'Hans Eskilsson',
#  'Marcus Falk-Olander',
#  'Finnur Tómas Pálmason',
#  'Mathias Florén',
#  'Alexander Fransson',
#  'Tor-Arne Fredheim',
#  'Eine Fredriksson',
#  'Niclas Fredriksson',
#  'James Frempong',
#  'Bobbie Friberg da Cruz',
#  'Dago Funes',
#  'Pierre Gallo',
#  'Garðar Gunnlaugsson',
#  'Mathias Gravem',
#  'Léandre Griffit',
#  'Guðmundur Þórarinsson',
#  'Gunnar Heidar Thorvaldsson',
#  'Gunnar Thor Gunnarsson',
#  'Niklas Gunnarsson',
#  'Yahav Gurfinkel',
#  'Eddie Gustafsson',
#  'Magnus Gustafsson (fotbollsspelare)',
#  'Stig Gustafsson (fotbollsspelare född 1931)',
#  'Bengt Gustavsson (fotbollsspelare)',
#  'Andreas Hadenius',
#  'Andreas Haglund',
#  'Sead Hakšabanović',
#  'Linus Hallenius',
#  'Mirza Halvadzic',
#  'Vito Hammershøy-Mistrati',
#  'Mikael Hansson',
#  'Shpëtim Hasani',
#  'Abbas Hassan',
#  'Fritiof Hellichius',
#  'Jan Hellström',
#  'Lennart Hemming',
#  'Karl Holmberg (fotbollsspelare)',
#  'Erik Holmqvist (fotbollsspelare)',
#  'Oskar Holmqvist',
#  'Fabian Holst-Larsen',
#  'Göran Holter',
#  'Christer Hult',
#  'Olle Håkansson',
#  'Per Mathias Høgmo',
#  'Kevin Höög Jansson',
#  'Armando Ibraković',
#  'De Pievre Ilunga',
#  'Ísak Andri Sigurgeirsson',
#  'Alexander Jakobsen',
#  'Felix Jakobsson',
#  'Wille Jakobsson',
#  'Dime Jankulovski',
#  'Gustav Jansson (fotbollsspelare)',
#  'Jan Jansson (fotbollsspelare)',
#  'Oscar Jansson',
#  'Elias Jemal',
#  'Ísak Bergmann Jóhannesson',
#  'Andreas Johansson (fotbollsspelare född 1982)',
#  'Marcus Johansson (fotbollsspelare)',
#  'Torsten Johansson (fotbollsspelare)',
#  'Åke "Bajdoff" Johansson',
#  'Jón Guðni Fjóluson',
#  'Jan-Åke Jonsson (fotbollsspelare)',
#  'Leo Jonsson',
#  'Lukas Jonsson',
#  'Magnus Jonsson (fotbollsmålvakt)',
#  'Torbjörn Jonsson',
#  'Patrik Jönsson (fotbollsspelare)',
#  'Jan Kalén',
#  'Alhaji Kamara',
#  'Darrell Kamdem Tibell',
#  'Göran E. Karlsson',
#  'Imad Khalili',
#  'Kristoffer Khazeni',
#  'Niclas Kindvall',
#  'Ove Kindvall',
#  'Adnan Kojic',
#  'Lars Krogh Gerson',
#  'Emir Kujović',
#  'Manasse Kusu',
#  'Jevgenij Kuznetsov (fotbollsspelare)',
#  'Henry Källgren',
#  'Evert Lager',
#  'Haris Laitinen',
#  'Michael Langer',
#  'Kasper Larsen',
#  'Håkan Larsson (fotbollsspelare)',
#  'Jordan Larsson',
#  'Svante Larsson',
#  'Dick Last',
#  'Rasmus Lauritsen',
#  'Rawez Lawan',
#  'Jonathan Levi',
#  'Nils Liedholm',
#  'Peter Liljedahl',
#  'Lucas Lima',
#  'Victor Lind',
#  'Andreas Lindberg',
#  'Torsten Lindberg',
#  'Erik Lindell',
#  'Otto Lindell',
#  'Julius Lindgren',
#  'Elvis Lindkvist',
#  'Mikael Lindskog',
#  'Jesper Lindvall',
#  'Marco Lund',
#  'Kent Lundqvist',
#  'Håkan Lundström',
#  'Siim Luts',
#  'Gösta Löfgren',
#  'Peter Lönn',
#  'Roger Lönn',
#  'Thomas Magnusson (fotbollsspelare)',
#  'Feliciano Magro',
#  'Eman Markovic',
#  'Örjan Martinsson',
#  'Otto Martler',
#  'Brian McDermott',
#  'Christopher Meneses',
#  'David Moberg Karlsson',
#  'Mohanad Jeahze',
#  'Russell Mwafulirwa',
#  'Tomas Månsson',
#  'Ihab Naser',
#  'Moutaz Neffati',
#  'Ryan Nelson',
#  'David Mitov Nilsson',
#  'Mika Niskala',
#  'Gunnar Nordahl',
#  'Göran Nordahl',
#  'Gösta Nordahl',
#  'Knut Nordahl',
#  'David Nordbeck',
#  'Pontus Nordenberg',
#  'Olle Nordin',
#  'Björn Nordqvist',
#  'Bengt Nyholm',
#  'Christoffer Nyman',
#  'Holger Nyman',
#  'Pär-Olof Ohlsson',
#  'Liam Olausson',
#  'Oliver Stefánsson',
#  'Thor André Olsen',
#  'Thomas Olsson (fotbollsspelare)',
#  'Simon Omekanda',
#  'Kojo Peprah Oppong',
#  'Jacob Ortmark',
#  'Ulf Ottosson',
#  'Sven Persson (1918–1994)',
#  'Håkan Pettersson (fotbollsspelare)',
#  'Isak Pettersson',
#  'Stefan Pettersson (fotbollsspelare)',
#  'Igor Ponomarjov',
#  'Petru Racu',
#  'Theodore Rask',
#  'Emil Roback',
#  'Hans Rosander',
#  'Birger Rosengren',
#  'Mikael Roth',
#  'Jonny Rödlund',
#  'Viktor Rönneklev',
#  'Klebér Saarenpää',
#  'Dino Salihovic',
#  'Alfons Sampsted',
#  'Magnus Samuelsson (fotbollsspelare)',
#  'Ture Sandberg',
#  'Herbert Sandin',
#  'Bruno Santos da Silva',
#  'Kylian Seka',
#  'Ken Sema',
#  'Maic Sema',
#  'Noel Sernelius',
#  'Sasa Sjanic',
#  'Daniel Sjölund',
#  'Edvard Skagestad',
#  'Morten Skjønsberg',
#  'Simon Skrabb',
#  'Martin Smedberg-Dalence',
#  'Eric Smith',
#  'Ian Smith (fotbollsspelare)',
#  'Richard Spong',
#  'Isak Ssewankambo',
#  'Stefán Þórðarson',
#  'Vladimir Sudar',
#  'Antti Sumiala',
#  'Stig Sundqvist',
#  'Kim Suominen',
#  'Ivar Svensson (fotbollsspelare)',
#  'Janne Svensson',
#  'Patrik Svensson (fotbollsspelare)',
#  'Abdoulie Tamba',
#  'Joonas Tamm',
#  'Armin Tanković',
#  'Muamer Tanković',
#  'Tesfaldet Tekie',
#  'Edvin Tellgren',
#  'Christopher Telo',
#  'Isaac Kiese Thelin',
#  'Simon Thern',
#  'Nikola Tkalčić',
#  'Jesper Tolinsson',
#  'Mikael Torin',
#  'Kenneth Udjus',
#  'Sulo Vaattovaara',
#  'Tommi Vaiho',
#  'Andreas Vaikla',
#  'Johannes Vall',
#  'Ivo Vazgeč',
#  'Linus Wahlqvist',
#  'Jonas Wallerstedt',
#  'Max Watson',
#  'Jonas Weber',
#  'Benny Wendt',
#  'Niklas Westberg',
#  'Anders Whass',
#  'Anders Wikström (fotbollsspelare)',
#  'Joachim Yaw Acheampong',
#  'Martin Åslund',
#  'Mattias Östberg',
#  'Alexander Östlund']

# %%
import requests
import time
import pandas as pd

WD_API = "https://www.wikidata.org/w/api.php"

session = requests.Session()
session.headers.update({
    "User-Agent": "IFK-Norrkoping-POC/1.0 (https://github.com/dittrepo; kontakt: salgö60@msn.com)"
})

# %%
# slå upp titles 
import requests
import pandas as pd
import time


def lookup_titles_in_batches(titles, batch_size=50):
    results = []

    for i in range(0, len(titles), batch_size):
        batch = titles[i:i+batch_size]
        titles_str = "|".join(batch)

        params = {
            "action": "wbgetentities",
            "sites": "svwiki",
            "titles": titles_str,
            "props": "claims|sitelinks",
            "redirects": "yes",
            "format": "json"
        }
        r = session.get(WD_API, params=params)
        r.raise_for_status()
        data = r.json()

        entities = data.get("entities", {})

        for title in batch:
            qid = None
            birthdate = None
            has_p54 = False

            # hitta rätt entity via sitelink
            for entity in entities.values():
                if entity.get("sitelinks", {}).get("svwiki", {}).get("title") == title:
                    qid = entity.get("id")
                    claims = entity.get("claims", {})

                    # birthdate
                    if "P569" in claims:
                        birthdate = claims["P569"][0]["mainsnak"]["datavalue"]["value"]["time"]

                    # P54 IFK
                    if "P54" in claims:
                        for c in claims["P54"]:
                            target = c["mainsnak"]["datavalue"]["value"]["id"]
                            if target == "Q329607":  # IFK Norrköping
                                has_p54 = True
                    break

            results.append({
                "wikipedia_sv": title,
                "wikidata_qid": qid,
                "birthdate_wd": birthdate,
                "has_P54_IFK": has_p54
            })

        time.sleep(0.5)  # var snäll mot API:t

    return pd.DataFrame(results)

df_wiki = lookup_titles_in_batches(titles)
df_wiki.head()
# Out:
#        wikipedia_sv wikidata_qid           birthdate_wd  has_P54_IFK
# 0  Ishaq Abdulrazak    Q96361469  +2002-05-05T00:00:00Z         True
# 1  Samuel Adegbenro    Q19152611  +1995-12-03T00:00:00Z        False
# 2   Viktor Agardius     Q5543358  +1989-10-23T00:00:00Z        False
# 3    Enis Ahmetovic    Q19787867  +1992-01-26T00:00:00Z        False
# 4  Astrit Ajdarević      Q751101  +1990-04-17T00:00:00Z         True

# %%
df_wiki.to_csv("ifkwikipedia.csv")

# %%
df_wiki["has_P54_IFK"].value_counts()
# Out:
# has_P54_IFK
# False    151
# True     143
# Name: count, dtype: int64

# %%
df_wiki.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294 entries, 0 to 293
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   wikipedia_sv  294 non-null    object
#  1   wikidata_qid  294 non-null    object
#  2   birthdate_wd  294 non-null    object
#  3   has_P54_IFK   294 non-null    bool
# dtypes: bool(1), object(3)
# memory usage: 7.3+ KB

# %% [markdown]
# ## Status rapport

# %%
import pandas as pd

# Wikipedia-länk
df_wiki["wikipedia_url"] = "https://sv.wikipedia.org/wiki/" + df_wiki["wikipedia_sv"].str.replace(" ", "_")

# Wikidata-länk
df_wiki["wikidata_url"] = "https://www.wikidata.org/wiki/" + df_wiki["wikidata_qid"]

# SnokaDb-länk (matcha på namn)
name_to_slug = dict(zip(df["name"], df["snokadb_id"]))
df_wiki["snokadb_id"] = df_wiki["wikipedia_sv"].map(name_to_slug)
df_wiki["snokadb_url"] = "https://snokadb.se/spelare/" + df_wiki["snokadb_id"].fillna("")

# %%
total_snokadb = len(df)
total_wikipedia = len(df_wiki)
total_p54 = df_wiki["has_P54_IFK"].sum()
missing_p54 = total_wikipedia - total_p54

coverage_percent = round((total_p54 / total_wikipedia) * 100, 1)

# %%
report = f"""
# Statusrapport IFK Norrköping – Wikipedia / Wikidata / SnokaDb

Klubb: IFK Norrköping  
Wikipedia-kategori: 294 spelare  
SnokaDb: {total_snokadb} spelare  

## Wikidata-struktur (P54)

- Har korrekt P54: {total_p54}
- Saknar P54: {missing_p54}
- Täckning: {coverage_percent} %

## Relaterad issue
https://github.com/salgo60/ifkdb/issues/13

---

## Detaljlista

| Namn | Wikipedia | Wikidata | SnokaDb | P54 |
|------|------------|------------|------------|------|
"""

for _, row in df_wiki.iterrows():
    report += f"| {row['wikipedia_sv']} | "
    report += f"[Wiki]({row['wikipedia_url']}) | "
    report += f"[WD]({row['wikidata_url']}) | "
    report += f"[SnokaDb]({row['snokadb_url']}) | "
    report += f"{'✅' if row['has_P54_IFK'] else '❌'} |\n"

print(report)
# Out:
