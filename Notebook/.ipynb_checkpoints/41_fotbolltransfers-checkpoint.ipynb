# %% [markdown]
# * [#41](https://github.com/salgo60/ifkdb/issues/41)
# * denna Notebook [41_fotbolltransfers.ipynb](https://github.com/salgo60/ifkdb/blob/main/Notebook/41_fotbolltransfers.ipynb)
#
# * Mixandmatch [catalog/7732](https://mix-n-match.toolforge.org/#/catalog/7732)

# %%
import sys
print(sys.executable)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/bin/python3.12

# %%
#!pip3 install aiohttp

# %%
import time

from datetime import datetime

now = datetime.now()
timestamp = now.timestamp()

start_time = time.time()
print("Start:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Start: 2026-03-20 14:09:58

# %%
import requests
from bs4 import BeautifulSoup
import time
from tqdm import tqdm
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import json
import os
import re

BASE_PLAYER_URL = "https://fotbolltransfers.com/spelare/x/{}"

SAVE_FILE = "resultsPlayer_partial.json"
FINAL_FILE = "resultsPlayer.json"

headers = {
    "User-Agent": "Mozilla/5.0 (compatible; Wikidatascraper/1.0 salgo60@msn.com)"
}

session = requests.Session()

retries = Retry(
    total=5,
    backoff_factor=0.5,
    status_forcelist=[429, 500, 502, 503, 504],
)

adapter = HTTPAdapter(max_retries=retries)
session.mount("https://", adapter)
session.mount("http://", adapter)

# 🔄 resume
if os.path.exists(SAVE_FILE):
    with open(SAVE_FILE, "r", encoding="utf-8") as f:
        resultsPlayer = json.load(f)
    print(f"Återupptar från {len(resultsPlayer)} spelare")
else:
    resultsPlayer = []

# 🔢 resume baserat på numeric_id
existing_ids = {item["numeric_id"] for item in resultsPlayer}
start_id = max(existing_ids) + 1 if existing_ids else 1

print(f"Startar från player_id = {start_id}")

SAVE_EVERY = 100
MAX_EMPTY_STREAK = 200
empty_streak = 0

def slugify(text):
    text = text.lower()
    text = re.sub(r"[^\w\s-]", "", text)
    text = text.replace(" ", "-")
    return text

for player_id in tqdm(range(start_id, 15500)):
    url = BASE_PLAYER_URL.format(player_id)

    try:
        r = session.get(url, headers=headers, timeout=10)

        if r.status_code != 200:
            empty_streak += 1
            continue

        soup = BeautifulSoup(r.text, "html.parser")

        if not soup.title or not soup.title.string:
            empty_streak += 1
            continue

        name = soup.title.string.split(" - ")[0].strip()

        if name == "Fotbolltransfers.com":
            empty_streak += 1
            continue

        # 🔑 bygg slug + full id
        slug = slugify(name)
        full_id = f"spelare/{slug}/{player_id}"
        full_url = f"https://fotbolltransfers.com/{full_id}"

        resultsPlayer.append({
            "id": full_id,
            "name": name,
            "url": full_url,
            "numeric_id": player_id
        })

        empty_streak = 0

    except requests.exceptions.RequestException as e:
        print(f"Error {player_id}: {e}")
        empty_streak += 1
        continue

    if player_id % SAVE_EVERY == 0:
        with open(SAVE_FILE, "w", encoding="utf-8") as f:
            json.dump(resultsPlayer, f, ensure_ascii=False)

    if empty_streak >= MAX_EMPTY_STREAK:
        print(f"\n🛑 Stoppar: {empty_streak} tomma i rad vid ID {player_id}")
        break

    time.sleep(0.2)

with open(FINAL_FILE, "w", encoding="utf-8") as f:
    json.dump(resultsPlayer, f, ensure_ascii=False, indent=2)

print(f"Klar! Spelare funna: {len(resultsPlayer)}")
# Out:
# Startar från player_id = 1
#  62%|████████████████████▉             | 9545/15499 [3:23:09<1:29:45,  1.11it/s]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 100%|███████████████████████████████████| 15499/15499 [5:09:06<00:00,  1.20s/it]
# Klar! Spelare funna: 14090

# %%
resultsPlayer.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 resultsPlayer.info()
#
# AttributeError: 'list' object has no attribute 'info'

# %%
import re

BASE_TEAM_URL = "https://fotbolltransfers.com/klubbar/x/xx/{}"

SAVE_FILE = "resultsTeam_partial.json"
FINAL_FILE = "resultsTeam.json"

# 🔄 resume
if os.path.exists(SAVE_FILE):
    with open(SAVE_FILE, "r", encoding="utf-8") as f:
        resultsTeam = json.load(f)
else:
    resultsTeam = []

existing_ids = {item["numeric_id"] for item in resultsTeam}
start_id = max(existing_ids) + 1 if existing_ids else 1

def slugify(text):
    text = text.lower()
    text = re.sub(r"[^\w\s-]", "", text)
    text = text.replace(" ", "-")
    return text

for team_id in tqdm(range(start_id, 6800)):
    url = BASE_TEAM_URL.format(team_id)

    try:
        r = session.get(url, headers=headers, timeout=10)

        if r.status_code != 200:
            empty_streak += 1
            continue

        soup = BeautifulSoup(r.text, "html.parser")

        if not soup.title or not soup.title.string:
            empty_streak += 1
            continue

        name = soup.title.string.split(" - ")[0].strip()

        if name == "Fotbolltransfers.com":
            empty_streak += 1
            continue

        link = soup.find("link", rel="canonical")
        full_url = link["href"]
        full_id = full_url.replace("https://fotbolltransfers.com/", "")

        slug = slugify(name)

        resultsTeam.append({
            "id": full_id,
            "name": name,
            "url": full_url,
            "numeric_id": team_id
        })

        empty_streak = 0

    except requests.exceptions.RequestException:
        empty_streak += 1
        continue

    if team_id % SAVE_EVERY == 0:
        with open(SAVE_FILE, "w", encoding="utf-8") as f:
            json.dump(resultsTeam, f, ensure_ascii=False)

    if empty_streak >= MAX_EMPTY_STREAK:
        break

    time.sleep(0.1)

with open(FINAL_FILE, "w", encoding="utf-8") as f:
    json.dump(resultsTeam, f, ensure_ascii=False, indent=2)
# Out:
# 100%|█████████████████████████████████████| 6799/6799 [1:44:07<00:00,  1.09it/s]

# %%
import json

with open("resultsTeam_snapshot.json", "w", encoding="utf-8") as f:
    json.dump(resultsTeam, f, ensure_ascii=False, indent=2)

print("Snapshot sparad ✅")
# Out:
# Snapshot sparad ✅

# %%
#resultsPlayer

# %%
import pandas as pd

# %%
dfPlayers = pd.DataFrame(resultsPlayer,columns=['id','name','url','numeric_id'])

# %%
dfPlayers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14090 entries, 0 to 14089
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          14090 non-null  object
#  1   name        14090 non-null  object
#  2   url         14090 non-null  object
#  3   numeric_id  14090 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 440.4+ KB

# %%
dfPlayers.head(10)
# Out:
#                             id              name  \
# 0   spelare/kim-christensen/37   Kim Christensen
# 1   spelare/marcus-sandberg/38   Marcus Sandberg
# 2     spelare/karl-svensson/39     Karl Svensson
# 3  spelare/nicklas-carlsson/40  Nicklas Carlsson
# 4   spelare/petter-björlund/41   Petter Björlund
# 5     spelare/tuomo-turunen/42     Tuomo Turunen
# 6    spelare/adam-johansson/43    Adam Johansson
# 7      spelare/tobias-hysén/45      Tobias Hysén
# 8     spelare/thomas-olsson/46     Thomas Olsson
# 9  spelare/stefan-selakovic/47  Stefan Selakovic
#
#                                                  url  numeric_id
# 0  https://fotbolltransfers.com/spelare/kim-chris...          37
# 1  https://fotbolltransfers.com/spelare/marcus-sa...          38
# 2  https://fotbolltransfers.com/spelare/karl-sven...          39
# 3  https://fotbolltransfers.com/spelare/nicklas-c...          40
# 4  https://fotbolltransfers.com/spelare/petter-bj...          41
# 5  https://fotbolltransfers.com/spelare/tuomo-tur...          42
# 6  https://fotbolltransfers.com/spelare/adam-joha...          43
# 7  https://fotbolltransfers.com/spelare/tobias-hy...          45
# 8  https://fotbolltransfers.com/spelare/thomas-ol...          46
# 9  https://fotbolltransfers.com/spelare/stefan-se...          47

# %%
dfPlayer.tail(10)
# Out:
#                                            id                      name  \
# 14080               spelare/elton-levin/15105               Elton Levin
# 14081              spelare/oliver-klang/15106              Oliver Klang
# 14082             spelare/oliver-schaaf/15107             Oliver Schaaf
# 14083          spelare/vilmer-johansson/15108          Vilmer Johansson
# 14084    spelare/mario-palomino-delgado/15109    Mario Palomino Delgado
# 14085  spelare/sindri-kristinn-ólafsson/15110  Sindri Kristinn Ólafsson
# 14086            spelare/elion-lipovica/15111            Elion Lipovica
# 14087              spelare/ebbe-orrling/15112              Ebbe Orrling
# 14088              spelare/hannes-nyman/15113              Hannes Nyman
# 14089              spelare/kota-sakurai/15114              Kota Sakurai
#
#                                                      url  numeric_id
# 14080  https://fotbolltransfers.com/spelare/elton-lev...       15105
# 14081  https://fotbolltransfers.com/spelare/oliver-kl...       15106
# 14082  https://fotbolltransfers.com/spelare/oliver-sc...       15107
# 14083  https://fotbolltransfers.com/spelare/vilmer-jo...       15108
# 14084  https://fotbolltransfers.com/spelare/mario-pal...       15109
# 14085  https://fotbolltransfers.com/spelare/sindri-kr...       15110
# 14086  https://fotbolltransfers.com/spelare/elion-lip...       15111
# 14087  https://fotbolltransfers.com/spelare/ebbe-orrl...       15112
# 14088  https://fotbolltransfers.com/spelare/hannes-ny...       15113
# 14089  https://fotbolltransfers.com/spelare/kota-saku...       15114

# %%
resultsTeam
# Out:
# [{'id': 'klubbar/sverige/ifk-goteborg/2',
#   'name': 'IFK Göteborg',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ifk-goteborg/2',
#   'numeric_id': 2},
#  {'id': 'klubbar/sverige/if-elfsborg/3',
#   'name': 'IF Elfsborg',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/if-elfsborg/3',
#   'numeric_id': 3},
#  {'id': 'klubbar/sverige/aik/4',
#   'name': 'AIK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/aik/4',
#   'numeric_id': 4},
#  {'id': 'klubbar/sverige/assyriska-ff/6',
#   'name': 'Assyriska FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/assyriska-ff/6',
#   'numeric_id': 6},
#  {'id': 'klubbar/sverige/osters-if/7',
#   'name': 'Östers IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/osters-if/7',
#   'numeric_id': 7},
#  {'id': 'spelare/utlandsproffs/norge/8',
#   'name': 'Svenska spelare i Norge',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/norge/8',
#   'numeric_id': 8},
#  {'id': 'klubbar/sverige/hammarby-if/9',
#   'name': 'Hammarby IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/hammarby-if/9',
#   'numeric_id': 9},
#  {'id': 'klubbar/sverige/djurgardens-if/10',
#   'name': 'Djurgårdens IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/djurgardens-if/10',
#   'numeric_id': 10},
#  {'id': 'spelare/utlandsproffs/danmark/11',
#   'name': 'Svenska spelare i Danmark',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/danmark/11',
#   'numeric_id': 11},
#  {'id': 'spelare/utlandsproffs/holland/12',
#   'name': 'Svenska spelare i Holland',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/holland/12',
#   'numeric_id': 12},
#  {'id': 'spelare/utlandsproffs/grekland/13',
#   'name': 'Svenska spelare i Grekland',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/grekland/13',
#   'numeric_id': 13},
#  {'id': 'spelare/utlandsproffs/england/14',
#   'name': 'Svenska spelare i England',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/england/14',
#   'numeric_id': 14},
#  {'id': 'spelare/utlandsproffs/schweiz/15',
#   'name': 'Svenska spelare i Schweiz',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/schweiz/15',
#   'numeric_id': 15},
#  {'id': 'spelare/utlandsproffs/turkiet/16',
#   'name': 'Svenska spelare i Turkiet',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/turkiet/16',
#   'numeric_id': 16},
#  {'id': 'spelare/utlandsproffs/tyskland/17',
#   'name': 'Svenska spelare i Tyskland',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/tyskland/17',
#   'numeric_id': 17},
#  {'id': 'spelare/utlandsproffs/italien/18',
#   'name': 'Svenska spelare i Italien',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/italien/18',
#   'numeric_id': 18},
#  {'id': 'spelare/utlandsproffs/spanien/19',
#   'name': 'Svenska spelare i Spanien',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/spanien/19',
#   'numeric_id': 19},
#  {'id': 'spelare/utlandsproffs/osterrike/20',
#   'name': 'Svenska spelare i Österrike',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/osterrike/20',
#   'numeric_id': 20},
#  {'id': 'spelare/utlandsproffs/ryssland/21',
#   'name': 'Svenska spelare i Ryssland',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/ryssland/21',
#   'numeric_id': 21},
#  {'id': 'klubbar/other/other/22',
#   'name': 'other',
#   'url': 'https://fotbolltransfers.com/klubbar/other/other/22',
#   'numeric_id': 22},
#  {'id': 'klubbar/sverige/syrianska-fc/23',
#   'name': 'Syrianska FC',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/syrianska-fc/23',
#   'numeric_id': 23},
#  {'id': 'klubbar/sverige/halmstads-bk/24',
#   'name': 'Halmstads BK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/halmstads-bk/24',
#   'numeric_id': 24},
#  {'id': 'klubbar/sverige/gefle-if/25',
#   'name': 'Gefle IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/gefle-if/25',
#   'numeric_id': 25},
#  {'id': 'klubbar/sverige/if-brommapojkarna/26',
#   'name': 'IF Brommapojkarna',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/if-brommapojkarna/26',
#   'numeric_id': 26},
#  {'id': 'klubbar/sverige/bk-hacken/27',
#   'name': 'BK Häcken',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/bk-hacken/27',
#   'numeric_id': 27},
#  {'id': 'klubbar/sverige/gais/28',
#   'name': 'GAIS',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/gais/28',
#   'numeric_id': 28},
#  {'id': 'klubbar/sverige/helsingborgs-if/29',
#   'name': 'Helsingborgs IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/helsingborgs-if/29',
#   'numeric_id': 29},
#  {'id': 'klubbar/sverige/kalmar-ff/30',
#   'name': 'Kalmar FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/kalmar-ff/30',
#   'numeric_id': 30},
#  {'id': 'klubbar/sverige/malmo-ff/31',
#   'name': 'Malmö FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/malmo-ff/31',
#   'numeric_id': 31},
#  {'id': 'klubbar/sverige/mjallby-aif/32',
#   'name': 'Mjällby AIF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/mjallby-aif/32',
#   'numeric_id': 32},
#  {'id': 'klubbar/sverige/trelleborgs-ff/33',
#   'name': 'Trelleborgs FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/trelleborgs-ff/33',
#   'numeric_id': 33},
#  {'id': 'klubbar/sverige/orebro-sk/34',
#   'name': 'Örebro SK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/orebro-sk/34',
#   'numeric_id': 34},
#  {'id': 'klubbar/sverige/atvidabergs-ff/35',
#   'name': 'Åtvidabergs FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/atvidabergs-ff/35',
#   'numeric_id': 35},
#  {'id': 'klubbar/sverige/degerfors-if/36',
#   'name': 'Degerfors IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/degerfors-if/36',
#   'numeric_id': 36},
#  {'id': 'klubbar/sverige/falkenbergs-ff/37',
#   'name': 'Falkenbergs FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/falkenbergs-ff/37',
#   'numeric_id': 37},
#  {'id': 'klubbar/sverige/fc-trollhattan/38',
#   'name': 'FC Trollhättan',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/fc-trollhattan/38',
#   'numeric_id': 38},
#  {'id': 'klubbar/sverige/gif-sundsvall/39',
#   'name': 'GIF Sundsvall',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/gif-sundsvall/39',
#   'numeric_id': 39},
#  {'id': 'klubbar/sverige/ifk-norrkoping/40',
#   'name': 'IFK Norrköping',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ifk-norrkoping/40',
#   'numeric_id': 40},
#  {'id': 'klubbar/sverige/ik-brage/41',
#   'name': 'IK Brage',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ik-brage/41',
#   'numeric_id': 41},
#  {'id': 'klubbar/sverige/jonkopings-sodra-if/42',
#   'name': 'Jönköpings Södra IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/jonkopings-sodra-if/42',
#   'numeric_id': 42},
#  {'id': 'klubbar/sverige/ljungskile-sk/43',
#   'name': 'Ljungskile SK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ljungskile-sk/43',
#   'numeric_id': 43},
#  {'id': 'klubbar/sverige/vasby-united/44',
#   'name': 'Väsby United',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/vasby-united/44',
#   'numeric_id': 44},
#  {'id': 'klubbar/sverige/angelholms-ff/45',
#   'name': 'Ängelholms FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/angelholms-ff/45',
#   'numeric_id': 45},
#  {'id': 'klubbar/sverige/orgryte-is/46',
#   'name': 'Örgryte IS',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/orgryte-is/46',
#   'numeric_id': 46},
#  {'id': 'klubbar/sverige/landskrona-bois/47',
#   'name': 'Landskrona BoIS',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/landskrona-bois/47',
#   'numeric_id': 47},
#  {'id': 'klubbar/sverige/arameisksyrianska-if/48',
#   'name': 'Arameisk-Syrianska IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/arameisksyrianska-if/48',
#   'numeric_id': 48},
#  {'id': 'klubbar/sverige/bk-forward/49',
#   'name': 'BK Forward',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/bk-forward/49',
#   'numeric_id': 49},
#  {'id': 'klubbar/sverige/bodens-bk-ff/50',
#   'name': 'Bodens BK FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/bodens-bk-ff/50',
#   'numeric_id': 50},
#  {'id': 'klubbar/sverige/carlstad-united/51',
#   'name': 'Carlstad United',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/carlstad-united/51',
#   'numeric_id': 51},
#  {'id': 'klubbar/sverige/dalkurd-ff/52',
#   'name': 'Dalkurd FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/dalkurd-ff/52',
#   'numeric_id': 52},
#  {'id': 'klubbar/sverige/grondals-ik/53',
#   'name': 'Gröndals IK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/grondals-ik/53',
#   'numeric_id': 53},
#  {'id': 'klubbar/sverige/hammarby-tff/54',
#   'name': 'Hammarby TFF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/hammarby-tff/54',
#   'numeric_id': 54},
#  {'id': 'klubbar/sverige/ik-sirius/55',
#   'name': 'IK Sirius',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ik-sirius/55',
#   'numeric_id': 55},
#  {'id': 'klubbar/sverige/syrianska-if-kerburan/56',
#   'name': 'Syrianska IF Kerburan',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/syrianska-if-kerburan/56',
#   'numeric_id': 56},
#  {'id': 'klubbar/sverige/umea-fc/57',
#   'name': 'Umeå FC',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/umea-fc/57',
#   'numeric_id': 57},
#  {'id': 'klubbar/sverige/valsta-syrianska-ik/58',
#   'name': 'Valsta Syrianska IK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/valsta-syrianska-ik/58',
#   'numeric_id': 58},
#  {'id': 'klubbar/sverige/vasalund-if/59',
#   'name': 'Vasalund IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/vasalund-if/59',
#   'numeric_id': 59},
#  {'id': 'klubbar/sverige/vasteras-sk/60',
#   'name': 'Västerås SK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/vasteras-sk/60',
#   'numeric_id': 60},
#  {'id': 'klubbar/sverige/ostersunds-fk/61',
#   'name': 'Östersunds FK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ostersunds-fk/61',
#   'numeric_id': 61},
#  {'id': 'klubbar/sverige/lb07/62',
#   'name': 'LB07',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/lb07/62',
#   'numeric_id': 62},
#  {'id': 'klubbar/sverige/fc-rosengard/63',
#   'name': 'FC Rosengård',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/fc-rosengard/63',
#   'numeric_id': 63},
#  {'id': 'klubbar/sverige/husqvarna-ff/64',
#   'name': 'Husqvarna FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/husqvarna-ff/64',
#   'numeric_id': 64},
#  {'id': 'klubbar/sverige/if-sylvia/65',
#   'name': 'IF Sylvia',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/if-sylvia/65',
#   'numeric_id': 65},
#  {'id': 'klubbar/sverige/ifk-varnamo/66',
#   'name': 'IFK Värnamo',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ifk-varnamo/66',
#   'numeric_id': 66},
#  {'id': 'klubbar/sverige/ik-sleipner/67',
#   'name': 'IK Sleipner',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ik-sleipner/67',
#   'numeric_id': 67},
#  {'id': 'klubbar/sverige/kristianstads-ff/68',
#   'name': 'Kristianstads FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/kristianstads-ff/68',
#   'numeric_id': 68},
#  {'id': 'klubbar/sverige/lunds-bk/69',
#   'name': 'Lunds BK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/lunds-bk/69',
#   'numeric_id': 69},
#  {'id': 'klubbar/sverige/norrby-if/70',
#   'name': 'Norrby IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/norrby-if/70',
#   'numeric_id': 70},
#  {'id': 'klubbar/sverige/qviding-fif/71',
#   'name': 'Qviding FIF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/qviding-fif/71',
#   'numeric_id': 71},
#  {'id': 'klubbar/sverige/skovde-aik/72',
#   'name': 'Skövde AIK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/skovde-aik/72',
#   'numeric_id': 72},
#  {'id': 'klubbar/sverige/torslanda-ik/73',
#   'name': 'Torslanda IK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/torslanda-ik/73',
#   'numeric_id': 73},
#  {'id': 'klubbar/sverige/vastra-frolunda-if/74',
#   'name': 'Västra Frölunda IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/vastra-frolunda-if/74',
#   'numeric_id': 74},
#  {'id': 'klubbar/sverige/ytterby-is/75',
#   'name': 'Ytterby IS',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ytterby-is/75',
#   'numeric_id': 75},
#  {'id': 'klubbar/italien/fc-inter/76',
#   'name': 'FC Inter',
#   'url': 'https://fotbolltransfers.com/klubbar/italien/fc-inter/76',
#   'numeric_id': 76},
#  {'id': 'klubbar/italien/ac-milan/77',
#   'name': 'AC Milan',
#   'url': 'https://fotbolltransfers.com/klubbar/italien/ac-milan/77',
#   'numeric_id': 77},
#  {'id': 'klubbar/italien/juventus-fc/78',
#   'name': 'Juventus FC',
#   'url': 'https://fotbolltransfers.com/klubbar/italien/juventus-fc/78',
#   'numeric_id': 78},
#  {'id': 'klubbar/italien/as-roma/79',
#   'name': 'AS Roma',
#   'url': 'https://fotbolltransfers.com/klubbar/italien/as-roma/79',
#   'numeric_id': 79},
#  {'id': 'klubbar/italien/acf-fiorentina/80',
#   'name': 'ACF Fiorentina',
#   'url': 'https://fotbolltransfers.com/klubbar/italien/acf-fiorentina/80',
#   'numeric_id': 80},
#  {'id': 'klubbar/england/manchester-united/81',
#   'name': 'Manchester United',
#   'url': 'https://fotbolltransfers.com/klubbar/england/manchester-united/81',
#   'numeric_id': 81},
#  {'id': 'klubbar/england/liverpool-fc/82',
#   'name': 'Liverpool FC',
#   'url': 'https://fotbolltransfers.com/klubbar/england/liverpool-fc/82',
#   'numeric_id': 82},
#  {'id': 'klubbar/england/arsenal-fc/83',
#   'name': 'Arsenal FC',
#   'url': 'https://fotbolltransfers.com/klubbar/england/arsenal-fc/83',
#   'numeric_id': 83},
#  {'id': 'klubbar/england/chelsea-fc/84',
#   'name': 'Chelsea FC',
#   'url': 'https://fotbolltransfers.com/klubbar/england/chelsea-fc/84',
#   'numeric_id': 84},
#  {'id': 'klubbar/spanien/fc-barcelona/85',
#   'name': 'FC Barcelona',
#   'url': 'https://fotbolltransfers.com/klubbar/spanien/fc-barcelona/85',
#   'numeric_id': 85},
#  {'id': 'klubbar/spanien/real-madrid/86',
#   'name': 'Real Madrid',
#   'url': 'https://fotbolltransfers.com/klubbar/spanien/real-madrid/86',
#   'numeric_id': 86},
#  {'id': 'klubbar/spanien/valencia-cf/87',
#   'name': 'Valencia CF',
#   'url': 'https://fotbolltransfers.com/klubbar/spanien/valencia-cf/87',
#   'numeric_id': 87},
#  {'id': 'klubbar/spanien/sevilla-fc/88',
#   'name': 'Sevilla FC',
#   'url': 'https://fotbolltransfers.com/klubbar/spanien/sevilla-fc/88',
#   'numeric_id': 88},
#  {'id': 'klubbar/holland/afc-ajax/89',
#   'name': 'AFC Ajax',
#   'url': 'https://fotbolltransfers.com/klubbar/holland/afc-ajax/89',
#   'numeric_id': 89},
#  {'id': 'klubbar/tyskland/bayer-leverkusen/90',
#   'name': 'Bayer Leverkusen',
#   'url': 'https://fotbolltransfers.com/klubbar/tyskland/bayer-leverkusen/90',
#   'numeric_id': 90},
#  {'id': 'klubbar/tyskland/bayern-munchen/91',
#   'name': 'Bayern München',
#   'url': 'https://fotbolltransfers.com/klubbar/tyskland/bayern-munchen/91',
#   'numeric_id': 91},
#  {'id': 'klubbar/tyskland/fc-schalke-04/92',
#   'name': 'FC Schalke 04',
#   'url': 'https://fotbolltransfers.com/klubbar/tyskland/fc-schalke-04/92',
#   'numeric_id': 92},
#  {'id': 'klubbar/tyskland/hamburger-sv/93',
#   'name': 'Hamburger SV',
#   'url': 'https://fotbolltransfers.com/klubbar/tyskland/hamburger-sv/93',
#   'numeric_id': 93},
#  {'id': 'klubbar/tyskland/borussia-dortmund/94',
#   'name': 'Borussia Dortmund',
#   'url': 'https://fotbolltransfers.com/klubbar/tyskland/borussia-dortmund/94',
#   'numeric_id': 94},
#  {'id': 'klubbar/tyskland/werder-bremen/95',
#   'name': 'Werder Bremen',
#   'url': 'https://fotbolltransfers.com/klubbar/tyskland/werder-bremen/95',
#   'numeric_id': 95},
#  {'id': 'klubbar/tyskland/vfl-wolfsburg/96',
#   'name': 'VfL Wolfsburg',
#   'url': 'https://fotbolltransfers.com/klubbar/tyskland/vfl-wolfsburg/96',
#   'numeric_id': 96},
#  {'id': 'klubbar/italien/parma-calcio-1913/97',
#   'name': 'Parma Calcio 1913',
#   'url': 'https://fotbolltransfers.com/klubbar/italien/parma-calcio-1913/97',
#   'numeric_id': 97},
#  {'id': 'klubbar/tyskland/vfb-stuttgart/98',
#   'name': 'VfB Stuttgart',
#   'url': 'https://fotbolltransfers.com/klubbar/tyskland/vfb-stuttgart/98',
#   'numeric_id': 98},
#  {'id': 'klubbar/italien/ssc-napoli/99',
#   'name': 'SSC Napoli',
#   'url': 'https://fotbolltransfers.com/klubbar/italien/ssc-napoli/99',
#   'numeric_id': 99},
#  {'id': 'klubbar/italien/palermo-fc/100',
#   'name': 'Palermo FC',
#   'url': 'https://fotbolltransfers.com/klubbar/italien/palermo-fc/100',
#   'numeric_id': 100},
#  {'id': 'klubbar/italien/uc-sampdoria/101',
#   'name': 'UC Sampdoria',
#   'url': 'https://fotbolltransfers.com/klubbar/italien/uc-sampdoria/101',
#   'numeric_id': 101},
#  {'id': 'klubbar/ovriga-europa/as-bari/102',
#   'name': 'AS Bari',
#   'url': 'https://fotbolltransfers.com/klubbar/ovriga-europa/as-bari/102',
#   'numeric_id': 102},
#  {'id': 'klubbar/italien/genoa-cfc/103',
#   'name': 'Genoa CFC',
#   'url': 'https://fotbolltransfers.com/klubbar/italien/genoa-cfc/103',
#   'numeric_id': 103},
#  {'id': 'klubbar/ovriga-europa/ac-chievo/104',
#   'name': 'AC Chievo',
#   'url': 'https://fotbolltransfers.com/klubbar/ovriga-europa/ac-chievo/104',
#   'numeric_id': 104},
#  {'id': 'klubbar/italien/cagliari-calcio/105',
#   'name': 'Cagliari Calcio',
#   'url': 'https://fotbolltransfers.com/klubbar/italien/cagliari-calcio/105',
#   'numeric_id': 105},
#  {'id': 'klubbar/italien/udinese-calcio/106',
#   'name': 'Udinese Calcio',
#   'url': 'https://fotbolltransfers.com/klubbar/italien/udinese-calcio/106',
#   'numeric_id': 106},
#  {'id': 'klubbar/italien/bologna-fc/107',
#   'name': 'Bologna FC',
#   'url': 'https://fotbolltransfers.com/klubbar/italien/bologna-fc/107',
#   'numeric_id': 107},
#  {'id': 'klubbar/ovriga-europa/as-livorno/108',
#   'name': 'AS Livorno',
#   'url': 'https://fotbolltransfers.com/klubbar/ovriga-europa/as-livorno/108',
#   'numeric_id': 108},
#  {'id': 'klubbar/italien/ss-lazio/109',
#   'name': 'SS Lazio',
#   'url': 'https://fotbolltransfers.com/klubbar/italien/ss-lazio/109',
#   'numeric_id': 109},
#  {'id': 'klubbar/italien/atalanta-bc/110',
#   'name': 'Atalanta BC',
#   'url': 'https://fotbolltransfers.com/klubbar/italien/atalanta-bc/110',
#   'numeric_id': 110},
#  {'id': 'klubbar/ovriga-europa/catania-fc/111',
#   'name': 'Catania FC',
#   'url': 'https://fotbolltransfers.com/klubbar/ovriga-europa/catania-fc/111',
#   'numeric_id': 111},
#  {'id': 'klubbar/ovriga-europa/ac-siena/112',
#   'name': 'AC Siena',
#   'url': 'https://fotbolltransfers.com/klubbar/ovriga-europa/ac-siena/112',
#   'numeric_id': 112},
#  {'id': 'klubbar/spanien/rcd-mallorca/113',
#   'name': 'RCD Mallorca',
#   'url': 'https://fotbolltransfers.com/klubbar/spanien/rcd-mallorca/113',
#   'numeric_id': 113},
#  {'id': 'klubbar/spanien/deportivo-la-coruna/114',
#   'name': 'Deportivo La Coruna',
#   'url': 'https://fotbolltransfers.com/klubbar/spanien/deportivo-la-coruna/114',
#   'numeric_id': 114},
#  {'id': 'klubbar/spanien/athletic-bilbao/115',
#   'name': 'Athletic Bilbao',
#   'url': 'https://fotbolltransfers.com/klubbar/spanien/athletic-bilbao/115',
#   'numeric_id': 115},
#  {'id': 'klubbar/spanien/getafe-cf/116',
#   'name': 'Getafe CF',
#   'url': 'https://fotbolltransfers.com/klubbar/spanien/getafe-cf/116',
#   'numeric_id': 116},
#  {'id': 'klubbar/spanien/villarreal-cf/117',
#   'name': 'Villarreal CF',
#   'url': 'https://fotbolltransfers.com/klubbar/spanien/villarreal-cf/117',
#   'numeric_id': 117},
#  {'id': 'klubbar/spanien/sporting-gijon/118',
#   'name': 'Sporting Gijón',
#   'url': 'https://fotbolltransfers.com/klubbar/spanien/sporting-gijon/118',
#   'numeric_id': 118},
#  {'id': 'klubbar/spanien/real-valladolid/119',
#   'name': 'Real Valladolid',
#   'url': 'https://fotbolltransfers.com/klubbar/spanien/real-valladolid/119',
#   'numeric_id': 119},
#  {'id': 'klubbar/spanien/ca-osasuna/120',
#   'name': 'CA Osasuna',
#   'url': 'https://fotbolltransfers.com/klubbar/spanien/ca-osasuna/120',
#   'numeric_id': 120},
#  {'id': 'klubbar/spanien/rcd-espanyol/121',
#   'name': 'RCD Espanyol',
#   'url': 'https://fotbolltransfers.com/klubbar/spanien/rcd-espanyol/121',
#   'numeric_id': 121},
#  {'id': 'klubbar/ovriga-europa/cd-tenerife/122',
#   'name': 'CD Tenerife',
#   'url': 'https://fotbolltransfers.com/klubbar/ovriga-europa/cd-tenerife/122',
#   'numeric_id': 122},
#  {'id': 'klubbar/spanien/atletico-madrid/123',
#   'name': 'Atlético Madrid',
#   'url': 'https://fotbolltransfers.com/klubbar/spanien/atletico-madrid/123',
#   'numeric_id': 123},
#  {'id': 'klubbar/ovriga-europa/racing-santander/124',
#   'name': 'Racing Santander',
#   'url': 'https://fotbolltransfers.com/klubbar/ovriga-europa/racing-santander/124',
#   'numeric_id': 124},
#  {'id': 'klubbar/spanien/ud-almeria/125',
#   'name': 'UD Almeria',
#   'url': 'https://fotbolltransfers.com/klubbar/spanien/ud-almeria/125',
#   'numeric_id': 125},
#  {'id': 'klubbar/spanien/malaga-cf/126',
#   'name': 'Malaga CF',
#   'url': 'https://fotbolltransfers.com/klubbar/spanien/malaga-cf/126',
#   'numeric_id': 126},
#  {'id': 'klubbar/spanien/real-zaragoza/127',
#   'name': 'Real Zaragoza',
#   'url': 'https://fotbolltransfers.com/klubbar/spanien/real-zaragoza/127',
#   'numeric_id': 127},
#  {'id': 'klubbar/ovriga-europa/xerez--cd/128',
#   'name': 'Xerez  CD',
#   'url': 'https://fotbolltransfers.com/klubbar/ovriga-europa/xerez--cd/128',
#   'numeric_id': 128},
#  {'id': 'klubbar/england/tottenham-hotspur/129',
#   'name': 'Tottenham Hotspur',
#   'url': 'https://fotbolltransfers.com/klubbar/england/tottenham-hotspur/129',
#   'numeric_id': 129},
#  {'id': 'klubbar/england/aston-villa/130',
#   'name': 'Aston Villa',
#   'url': 'https://fotbolltransfers.com/klubbar/england/aston-villa/130',
#   'numeric_id': 130},
#  {'id': 'klubbar/england/portsmouth-fc/131',
#   'name': 'Portsmouth FC',
#   'url': 'https://fotbolltransfers.com/klubbar/england/portsmouth-fc/131',
#   'numeric_id': 131},
#  {'id': 'klubbar/england/manchester-city/132',
#   'name': 'Manchester City',
#   'url': 'https://fotbolltransfers.com/klubbar/england/manchester-city/132',
#   'numeric_id': 132},
#  {'id': 'klubbar/england/birmingham-city/133',
#   'name': 'Birmingham City',
#   'url': 'https://fotbolltransfers.com/klubbar/england/birmingham-city/133',
#   'numeric_id': 133},
#  {'id': 'klubbar/england/fulham-fc/134',
#   'name': 'Fulham FC',
#   'url': 'https://fotbolltransfers.com/klubbar/england/fulham-fc/134',
#   'numeric_id': 134},
#  {'id': 'klubbar/england/sunderland-afc/135',
#   'name': 'Sunderland AFC',
#   'url': 'https://fotbolltransfers.com/klubbar/england/sunderland-afc/135',
#   'numeric_id': 135},
#  {'id': 'klubbar/england/everton-fc/136',
#   'name': 'Everton FC',
#   'url': 'https://fotbolltransfers.com/klubbar/england/everton-fc/136',
#   'numeric_id': 136},
#  {'id': 'klubbar/england/stoke-city/137',
#   'name': 'Stoke City',
#   'url': 'https://fotbolltransfers.com/klubbar/england/stoke-city/137',
#   'numeric_id': 137},
#  {'id': 'klubbar/england/blackburn-rovers/138',
#   'name': 'Blackburn Rovers',
#   'url': 'https://fotbolltransfers.com/klubbar/england/blackburn-rovers/138',
#   'numeric_id': 138},
#  {'id': 'klubbar/england/burnley-fc/139',
#   'name': 'Burnley FC',
#   'url': 'https://fotbolltransfers.com/klubbar/england/burnley-fc/139',
#   'numeric_id': 139},
#  {'id': 'klubbar/england/wolverhampton-wfc/140',
#   'name': 'Wolverhampton WFC',
#   'url': 'https://fotbolltransfers.com/klubbar/england/wolverhampton-wfc/140',
#   'numeric_id': 140},
#  {'id': 'klubbar/ovriga-europa/wigan-athletic/141',
#   'name': 'Wigan Athletic',
#   'url': 'https://fotbolltransfers.com/klubbar/ovriga-europa/wigan-athletic/141',
#   'numeric_id': 141},
#  {'id': 'klubbar/england/west-ham-united/142',
#   'name': 'West Ham United',
#   'url': 'https://fotbolltransfers.com/klubbar/england/west-ham-united/142',
#   'numeric_id': 142},
#  {'id': 'klubbar/ovriga-europa/bolton-wanderers/143',
#   'name': 'Bolton Wanderers',
#   'url': 'https://fotbolltransfers.com/klubbar/ovriga-europa/bolton-wanderers/143',
#   'numeric_id': 143},
#  {'id': 'klubbar/england/hull-city/144',
#   'name': 'Hull City',
#   'url': 'https://fotbolltransfers.com/klubbar/england/hull-city/144',
#   'numeric_id': 144},
#  {'id': 'klubbar/holland/psv-eindhoven/145',
#   'name': 'PSV Eindhoven',
#   'url': 'https://fotbolltransfers.com/klubbar/holland/psv-eindhoven/145',
#   'numeric_id': 145},
#  {'id': 'klubbar/ovriga-europa/fc-girondins-bordeaux/146',
#   'name': 'FC Girondins Bordeaux',
#   'url': 'https://fotbolltransfers.com/klubbar/ovriga-europa/fc-girondins-bordeaux/146',
#   'numeric_id': 146},
#  {'id': 'klubbar/frankrike/olympique-marseille/147',
#   'name': 'Olympique Marseille',
#   'url': 'https://fotbolltransfers.com/klubbar/frankrike/olympique-marseille/147',
#   'numeric_id': 147},
#  {'id': 'klubbar/frankrike/olympique-lyon/148',
#   'name': 'Olympique Lyon',
#   'url': 'https://fotbolltransfers.com/klubbar/frankrike/olympique-lyon/148',
#   'numeric_id': 148},
#  {'id': 'klubbar/frankrike/paris-saintgermain/149',
#   'name': 'Paris Saint-Germain',
#   'url': 'https://fotbolltransfers.com/klubbar/frankrike/paris-saintgermain/149',
#   'numeric_id': 149},
#  {'id': 'klubbar/frankrike/as-monaco/150',
#   'name': 'AS Monaco',
#   'url': 'https://fotbolltransfers.com/klubbar/frankrike/as-monaco/150',
#   'numeric_id': 150},
#  {'id': 'klubbar/frankrike/lille-osc/151',
#   'name': 'Lille OSC',
#   'url': 'https://fotbolltransfers.com/klubbar/frankrike/lille-osc/151',
#   'numeric_id': 151},
#  {'id': 'spelare/utlandsproffs/frankrike/152',
#   'name': 'Svenska spelare i Frankrike',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/frankrike/152',
#   'numeric_id': 152},
#  {'id': 'spelare/utlandsproffs/usa/153',
#   'name': 'Svenska spelare i USA',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/usa/153',
#   'numeric_id': 153},
#  {'id': 'spelare/utlandsproffs/saudiarabien/154',
#   'name': 'Svenska spelare i Saudiarabien',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/saudiarabien/154',
#   'numeric_id': 154},
#  {'id': 'klubbar/sverige/kontraktslos/155',
#   'name': 'Kontraktslös',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/kontraktslos/155',
#   'numeric_id': 155},
#  {'id': 'klubbar/danmark/brondby-if/157',
#   'name': 'Bröndby IF',
#   'url': 'https://fotbolltransfers.com/klubbar/danmark/brondby-if/157',
#   'numeric_id': 157},
#  {'id': 'klubbar/danmark/fc-kopenhamn/159',
#   'name': 'FC Köpenhamn',
#   'url': 'https://fotbolltransfers.com/klubbar/danmark/fc-kopenhamn/159',
#   'numeric_id': 159},
#  {'id': 'klubbar/norge/rosenborg-bk/160',
#   'name': 'Rosenborg BK',
#   'url': 'https://fotbolltransfers.com/klubbar/norge/rosenborg-bk/160',
#   'numeric_id': 160},
#  {'id': 'klubbar/ovriga-europa/tidigare-i-sverige/161',
#   'name': 'Tidigare i Sverige',
#   'url': 'https://fotbolltransfers.com/klubbar/ovriga-europa/tidigare-i-sverige/161',
#   'numeric_id': 161},
#  {'id': 'spelare/utlandsproffs/oman/162',
#   'name': 'Svenska spelare i Oman',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/oman/162',
#   'numeric_id': 162},
#  {'id': 'spelare/utlandsproffs/finland/163',
#   'name': 'Svenska spelare i Finland',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/finland/163',
#   'numeric_id': 163},
#  {'id': 'spelare/utlandsproffs/singapore/164',
#   'name': 'Svenska spelare i Singapore',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/singapore/164',
#   'numeric_id': 164},
#  {'id': 'klubbar/england/newcastle-united/165',
#   'name': 'Newcastle United',
#   'url': 'https://fotbolltransfers.com/klubbar/england/newcastle-united/165',
#   'numeric_id': 165},
#  {'id': 'spelare/utlandsproffs/cypern/166',
#   'name': 'Svenska spelare på Cypern',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/cypern/166',
#   'numeric_id': 166},
#  {'id': 'spelare/utlandsproffs/belgien/167',
#   'name': 'Svenska spelare i Belgien',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/belgien/167',
#   'numeric_id': 167},
#  {'id': 'spelare/utlandsproffs/portugal/168',
#   'name': 'Svenska spelare i Portugal',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/portugal/168',
#   'numeric_id': 168},
#  {'id': 'spelare/utlandsproffs/skottland/169',
#   'name': 'Svenska spelare i Skottland',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/skottland/169',
#   'numeric_id': 169},
#  {'id': 'spelare/utlandsproffs/ungern/202',
#   'name': 'Svenska spelare i Ungern',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/ungern/202',
#   'numeric_id': 202},
#  {'id': 'spelare/utlandsproffs/thailand/204',
#   'name': 'Svenska spelare i Thailand',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/thailand/204',
#   'numeric_id': 204},
#  {'id': 'spelare/utlandsproffs/island/205',
#   'name': 'Svenska spelare på Island',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/island/205',
#   'numeric_id': 205},
#  {'id': 'spelare/utlandsproffs/syrien/206',
#   'name': 'Svenska spelare i Syrien',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/syrien/206',
#   'numeric_id': 206},
#  {'id': 'spelare/utlandsproffs/kroatien/207',
#   'name': 'Svenska spelare i Kroatien',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/kroatien/207',
#   'numeric_id': 207},
#  {'id': 'spelare/utlandsproffs/algeriet/209',
#   'name': 'Svenska spelare i Algeriet',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/algeriet/209',
#   'numeric_id': 209},
#  {'id': 'klubbar/sverige/akropolis-if/210',
#   'name': 'Akropolis IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/akropolis-if/210',
#   'numeric_id': 210},
#  {'id': 'klubbar/sverige/ik-frej-taby/211',
#   'name': 'IK Frej Täby',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ik-frej-taby/211',
#   'numeric_id': 211},
#  {'id': 'klubbar/sverige/ifk-lulea/212',
#   'name': 'IFK Luleå',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ifk-lulea/212',
#   'numeric_id': 212},
#  {'id': 'klubbar/sverige/motala-aif-fk/213',
#   'name': 'Motala AIF FK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/motala-aif-fk/213',
#   'numeric_id': 213},
#  {'id': 'klubbar/sverige/varbergs-bois/214',
#   'name': 'Varbergs BoIS',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/varbergs-bois/214',
#   'numeric_id': 214},
#  {'id': 'klubbar/sverige/ik-oddevold/215',
#   'name': 'IK Oddevold',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ik-oddevold/215',
#   'numeric_id': 215},
#  {'id': 'klubbar/sverige/karlstad-bk/216',
#   'name': 'Karlstad BK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/karlstad-bk/216',
#   'numeric_id': 216},
#  {'id': 'spelare/utlandsproffs/azerbajdzjan/217',
#   'name': 'Svenska spelare i Azerbajdzjan',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/azerbajdzjan/217',
#   'numeric_id': 217},
#  {'id': 'klubbar/sverige/avslutat-karriaren/218',
#   'name': 'Avslutat karriären',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/avslutat-karriaren/218',
#   'numeric_id': 218},
#  {'id': 'klubbar/ovriga-europa/avslutat-karriaren-internationellt/219',
#   'name': 'Avslutat karriären (Internationellt)',
#   'url': 'https://fotbolltransfers.com/klubbar/ovriga-europa/avslutat-karriaren-internationellt/219',
#   'numeric_id': 219},
#  {'id': 'klubbar/sverige/ovriga-sverige/220',
#   'name': 'Övriga Sverige',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ovriga-sverige/220',
#   'numeric_id': 220},
#  {'id': 'klubbar/ovriga-europa/ovriga-europa/221',
#   'name': 'Övriga Europa',
#   'url': 'https://fotbolltransfers.com/klubbar/ovriga-europa/ovriga-europa/221',
#   'numeric_id': 221},
#  {'id': 'spelare/utlandsproffs/serbien/222',
#   'name': 'Svenska spelare i Serbien',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/serbien/222',
#   'numeric_id': 222},
#  {'id': 'spelare/utlandsproffs/iran/223',
#   'name': 'Svenska spelare i Iran',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/iran/223',
#   'numeric_id': 223},
#  {'id': 'spelare/utlandsproffs/bulgarien/224',
#   'name': 'Svenska spelare i Bulgarien',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/bulgarien/224',
#   'numeric_id': 224},
#  {'id': 'spelare/utlandsproffs/japan/225',
#   'name': 'Svenska spelare i Japan',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/japan/225',
#   'numeric_id': 225},
#  {'id': 'spelare/utlandsproffs/qatar/226',
#   'name': 'Svenska spelare i Qatar',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/qatar/226',
#   'numeric_id': 226},
#  {'id': 'spelare/utlandsproffs/rumanien/227',
#   'name': 'Svenska spelare i Rumänien',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/rumanien/227',
#   'numeric_id': 227},
#  {'id': 'klubbar/varlden/brasilien/228',
#   'name': 'Brasilien',
#   'url': 'https://fotbolltransfers.com/klubbar/varlden/brasilien/228',
#   'numeric_id': 228},
#  {'id': 'klubbar/varlden/argentina/229',
#   'name': 'Argentina',
#   'url': 'https://fotbolltransfers.com/klubbar/varlden/argentina/229',
#   'numeric_id': 229},
#  {'id': 'klubbar/varlden/usa/230',
#   'name': 'USA',
#   'url': 'https://fotbolltransfers.com/klubbar/varlden/usa/230',
#   'numeric_id': 230},
#  {'id': 'klubbar/sverige/sandvikens-if/231',
#   'name': 'Sandvikens IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/sandvikens-if/231',
#   'numeric_id': 231},
#  {'id': 'klubbar/sverige/enkopings-sk-fk/232',
#   'name': 'Enköpings SK FK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/enkopings-sk-fk/232',
#   'numeric_id': 232},
#  {'id': 'klubbar/sverige/eskilstuna-city/233',
#   'name': 'Eskilstuna City',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/eskilstuna-city/233',
#   'numeric_id': 233},
#  {'id': 'klubbar/sverige/utsiktens-bk/234',
#   'name': 'Utsiktens BK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/utsiktens-bk/234',
#   'numeric_id': 234},
#  {'id': 'klubbar/sverige/ik-gauthiod/235',
#   'name': 'IK Gauthiod',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ik-gauthiod/235',
#   'numeric_id': 235},
#  {'id': 'spelare/utlandsproffs/forenade-arabemiraten/236',
#   'name': 'Svenska spelare i Förenade Arabemiraten',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/forenade-arabemiraten/236',
#   'numeric_id': 236},
#  {'id': 'spelare/utlandsproffs/kina/237',
#   'name': 'Svenska spelare i Kina',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/kina/237',
#   'numeric_id': 237},
#  {'id': 'spelare/utlandsproffs/moldavien/238',
#   'name': 'Svenska spelare i Moldavien',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/moldavien/238',
#   'numeric_id': 238},
#  {'id': 'klubbar/portugal/fc-porto/239',
#   'name': 'FC Porto',
#   'url': 'https://fotbolltransfers.com/klubbar/portugal/fc-porto/239',
#   'numeric_id': 239},
#  {'id': 'klubbar/varlden/kina/240',
#   'name': 'Kina',
#   'url': 'https://fotbolltransfers.com/klubbar/varlden/kina/240',
#   'numeric_id': 240},
#  {'id': 'spelare/utlandsproffs/malta/241',
#   'name': 'Svenska spelare på Malta',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/malta/241',
#   'numeric_id': 241},
#  {'id': 'spelare/utlandsproffs/ukraina/242',
#   'name': 'Svenska spelare i Ukraina',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/ukraina/242',
#   'numeric_id': 242},
#  {'id': 'spelare/utlandsproffs/irland/243',
#   'name': 'Svenska spelare på Irland',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/irland/243',
#   'numeric_id': 243},
#  {'id': 'spelare/utlandsproffs/kuwait/244',
#   'name': 'Svenska spelare i Kuwait',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/kuwait/244',
#   'numeric_id': 244},
#  {'id': 'spelare/utlandsproffs/irak/245',
#   'name': 'Svenska spelare i Irak',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/irak/245',
#   'numeric_id': 245},
#  {'id': 'spelare/utlandsproffs/polen/246',
#   'name': 'Svenska spelare i Polen',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/polen/246',
#   'numeric_id': 246},
#  {'id': 'klubbar/sverige/afc-united/247',
#   'name': 'AFC United',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/afc-united/247',
#   'numeric_id': 247},
#  {'id': 'klubbar/sverige/is-halmia/248',
#   'name': 'IS Halmia',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/is-halmia/248',
#   'numeric_id': 248},
#  {'id': 'klubbar/sverige/nykopings-bis/249',
#   'name': 'Nyköpings BIS',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/nykopings-bis/249',
#   'numeric_id': 249},
#  {'id': 'klubbar/sverige/selanger-sk/250',
#   'name': 'Selånger SK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/selanger-sk/250',
#   'numeric_id': 250},
#  {'id': 'spelare/utlandsproffs/israel/252',
#   'name': 'Svenska spelare i Israel',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/israel/252',
#   'numeric_id': 252},
#  {'id': 'spelare/utlandsproffs/kosovo/253',
#   'name': 'Svenska spelare i Kosovo',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/kosovo/253',
#   'numeric_id': 253},
#  {'id': 'klubbar/england/southampton-fc/254',
#   'name': 'Southampton FC',
#   'url': 'https://fotbolltransfers.com/klubbar/england/southampton-fc/254',
#   'numeric_id': 254},
#  {'id': 'klubbar/sverige/ifk-uddevalla/255',
#   'name': 'IFK Uddevalla',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ifk-uddevalla/255',
#   'numeric_id': 255},
#  {'id': 'klubbar/sverige/skelleftea-ff/256',
#   'name': 'Skellefteå FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/skelleftea-ff/256',
#   'numeric_id': 256},
#  {'id': 'klubbar/sverige/oskarshamns-aik/257',
#   'name': 'Oskarshamns AIK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/oskarshamns-aik/257',
#   'numeric_id': 257},
#  {'id': 'klubbar/sverige/huddinge-if/258',
#   'name': 'Huddinge IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/huddinge-if/258',
#   'numeric_id': 258},
#  {'id': 'spelare/utlandsproffs/nicaragua/259',
#   'name': 'Svenska spelare i Nicaragua',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/nicaragua/259',
#   'numeric_id': 259},
#  {'id': 'klubbar/skottland/celtic-fc/260',
#   'name': 'Celtic FC',
#   'url': 'https://fotbolltransfers.com/klubbar/skottland/celtic-fc/260',
#   'numeric_id': 260},
#  {'id': 'klubbar/ovriga-europa/cardiff-city/261',
#   'name': 'Cardiff City',
#   'url': 'https://fotbolltransfers.com/klubbar/ovriga-europa/cardiff-city/261',
#   'numeric_id': 261},
#  {'id': 'klubbar/england/west-bromwich/262',
#   'name': 'West Bromwich',
#   'url': 'https://fotbolltransfers.com/klubbar/england/west-bromwich/262',
#   'numeric_id': 262},
#  {'id': 'klubbar/varlden/mexiko/263',
#   'name': 'Mexiko',
#   'url': 'https://fotbolltransfers.com/klubbar/varlden/mexiko/263',
#   'numeric_id': 263},
#  {'id': 'klubbar/italien/torino-fc/264',
#   'name': 'Torino FC',
#   'url': 'https://fotbolltransfers.com/klubbar/italien/torino-fc/264',
#   'numeric_id': 264},
#  {'id': 'klubbar/portugal/sl-benfica/265',
#   'name': 'SL Benfica',
#   'url': 'https://fotbolltransfers.com/klubbar/portugal/sl-benfica/265',
#   'numeric_id': 265},
#  {'id': 'spelare/utlandsproffs/indien/266',
#   'name': 'Svenska spelare i Indien',
#   'url': 'https://fotbolltransfers.com/spelare/utlandsproffs/indien/266',
#   'numeric_id': 266},
#  {'id': 'klubbar/sverige/eskilsminne-if/267',
#   'name': 'Eskilsminne IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/eskilsminne-if/267',
#   'numeric_id': 267},
#  {'id': 'klubbar/sverige/pitea-if/268',
#   'name': 'Piteå IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/pitea-if/268',
#   'numeric_id': 268},
#  {'id': 'klubbar/sverige/fc-hollviken/269',
#   'name': 'FC Höllviken',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/fc-hollviken/269',
#   'numeric_id': 269},
#  {'id': 'klubbar/sverige/sodertalje-fk/270',
#   'name': 'Södertälje FK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/sodertalje-fk/270',
#   'numeric_id': 270},
#  {'id': 'klubbar/sverige/hudiksvalls-ff/271',
#   'name': 'Hudiksvalls FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/hudiksvalls-ff/271',
#   'numeric_id': 271},
#  {'id': 'klubbar/varlden/chapecoense/272',
#   'name': 'Chapecoense',
#   'url': 'https://fotbolltransfers.com/klubbar/varlden/chapecoense/272',
#   'numeric_id': 272},
#  {'id': 'klubbar/sverige/anundsjo-if/273',
#   'name': 'Anundsjö IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/anundsjo-if/273',
#   'numeric_id': 273},
#  {'id': 'klubbar/sverige/ange-if/274',
#   'name': 'Ånge IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ange-if/274',
#   'numeric_id': 274},
#  {'id': 'klubbar/sverige/tegs-sk/275',
#   'name': 'Tegs SK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/tegs-sk/275',
#   'numeric_id': 275},
#  {'id': 'klubbar/sverige/ifk-ostersund/276',
#   'name': 'IFK Östersund',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ifk-ostersund/276',
#   'numeric_id': 276},
#  {'id': 'klubbar/sverige/harnosands-ff/277',
#   'name': 'Härnösands FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/harnosands-ff/277',
#   'numeric_id': 277},
#  {'id': 'klubbar/sverige/soderhamns-ff/278',
#   'name': 'Söderhamns FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/soderhamns-ff/278',
#   'numeric_id': 278},
#  {'id': 'klubbar/sverige/mariehem-sk/279',
#   'name': 'Mariehem SK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/mariehem-sk/279',
#   'numeric_id': 279},
#  {'id': 'klubbar/sverige/sandviks-ik/280',
#   'name': 'Sandviks IK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/sandviks-ik/280',
#   'numeric_id': 280},
#  {'id': 'klubbar/sverige/gamla-upsala-sk/281',
#   'name': 'Gamla Upsala SK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/gamla-upsala-sk/281',
#   'numeric_id': 281},
#  {'id': 'klubbar/sverige/sollentuna-ff/282',
#   'name': 'Sollentuna FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/sollentuna-ff/282',
#   'numeric_id': 282},
#  {'id': 'klubbar/sverige/bkv-norrtalje/283',
#   'name': 'BKV Norrtälje',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/bkv-norrtalje/283',
#   'numeric_id': 283},
#  {'id': 'klubbar/sverige/ifk-aspuddentellus/284',
#   'name': 'IFK Aspudden-Tellus',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ifk-aspuddentellus/284',
#   'numeric_id': 284},
#  {'id': 'klubbar/sverige/varmdo-if/285',
#   'name': 'Värmdö IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/varmdo-if/285',
#   'numeric_id': 285},
#  {'id': 'klubbar/sverige/skiljebo-sk/286',
#   'name': 'Skiljebo SK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/skiljebo-sk/286',
#   'numeric_id': 286},
#  {'id': 'klubbar/sverige/konyaspor-kif/287',
#   'name': 'Konyaspor KIF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/konyaspor-kif/287',
#   'numeric_id': 287},
#  {'id': 'klubbar/sverige/vasteras-ik/288',
#   'name': 'Västerås IK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/vasteras-ik/288',
#   'numeric_id': 288},
#  {'id': 'klubbar/sverige/kvarnsvedens-ik/289',
#   'name': 'Kvarnsvedens IK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/kvarnsvedens-ik/289',
#   'numeric_id': 289},
#  {'id': 'klubbar/sverige/stromsbergs-if/290',
#   'name': 'Strömsbergs IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/stromsbergs-if/290',
#   'numeric_id': 290},
#  {'id': 'klubbar/sverige/karlbergs-bk/291',
#   'name': 'Karlbergs BK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/karlbergs-bk/291',
#   'numeric_id': 291},
#  {'id': 'klubbar/sverige/sparvagens-ff/292',
#   'name': 'Spårvägens FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/sparvagens-ff/292',
#   'numeric_id': 292},
#  {'id': 'klubbar/sverige/enskede-ik/293',
#   'name': 'Enskede IK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/enskede-ik/293',
#   'numeric_id': 293},
#  {'id': 'klubbar/sverige/nacka-ff/294',
#   'name': 'Nacka FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/nacka-ff/294',
#   'numeric_id': 294},
#  {'id': 'klubbar/sverige/eskilstuna-city-fk/295',
#   'name': 'Eskilstuna City FK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/eskilstuna-city-fk/295',
#   'numeric_id': 295},
#  {'id': 'klubbar/sverige/ekero-ik/296',
#   'name': 'Ekerö IK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ekero-ik/296',
#   'numeric_id': 296},
#  {'id': 'klubbar/sverige/rynninge-ik/297',
#   'name': 'Rynninge IK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/rynninge-ik/297',
#   'numeric_id': 297},
#  {'id': 'klubbar/sverige/fc-linkoping-city/299',
#   'name': 'FC Linköping City',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/fc-linkoping-city/299',
#   'numeric_id': 299},
#  {'id': 'klubbar/sverige/karlslunds-if-fk/300',
#   'name': 'Karlslunds IF FK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/karlslunds-if-fk/300',
#   'numeric_id': 300},
#  {'id': 'klubbar/sverige/fc-gute/301',
#   'name': 'FC Gute',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/fc-gute/301',
#   'numeric_id': 301},
#  {'id': 'klubbar/sverige/smedby-ais/302',
#   'name': 'Smedby AIS',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/smedby-ais/302',
#   'numeric_id': 302},
#  {'id': 'klubbar/sverige/varmbols-fc/303',
#   'name': 'Värmbols FC',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/varmbols-fc/303',
#   'numeric_id': 303},
#  {'id': 'klubbar/sverige/karlskoga-ff/304',
#   'name': 'Karlskoga FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/karlskoga-ff/304',
#   'numeric_id': 304},
#  {'id': 'klubbar/sverige/nordvarmland-ff/305',
#   'name': 'Nordvärmland FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/nordvarmland-ff/305',
#   'numeric_id': 305},
#  {'id': 'klubbar/sverige/grebbestads-if/306',
#   'name': 'Grebbestads IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/grebbestads-if/306',
#   'numeric_id': 306},
#  {'id': 'klubbar/sverige/larjeangereds-if/307',
#   'name': 'Lärje-Angereds IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/larjeangereds-if/307',
#   'numeric_id': 307},
#  {'id': 'klubbar/sverige/lidkopings-fk/308',
#   'name': 'Lidköpings FK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/lidkopings-fk/308',
#   'numeric_id': 308},
#  {'id': 'klubbar/sverige/tibro-aik-fk/309',
#   'name': 'Tibro AIK FK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/tibro-aik-fk/309',
#   'numeric_id': 309},
#  {'id': 'klubbar/sverige/stenungsunds-if/310',
#   'name': 'Stenungsunds IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/stenungsunds-if/310',
#   'numeric_id': 310},
#  {'id': 'klubbar/sverige/ifk-amal/311',
#   'name': 'IFK Åmål',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ifk-amal/311',
#   'numeric_id': 311},
#  {'id': 'klubbar/sverige/ifk-olme/312',
#   'name': 'IFK Ölme',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ifk-olme/312',
#   'numeric_id': 312},
#  {'id': 'klubbar/sverige/lerums-is/313',
#   'name': 'Lerums IS',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/lerums-is/313',
#   'numeric_id': 313},
#  {'id': 'klubbar/sverige/fk-karlskrona/314',
#   'name': 'FK Karlskrona',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/fk-karlskrona/314',
#   'numeric_id': 314},
#  {'id': 'klubbar/sverige/ifk-berga/315',
#   'name': 'IFK Berga',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ifk-berga/315',
#   'numeric_id': 315},
#  {'id': 'klubbar/sverige/vimmerby-if/316',
#   'name': 'Vimmerby IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/vimmerby-if/316',
#   'numeric_id': 316},
#  {'id': 'klubbar/sverige/asarums-if-fk/317',
#   'name': 'Asarums IF FK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/asarums-if-fk/317',
#   'numeric_id': 317},
#  {'id': 'klubbar/sverige/hassleholms-if/318',
#   'name': 'Hässleholms IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/hassleholms-if/318',
#   'numeric_id': 318},
#  {'id': 'klubbar/sverige/bw-90-if/319',
#   'name': 'BW 90 IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/bw-90-if/319',
#   'numeric_id': 319},
#  {'id': 'klubbar/sverige/kvarnby-ik/320',
#   'name': 'Kvarnby IK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/kvarnby-ik/320',
#   'numeric_id': 320},
#  {'id': 'klubbar/sverige/lindsdals-if/321',
#   'name': 'Lindsdals IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/lindsdals-if/321',
#   'numeric_id': 321},
#  {'id': 'klubbar/sverige/ksf-prespa-birlik/322',
#   'name': 'KSF Prespa Birlik',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ksf-prespa-birlik/322',
#   'numeric_id': 322},
#  {'id': 'klubbar/sverige/nosaby-if/323',
#   'name': 'Nosaby IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/nosaby-if/323',
#   'numeric_id': 323},
#  {'id': 'klubbar/sverige/ljungby-if/324',
#   'name': 'Ljungby IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ljungby-if/324',
#   'numeric_id': 324},
#  {'id': 'klubbar/sverige/if-limhamn-bunkeflo/325',
#   'name': 'IF Limhamn Bunkeflo',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/if-limhamn-bunkeflo/325',
#   'numeric_id': 325},
# ...
#   'name': 'Svängsta IF/Asarums IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/svangsta-ifasarums-if/955',
#   'numeric_id': 955},
#  {'id': 'klubbar/sverige/melleruds-if/956',
#   'name': 'Melleruds IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/melleruds-if/956',
#   'numeric_id': 956},
#  {'id': 'klubbar/sverige/vallens-if/957',
#   'name': 'Vallens IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/vallens-if/957',
#   'numeric_id': 957},
#  {'id': 'klubbar/sverige/herrestads-aif/958',
#   'name': 'Herrestads AIF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/herrestads-aif/958',
#   'numeric_id': 958},
#  {'id': 'klubbar/sverige/bengtsfors-if/959',
#   'name': 'Bengtsfors IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/bengtsfors-if/959',
#   'numeric_id': 959},
#  {'id': 'klubbar/sverige/ifk-lane/960',
#   'name': 'IFK Lane',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ifk-lane/960',
#   'numeric_id': 960},
#  {'id': 'klubbar/sverige/skarhamns-ik/961',
#   'name': 'Skärhamns IK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/skarhamns-ik/961',
#   'numeric_id': 961},
#  {'id': 'klubbar/sverige/if-viken/962',
#   'name': 'IF Viken',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/if-viken/962',
#   'numeric_id': 962},
#  {'id': 'klubbar/sverige/fargelanda-if/963',
#   'name': 'Färgelanda IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/fargelanda-if/963',
#   'numeric_id': 963},
#  {'id': 'klubbar/sverige/odsmals-ik/964',
#   'name': 'Ödsmåls IK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/odsmals-ik/964',
#   'numeric_id': 964},
#  {'id': 'klubbar/sverige/asebro-if/965',
#   'name': 'Åsebro IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/asebro-if/965',
#   'numeric_id': 965},
#  {'id': 'klubbar/sverige/svarteborgs-fk/966',
#   'name': 'Svarteborgs FK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/svarteborgs-fk/966',
#   'numeric_id': 966},
#  {'id': 'klubbar/sverige/stigenelleno/967',
#   'name': 'Stigen/Ellenö',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/stigenelleno/967',
#   'numeric_id': 967},
#  {'id': 'klubbar/sverige/ik-svane/968',
#   'name': 'IK Svane',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ik-svane/968',
#   'numeric_id': 968},
#  {'id': 'klubbar/sverige/munkedals-if/969',
#   'name': 'Munkedals IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/munkedals-if/969',
#   'numeric_id': 969},
#  {'id': 'klubbar/sverige/morlanda-goif/970',
#   'name': 'Morlanda GoIF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/morlanda-goif/970',
#   'numeric_id': 970},
#  {'id': 'klubbar/sverige/henans-if/971',
#   'name': 'Henåns IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/henans-if/971',
#   'numeric_id': 971},
#  {'id': 'klubbar/sverige/ifk-valla/972',
#   'name': 'IFK Valla',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ifk-valla/972',
#   'numeric_id': 972},
#  {'id': 'klubbar/sverige/ifk-stromstad/973',
#   'name': 'IFK Strömstad',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ifk-stromstad/973',
#   'numeric_id': 973},
#  {'id': 'klubbar/sverige/lysekils-ff/974',
#   'name': 'Lysekils FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/lysekils-ff/974',
#   'numeric_id': 974},
#  {'id': 'klubbar/sverige/gilleby-if/975',
#   'name': 'Gilleby IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/gilleby-if/975',
#   'numeric_id': 975},
#  {'id': 'klubbar/sverige/stalamyckleby/976',
#   'name': 'Stala/Myckleby',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/stalamyckleby/976',
#   'numeric_id': 976},
#  {'id': 'klubbar/sverige/smogen-kif/977',
#   'name': 'Smögen KIF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/smogen-kif/977',
#   'numeric_id': 977},
#  {'id': 'klubbar/sverige/hamburgsunds-if/978',
#   'name': 'Hamburgsunds IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/hamburgsunds-if/978',
#   'numeric_id': 978},
#  {'id': 'klubbar/sverige/hogstorps-if/979',
#   'name': 'Hogstorps IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/hogstorps-if/979',
#   'numeric_id': 979},
#  {'id': 'klubbar/sverige/hedekassvarteborg/980',
#   'name': 'Hedekas/Svarteborg',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/hedekassvarteborg/980',
#   'numeric_id': 980},
#  {'id': 'klubbar/sverige/slattens-ik/981',
#   'name': 'Slättens IK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/slattens-ik/981',
#   'numeric_id': 981},
#  {'id': 'klubbar/sverige/grundsunds-if/982',
#   'name': 'Grundsunds IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/grundsunds-if/982',
#   'numeric_id': 982},
#  {'id': 'klubbar/sverige/bovall-hunnebo/983',
#   'name': 'Bovall/ Hunnebo',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/bovall-hunnebo/983',
#   'numeric_id': 983},
#  {'id': 'klubbar/sverige/rosserods-ik/984',
#   'name': 'Rosseröds IK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/rosserods-ik/984',
#   'numeric_id': 984},
#  {'id': 'klubbar/sverige/svenshogens-sk/985',
#   'name': 'Svenshögens SK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/svenshogens-sk/985',
#   'numeric_id': 985},
#  {'id': 'klubbar/sverige/groheds-if/986',
#   'name': 'Groheds IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/groheds-if/986',
#   'numeric_id': 986},
#  {'id': 'klubbar/sverige/ronnangs-ff/987',
#   'name': 'Rönnängs FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ronnangs-ff/987',
#   'numeric_id': 987},
#  {'id': 'klubbar/sverige/ik-svaneuis/988',
#   'name': 'IK Svane/UIS',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ik-svaneuis/988',
#   'numeric_id': 988},
#  {'id': 'klubbar/sverige/tanums-if/989',
#   'name': 'Tanums IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/tanums-if/989',
#   'numeric_id': 989},
#  {'id': 'klubbar/sverige/skredsviks-sk/990',
#   'name': 'Skredsviks SK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/skredsviks-sk/990',
#   'numeric_id': 990},
#  {'id': 'klubbar/sverige/bokenas-if/991',
#   'name': 'Bokenäs IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/bokenas-if/991',
#   'numeric_id': 991},
#  {'id': 'klubbar/sverige/bullarens-goif/992',
#   'name': 'Bullarens GOIF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/bullarens-goif/992',
#   'numeric_id': 992},
#  {'id': 'klubbar/sverige/torp-goif/993',
#   'name': 'Torp GOIF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/torp-goif/993',
#   'numeric_id': 993},
#  {'id': 'klubbar/sverige/fjallbacka-ikhamburgsund/994',
#   'name': 'Fjällbacka IK/Hamburgsund',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/fjallbacka-ikhamburgsund/994',
#   'numeric_id': 994},
#  {'id': 'klubbar/sverige/ifk-mora-fk/995',
#   'name': 'IFK Mora FK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ifk-mora-fk/995',
#   'numeric_id': 995},
#  {'id': 'klubbar/sverige/svardsjo-if/996',
#   'name': 'Svärdsjö IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/svardsjo-if/996',
#   'numeric_id': 996},
#  {'id': 'klubbar/sverige/husby-aik/997',
#   'name': 'Husby AIK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/husby-aik/997',
#   'numeric_id': 997},
#  {'id': 'klubbar/sverige/dalajarna-ik/998',
#   'name': 'Dala-Järna IK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/dalajarna-ik/998',
#   'numeric_id': 998},
#  {'id': 'klubbar/sverige/islingby-ik/999',
#   'name': 'Islingby IK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/islingby-ik/999',
#   'numeric_id': 999},
#  {'id': 'klubbar/sverige/if-tunabro/1000',
#   'name': 'IF Tunabro',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/if-tunabro/1000',
#   'numeric_id': 1000},
#  {'id': 'klubbar/sverige/skogsboavesta-if/1001',
#   'name': 'Skogsbo/Avesta IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/skogsboavesta-if/1001',
#   'numeric_id': 1001},
#  {'id': 'klubbar/sverige/ulfshyttans-if/1002',
#   'name': 'Ulfshyttans IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ulfshyttans-if/1002',
#   'numeric_id': 1002},
#  {'id': 'klubbar/sverige/nyhammars-if/1003',
#   'name': 'Nyhammars IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/nyhammars-if/1003',
#   'numeric_id': 1003},
#  {'id': 'klubbar/sverige/bullermyrens-ik/1004',
#   'name': 'Bullermyrens IK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/bullermyrens-ik/1004',
#   'numeric_id': 1004},
#  {'id': 'klubbar/sverige/smedjebackens-fk/1005',
#   'name': 'Smedjebackens FK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/smedjebackens-fk/1005',
#   'numeric_id': 1005},
#  {'id': 'klubbar/sverige/ostansbo-is/1006',
#   'name': 'Östansbo IS',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ostansbo-is/1006',
#   'numeric_id': 1006},
#  {'id': 'klubbar/sverige/vansbro-aik-fk/1007',
#   'name': 'Vansbro AIK FK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/vansbro-aik-fk/1007',
#   'numeric_id': 1007},
#  {'id': 'klubbar/sverige/slatta-sk/1008',
#   'name': 'Slätta SK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/slatta-sk/1008',
#   'numeric_id': 1008},
#  {'id': 'klubbar/sverige/saters-if/1009',
#   'name': 'Säters IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/saters-if/1009',
#   'numeric_id': 1009},
#  {'id': 'klubbar/sverige/krylbo-if/1010',
#   'name': 'Krylbo IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/krylbo-if/1010',
#   'numeric_id': 1010},
#  {'id': 'klubbar/sverige/appelbo-aik/1011',
#   'name': 'Äppelbo AIK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/appelbo-aik/1011',
#   'numeric_id': 1011},
#  {'id': 'klubbar/sverige/leksands-if/1012',
#   'name': 'Leksands IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/leksands-if/1012',
#   'numeric_id': 1012},
#  {'id': 'klubbar/sverige/swesom-fc/1013',
#   'name': 'Swesom FC',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/swesom-fc/1013',
#   'numeric_id': 1013},
#  {'id': 'klubbar/sverige/ik-segro/1015',
#   'name': 'IK Segro',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ik-segro/1015',
#   'numeric_id': 1015},
#  {'id': 'klubbar/sverige/gagnefs-if/1016',
#   'name': 'Gagnefs IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/gagnefs-if/1016',
#   'numeric_id': 1016},
#  {'id': 'klubbar/sverige/malungs-if/1018',
#   'name': 'Malungs IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/malungs-if/1018',
#   'numeric_id': 1018},
#  {'id': 'klubbar/sverige/s-slima/1019',
#   'name': 'S/ S-Lima',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/s-slima/1019',
#   'numeric_id': 1019},
#  {'id': 'klubbar/sverige/tallbergs-if/1020',
#   'name': 'Tällbergs IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/tallbergs-if/1020',
#   'numeric_id': 1020},
#  {'id': 'klubbar/sverige/ifk-vamhus/1022',
#   'name': 'IFK Våmhus',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ifk-vamhus/1022',
#   'numeric_id': 1022},
#  {'id': 'klubbar/sverige/amsbergs-sk/1023',
#   'name': 'Amsbergs SK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/amsbergs-sk/1023',
#   'numeric_id': 1023},
#  {'id': 'klubbar/sverige/grycksbo-if/1024',
#   'name': 'Grycksbo IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/grycksbo-if/1024',
#   'numeric_id': 1024},
#  {'id': 'klubbar/sverige/hulans-if/1025',
#   'name': 'Hulåns IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/hulans-if/1025',
#   'numeric_id': 1025},
#  {'id': 'klubbar/sverige/boda-ore-sk/1026',
#   'name': 'Boda Ore SK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/boda-ore-sk/1026',
#   'numeric_id': 1026},
#  {'id': 'klubbar/sverige/langshyttans-aik-fk/1027',
#   'name': 'Långshyttans AIK FK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/langshyttans-aik-fk/1027',
#   'numeric_id': 1027},
#  {'id': 'klubbar/sverige/stora-tuna-ik/1028',
#   'name': 'Stora Tuna IK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/stora-tuna-ik/1028',
#   'numeric_id': 1028},
#  {'id': 'klubbar/sverige/ifk-hedemora/1029',
#   'name': 'IFK Hedemora',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ifk-hedemora/1029',
#   'numeric_id': 1029},
#  {'id': 'klubbar/sverige/vika-if/1030',
#   'name': 'Vika IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/vika-if/1030',
#   'numeric_id': 1030},
#  {'id': 'klubbar/sverige/ludvika-city-bk/1031',
#   'name': 'Ludvika City BK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ludvika-city-bk/1031',
#   'numeric_id': 1031},
#  {'id': 'klubbar/sverige/stora-skedvi-ik-ff/1032',
#   'name': 'Stora Skedvi IK FF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/stora-skedvi-ik-ff/1032',
#   'numeric_id': 1032},
#  {'id': 'klubbar/sverige/farnas-sk/1033',
#   'name': 'Färnäs SK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/farnas-sk/1033',
#   'numeric_id': 1033},
#  {'id': 'klubbar/sverige/if-vikapojkarna/1034',
#   'name': 'IF Vikapojkarna',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/if-vikapojkarna/1034',
#   'numeric_id': 1034},
#  {'id': 'klubbar/sverige/ona-sk/1035',
#   'name': 'Öna SK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ona-sk/1035',
#   'numeric_id': 1035},
#  {'id': 'klubbar/sverige/alvdalens-if-fk/1036',
#   'name': 'Älvdalens IF FK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/alvdalens-if-fk/1036',
#   'numeric_id': 1036},
#  {'id': 'klubbar/sverige/ifk-rattvik-fk/1037',
#   'name': 'IFK Rättvik FK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ifk-rattvik-fk/1037',
#   'numeric_id': 1037},
#  {'id': 'klubbar/sverige/if-nornan/1038',
#   'name': 'IF Nornan',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/if-nornan/1038',
#   'numeric_id': 1038},
#  {'id': 'klubbar/sverige/asens-sk/1039',
#   'name': 'Åsens SK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/asens-sk/1039',
#   'numeric_id': 1039},
#  {'id': 'klubbar/sverige/mockfjards-bk/1040',
#   'name': 'Mockfjärds BK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/mockfjards-bk/1040',
#   'numeric_id': 1040},
#  {'id': 'klubbar/sverige/if-vulcanus/1041',
#   'name': 'IF Vulcanus',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/if-vulcanus/1041',
#   'numeric_id': 1041},
#  {'id': 'klubbar/sverige/ifk-grangesberg-fk/1042',
#   'name': 'IFK Grängesberg FK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/ifk-grangesberg-fk/1042',
#   'numeric_id': 1042},
#  {'id': 'klubbar/sverige/torsangs-if/1044',
#   'name': 'Torsångs IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/torsangs-if/1044',
#   'numeric_id': 1044},
#  {'id': 'klubbar/sverige/bjursas-ik/1045',
#   'name': 'Bjursås IK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/bjursas-ik/1045',
#   'numeric_id': 1045},
#  {'id': 'klubbar/sverige/siljansnas-if/1046',
#   'name': 'Siljansnäs IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/siljansnas-if/1046',
#   'numeric_id': 1046},
#  {'id': 'klubbar/sverige/aspeboda-sk/1047',
#   'name': 'Aspeboda SK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/aspeboda-sk/1047',
#   'numeric_id': 1047},
#  {'id': 'klubbar/sverige/sundborns-goif/1048',
#   'name': 'Sundborns GOIF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/sundborns-goif/1048',
#   'numeric_id': 1048},
#  {'id': 'klubbar/sverige/halsinggardens-aik/1049',
#   'name': 'Hälsinggårdens AIK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/halsinggardens-aik/1049',
#   'numeric_id': 1049},
#  {'id': 'klubbar/sverige/horndals-if/1050',
#   'name': 'Horndals IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/horndals-if/1050',
#   'numeric_id': 1050},
#  {'id': 'klubbar/sverige/fors-ik/1051',
#   'name': 'Fors IK',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/fors-ik/1051',
#   'numeric_id': 1051},
#  {'id': 'klubbar/sverige/nas-if/1052',
#   'name': 'Näs IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/nas-if/1052',
#   'numeric_id': 1052},
#  {'id': 'klubbar/sverige/bralanda-if/1053',
#   'name': 'Brålanda IF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/bralanda-if/1053',
#   'numeric_id': 1053},
#  {'id': 'klubbar/sverige/hogsaters-gf/1054',
#   'name': 'Högsäters GF',
#   'url': 'https://fotbolltransfers.com/klubbar/sverige/hogsaters-gf/1054',
#   'numeric_id': 1054},
#  ...]

# %%
dfTeam = pd.DataFrame(resultsTeam,columns=['id','name','url','numeric_id'])

# %%
dfTeam
# Out:
#                                             id               name  \
# 0               klubbar/sverige/ifk-goteborg/2       IFK Göteborg
# 1                klubbar/sverige/if-elfsborg/3        IF Elfsborg
# 2                        klubbar/sverige/aik/4                AIK
# 3               klubbar/sverige/assyriska-ff/6       Assyriska FF
# 4                  klubbar/sverige/osters-if/7          Östers IF
# ...                                        ...                ...
# 6687      klubbar/ovriga-europa/mexico-fc/6795          México FC
# 6688    klubbar/sverige/fk-karlskrona-u16/6796  FK Karlskrona U16
# 6689  klubbar/ovriga-europa/rodina-moskva/6797      Rodina Moskva
# 6690   klubbar/ovriga-europa/fc-inter-u23/6798       FC Inter U23
# 6691          klubbar/varlden/toluca-fc-d/6799      Toluca FC (D)
#
#                                                     url  numeric_id
# 0     https://fotbolltransfers.com/klubbar/sverige/i...           2
# 1     https://fotbolltransfers.com/klubbar/sverige/i...           3
# 2     https://fotbolltransfers.com/klubbar/sverige/a...           4
# 3     https://fotbolltransfers.com/klubbar/sverige/a...           6
# 4     https://fotbolltransfers.com/klubbar/sverige/o...           7
# ...                                                 ...         ...
# 6687  https://fotbolltransfers.com/klubbar/ovriga-eu...        6795
# 6688  https://fotbolltransfers.com/klubbar/sverige/f...        6796
# 6689  https://fotbolltransfers.com/klubbar/ovriga-eu...        6797
# 6690  https://fotbolltransfers.com/klubbar/ovriga-eu...        6798
# 6691  https://fotbolltransfers.com/klubbar/varlden/t...        6799
#
# [6692 rows x 4 columns]

# %% [markdown]
# ### MixandMatch
# id,name,desc,type,url

# %%
dfTeam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6692 entries, 0 to 6691
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          6692 non-null   object
#  1   name        6692 non-null   object
#  2   url         6692 non-null   object
#  3   numeric_id  6692 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 209.3+ KB

# %%
import pandas as pd
from datetime import datetime

# ===== KONFIG =====
TYPE_PLAYER = "Q5"        # människa
TYPE_TEAM = "Q476028"     # fotbollsklubb

# ===== FILNAMN =====
today = datetime.now().strftime("%Y%m%d")
filename = f"41_fotbolltransfers_mixnmatch_{today}.csv"

# ===== BYGG DATA =====

# Spelare
df_players_out = dfPlayers.copy()
df_players_out["desc"] = "fotbollsspelare"
df_players_out["type"] = TYPE_PLAYER

# Klubb
df_team_out = dfTeam.copy()
df_team_out["desc"] = "fotbollsklubb"
df_team_out["type"] = TYPE_TEAM

# ===== KOMBINERA =====
df_out = pd.concat([df_players_out, df_team_out], ignore_index=True)

# ===== VÄLJ KOLUMNER =====
df_out = df_out[["id", "name", "desc", "type", "url"]]

# ===== EXPORT =====
df_out.to_csv(filename, index=False, encoding="utf-8")

print(f"Fil skapad: {filename}")
# Out:
# Fil skapad: 41_fotbolltransfers_mixnmatch_20260323.csv

# %%
 # End timer and calculate duration
end_time = time.time()
elapsed_time = end_time - start_time# Bygg audit-lager för den här etappen

# Print current date and total time
print("Date:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
minutes, seconds = divmod(elapsed_time, 60)
print("Total time elapsed: {:02.0f} minutes {:05.2f} seconds".format(minutes, seconds))
# Out:
# Date: 2026-03-20 21:03:15
# Total time elapsed: 413 minutes 17.43 seconds
