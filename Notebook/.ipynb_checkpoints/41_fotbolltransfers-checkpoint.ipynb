# %% [markdown]
# * [#41](https://github.com/salgo60/ifkdb/issues/41)
# * 41_fotbolltransfers.ipynb

# %%
import sys
print(sys.executable)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/bin/python3.12

# %%
#!pip3 install aiohttp

# %%
import time

from datetime import datetime

now = datetime.now()
timestamp = now.timestamp()

start_time = time.time()
print("Start:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Start: 2026-03-20 06:09:32

# %%
import requests
from bs4 import BeautifulSoup
import time
from tqdm import tqdm
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import json
import os

BASE_PLAYER_URL = "https://fotbolltransfers.com/spelare/x/{}"

SAVE_FILE = "resultsPlayer_partial.json"
FINAL_FILE = "resultsPlayer.json"

headers = {
    "User-Agent": "Mozilla/5.0 (compatible; scraper/1.0; contact: you@example.com)"
}

# 🔧 session med retry
session = requests.Session()

retries = Retry(
    total=5,
    backoff_factor=0.5,
    status_forcelist=[429, 500, 502, 503, 504],
)

adapter = HTTPAdapter(max_retries=retries)
session.mount("https://", adapter)
session.mount("http://", adapter)

# 🔄 Ladda snapshot om finns
if os.path.exists(SAVE_FILE):
    with open(SAVE_FILE, "r", encoding="utf-8") as f:
        resultsPlayer = json.load(f)
    print(f"Återupptar från {len(resultsPlayer)} spelare")
else:
    resultsPlayer = []

# 🔢 hitta startpunkt
existing_ids = {pid for _, pid in resultsPlayer}
start_id = max(existing_ids) + 1 if existing_ids else 1

print(f"Startar från player_id = {start_id}")

SAVE_EVERY = 100

for player_id in tqdm(range(start_id, 20001)):
    url = BASE_PLAYER_URL.format(player_id)

    try:
        r = session.get(url, headers=headers, timeout=10)

        if r.status_code != 200:
            continue

        soup = BeautifulSoup(r.text, "html.parser")

        if not soup.title or not soup.title.string:
            continue

        name = soup.title.string.split(" - ")[0].strip()

        # 🚫 filtrera bort skräp
        if name == "Fotbolltransfers.com":
            continue

        resultsPlayer.append((name, player_id))

    except requests.exceptions.RequestException as e:
        print(f"Error {player_id}: {e}")
        continue

    # 💾 checkpoint
    if player_id % SAVE_EVERY == 0:
        with open(SAVE_FILE, "w", encoding="utf-8") as f:
            json.dump(resultsPlayer, f, ensure_ascii=False)

    # 🐢 throttling (justera vid behov)
    #time.sleep(0.2)

# ✅ slutlig snapshot
with open(FINAL_FILE, "w", encoding="utf-8") as f:
    json.dump(resultsPlayer, f, ensure_ascii=False, indent=2)

print(f"Klar! Spelare funna: {len(resultsPlayer)}")
# Out:
# Startar från player_id = 1
#   0%|▏                                     | 76/20000 [00:39<6:55:16,  1.25s/it]

# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import json
import os
import time

BASE_TEAM_URL = "https://fotbolltransfers.com/klubbar/x/xx/{}"
SAVE_FILE = "resultsTeam_partial.json"
FINAL_FILE = "resultsTeam.json"

headers = {
    "User-Agent": "Mozilla/5.0"
}

session = requests.Session()

# 🔄 Ladda tidigare checkpoint om finns
if os.path.exists(SAVE_FILE):
    with open(SAVE_FILE, "r", encoding="utf-8") as f:
        resultsTeam = json.load(f)
    print(f"Återupptar från {len(resultsTeam)} lag")
else:
    resultsTeam = []

# 🔢 hitta startpunkt
existing_ids = {team_id for _, team_id in resultsTeam}
start_id = max(existing_ids) + 1 if existing_ids else 1

print(f"Startar från team_id = {start_id}")

SAVE_EVERY = 100

for team_id in tqdm(range(start_id, 20001)):
    url = BASE_TEAM_URL.format(team_id)

    try:
        r = session.get(url, headers=headers, timeout=10)

        if r.status_code != 200:
            continue

        soup = BeautifulSoup(r.text, "html.parser")

        if not soup.title or not soup.title.string:
            continue

        name = soup.title.string.split(" - ")[0].strip()

        # 🚫 filtrera bort skräp
        if name == "Fotbolltransfers.com":
            continue

        resultsTeam.append((name, team_id))

    except requests.exceptions.RequestException as e:
        print(f"Error {team_id}: {e}")
        continue

    # 💾 checkpoint
    if team_id % SAVE_EVERY == 0:
        with open(SAVE_FILE, "w", encoding="utf-8") as f:
            json.dump(resultsTeam, f, ensure_ascii=False)

    # 🐢 liten delay (minskar risk för block)
    #time.sleep(0.1)

# ✅ spara slutresultat
with open(FINAL_FILE, "w", encoding="utf-8") as f:
    json.dump(resultsTeam, f, ensure_ascii=False, indent=2)

print(f"Klar! Totalt lag: {len(resultsTeam)}")

# %%
import json

with open("resultsTeam_snapshot.json", "w", encoding="utf-8") as f:
    json.dump(resultsTeam, f, ensure_ascii=False, indent=2)

print("Snapshot sparad ✅")

# %%
resultsTeam

# %%
 # End timer and calculate duration
end_time = time.time()
elapsed_time = end_time - start_time# Bygg audit-lager för den här etappen

# Print current date and total time
print("Date:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
minutes, seconds = divmod(elapsed_time, 60)
print("Total time elapsed: {:02.0f} minutes {:05.2f} seconds".format(minutes, seconds))
