# %% [markdown]
# ### 3 Kolla nya ifkdb
# * https://ifkdb.se/listor/allaspelare
# * [#32](https://github.com/salgo60/ifkdb/issues/32)
# * denna notebook [32_ifkdb_all.ipynb](https://github.com/salgo60/ifkdb/blob/main/Notebook/32_ifkdb_all.ipynb)
# * lista
#    * [Notebook/ifkdb_mixnmatch.csv](https://github.com/salgo60/ifkdb/blob/main/Notebook/ifkdb_mixnmatch.csv)
#    * [csv](https://salgo60.github.io/ifkdb/Notebook/ifkdb_mixnmatch.csv)

# %%
from datetime import datetime
import platform
import sys
import os

# Start timer
start_time = datetime.now()
print(f"Start time: {start_time:%Y-%m-%d %H:%M:%S}")
# Out:
# Start time: 2026-03-03 16:52:03

# %%
import requests
import urllib.parse
import pandas as pd
from bs4 import BeautifulSoup
from SPARQLWrapper import SPARQLWrapper, JSON

# --------------------------------------------------
# 1. HÄMTA ALLA SPELARE FRÅN IFKDB
# --------------------------------------------------

import re

def scrape_player_details(full_id):

    url = f"https://ifkdb.se/spelare/{urllib.parse.quote(full_id)}"

    import time
    time.sleep(0.3)
    try:
        r = session.get(url, timeout=15)
        r.raise_for_status()
    except:
        return None

    soup = BeautifulSoup(r.text, "html.parser")

    text = soup.get_text("\n")

    fullname = None
    birthdate = None
    birthplace = None
    position = None
    last_season = None

    for line in text.split("\n"):

        line = line.strip()

        if line.startswith("Fullständigt namn"):
            fullname = line.replace("Fullständigt namn:", "").strip()

        if line.startswith("Född"):
            m = re.search(r"(\d{4}-\d{2}-\d{2})", line)
            if m:
                birthdate = m.group(1)

            place = line.split(" i ")
            if len(place) > 1:
                birthplace = place[-1].strip()

        # hitta sista säsong
        m = re.search(r"sista säsong.*?(\d{4})", line)
        if m:
            last_season = m.group(1)

        # hitta position
        if "målvakt" in line.lower():
            position = "målvakt"
        elif "försvarare" in line.lower():
            position = "försvarare"
        elif "mittfältare" in line.lower():
            position = "mittfältare"
        elif "anfallare" in line.lower():
            position = "anfallare"

    return {
        "fullname": fullname,
        "birthdate": birthdate,
        "birthplace": birthplace,
        "position": position,
        "last_season": last_season
    }


session = requests.Session()
session.headers.update({
    "User-Agent": "IFKDB-Match/1.0 (salgo60@msn.com)"
})

url = "https://ifkdb.se/listor/allaspelare"
r = session.get(url)
r.raise_for_status()

soup = BeautifulSoup(r.text, "html.parser")

players = {}

for a in soup.find_all("a", href=True):
    href = a["href"]
    if "/spelare/" in href:
        full_id = href.split("/spelare/")[1]
        full_id = urllib.parse.unquote(full_id)
        players[full_id] = a.text.strip()

print("Antal unika spelare:", len(players))


# --------------------------------------------------
# 2. SKAPA dfPlayers + NORMALISERA NAMN
# --------------------------------------------------

def normalize_name(name):
    parts = name.strip().split(" ", 1)
    if len(parts) != 2:
        return name.title()
    surname, firstname = parts
    return f"{firstname.title()} {surname.title()}"

dfPlayers = pd.DataFrame([
    {
        "full_id": pid,
        "numeric_id": pid.split("_")[-1],
        "name": normalize_name(name)
    }
    for pid, name in players.items()
])

print("Verifierade spelare:", len(dfPlayers))

details = []

for pid in dfPlayers["full_id"]:
    d = scrape_player_details(pid)
    print(d)
    if d:
        details.append(d)
    else:
        details.append({
            "position": None,
            "period": None,
            "fullname": None,
            "born": None
        })

dfDetails = pd.DataFrame(details)

dfPlayers = pd.concat([dfPlayers, dfDetails], axis=1)

# --------------------------------------------------
# 3. HÄMTA ALLA P11905 FRÅN WIKIDATA
# --------------------------------------------------

endpoint = "https://query.wikidata.org/sparql"

query = """
SELECT ?item ?ifkdb WHERE {
  # ?item wdt:P11905 ?ifkdb .
}
"""

sparql = SPARQLWrapper(endpoint)
sparql.setQuery(query)
sparql.setReturnFormat(JSON)
sparql.addCustomHttpHeader("User-Agent", "IFKDB-Match/1.0 (your_email@example.com)")

results = sparql.query().convert()

rows = []
for result in results["results"]["bindings"]:
    item = result["item"]["value"].split("/")[-1]
    ifkdb = result["ifkdb"]["value"]
    numeric_id = ifkdb.split("_")[-1]
    rows.append({
        "item": item,
        "numeric_id": numeric_id
    })

wd = pd.DataFrame(rows)

print("Wikidata entries:", len(wd))


# --------------------------------------------------
# 4. MATCHA PÅ NUMERISK ID (DETERMINISTISKT)
# --------------------------------------------------

matched = dfPlayers.merge(
    wd,
    on="numeric_id",
    how="left"
)

print("Matchade:", matched["item"].notna().sum())
print("Saknas:", matched["item"].isna().sum())


# --------------------------------------------------
# 5. SKAPA MIX'N'MATCH CSV
# --------------------------------------------------

def make_desc(row):

    if pd.notna(row["position"]) and pd.notna(row["last_season"]):
        return f"{row['position']} i IFK Göteborg, sista säsong {row['last_season']}"

    if pd.notna(row["last_season"]):
        return f"IFK Göteborg-spelare, sista säsong {row['last_season']}"

    return "IFK Göteborg-spelare enligt ifkdb.se"

matched["desc"] = matched.apply(make_desc, axis=1) 
matched["type"] = "Q5"
matched["q"] = matched["item"]  # Manual match om finns

dfMix = matched[["full_id", "name", "desc", "type", "q"]]
dfMix.columns = ["id", "name", "desc", "type", "q"]

dfMix.to_csv("ifkdb_mixnmatch_.csv", index=False, encoding="utf-8")

print("CSV skapad: ifkdb_mixnmatch_v2.csv")
# Out:
# Antal unika spelare: 1013
# Verifierade spelare: 1013
# {'fullname': 'Suleiman Abdullahi', 'birthdate': '1996-12-10', 'birthplace': None, 'position': 'anfallare', 'last_season': '2024'}
# {'fullname': 'Jan Axel Åberg', 'birthdate': '1939-12-12', 'birthplace': None, 'position': 'målvakt', 'last_season': '1964'}
# {'fullname': 'Paulos Johannes Abraham', 'birthdate': '2002-07-16', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2024'}
# {'fullname': 'Sargon Abraham', 'birthdate': '1991-02-07', 'birthplace': None, 'position': 'anfallare', 'last_season': '2020'}
# {'fullname': 'Harvid Karl Albert Abrahamsson', 'birthdate': '1895-08-29', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Henok Andreas Abrahamsson', 'birthdate': '1909-10-29', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Samuel Ayomide Adekugbe', 'birthdate': '1995-01-16', 'birthplace': None, 'position': None, 'last_season': '2017'}
# {'fullname': 'Mustapha Adio Ojora', 'birthdate': '2003-08-02', 'birthplace': None, 'position': 'anfallare', 'last_season': '2023'}
# {'fullname': 'Amin Tareq Affane', 'birthdate': '1994-01-21', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2020'}
# {'fullname': 'Bror Harry Agernäs', 'birthdate': '1927-11-25', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Thomas Karl Olof Ågren', 'birthdate': '1948-01-18', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1966'}
# {'fullname': 'Anders Bengt Ahlberg', 'birthdate': '1953-09-23', 'birthplace': None, 'position': 'anfallare', 'last_season': '1980'}
# {'fullname': 'Lars Erik Ahlberg', 'birthdate': '1934-06-05', 'birthplace': None, 'position': None, 'last_season': '1966'}
# {'fullname': 'Lars Gunnar Ahlberg', 'birthdate': '1947-03-30', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Hosam Aiesh', 'birthdate': '1995-04-14', 'birthplace': None, 'position': 'anfallare', 'last_season': '2022'}
# {'fullname': 'Evert Mauritz Åkervall', 'birthdate': '1908-11-08', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Amir Al-Ammari', 'birthdate': '1997-07-27', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2023'}
# {'fullname': 'Mohanad Mudhafar Burhan Al-Jarah', 'birthdate': '1996-12-23', 'birthplace': None, 'position': None, 'last_season': '2024'}
# {'fullname': 'Leif Gunnar Albinsson', 'birthdate': '1944-10-24', 'birthplace': None, 'position': None, 'last_season': '1963'}
# {'fullname': 'Rein Albo', 'birthdate': '1954-02-13', 'birthplace': None, 'position': None, 'last_season': '1978'}
# {'fullname': 'Anssi Mauricio Albornoz Inola', 'birthdate': '1988-03-10', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2016'}
# {'fullname': 'Mads Winther Albæk', 'birthdate': '1990-01-14', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2017'}
# {'fullname': 'Axel Villy Albin Aldebrink', 'birthdate': '1927-01-16', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Haitam Aleesami', 'birthdate': '1991-07-31', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2016'}
# {'fullname': 'Daniel Nils Alexandersson', 'birthdate': '1978-12-03', 'birthplace': None, 'position': 'anfallare', 'last_season': '2009'}
# {'fullname': 'Jens Niclas Alexandersson', 'birthdate': '1971-12-29', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2009'}
# {'fullname': 'Noah Jonathan Alexandersson', 'birthdate': '2001-09-30', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2022'}
# {'fullname': 'Karl Ruben Alexandersson', 'birthdate': '1935-04-22', 'birthplace': None, 'position': 'försvarare', 'last_season': None}
# {'fullname': 'Axel Alfredsson', 'birthdate': '1902-05-02', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Sten Gunde Algebäck', 'birthdate': '1950-01-29', 'birthplace': None, 'position': 'anfallare', 'last_season': '1972'}
# {'fullname': 'Saidou Alioum Moubarak', 'birthdate': '2003-07-25', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Joel Emil Martin Allansson', 'birthdate': '1992-11-03', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2014'}
# {'fullname': 'Karl Henry Almborg', 'birthdate': '1909-10-30', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Max Henry Almén', 'birthdate': '1896-02-22', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Rolf Reine Almqvist', 'birthdate': '1949-04-12', 'birthplace': None, 'position': 'anfallare', 'last_season': '1980'}
# {'fullname': 'Rolf Sixten Ingemar Almqvist', 'birthdate': '1928-05-12', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Erik Severius Alstam', 'birthdate': '1889-10-24', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'John Rune Alvbåge', 'birthdate': '1982-08-10', 'birthplace': None, 'position': 'målvakt', 'last_season': '2016'}
# {'fullname': 'Filip Alexander Ambrož', 'birthdate': '2003-12-01', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2023'}
# {'fullname': 'Sixten Vilhelm Paul Ammerfelt', 'birthdate': '1911-11-21', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Tom Shiran Amos', 'birthdate': '1998-02-06', 'birthplace': None, 'position': 'målvakt', 'last_season': '2021'}
# {'fullname': 'Niklas Johan Andersen', 'birthdate': '1992-08-05', 'birthplace': None, 'position': None, 'last_season': '2010'}
# {'fullname': 'Mats Anders Andersson', 'birthdate': '1951-03-08', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1973'}
# {'fullname': 'Claes Andreas Andersson', 'birthdate': '1974-04-10', 'birthplace': None, 'position': 'anfallare', 'last_season': '1997'}
# {'fullname': None, 'birthdate': None, 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Gustaf Arnold Andersson', 'birthdate': '1916-02-29', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Arthur Erland Eugen Andersson', 'birthdate': '1888-01-07', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Bengt Evert Andersson', 'birthdate': '1966-08-11', 'birthplace': None, 'position': 'målvakt', 'last_season': '2007'}
# {'fullname': 'Bo Erland Andersson', 'birthdate': '1955-08-31', 'birthplace': None, 'position': 'mittfältare', 'last_season': None}
# {'fullname': 'Carl Fredrik Andersson', 'birthdate': None, 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Clas Erik Valdemar Andersson', 'birthdate': '1892-08-20', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'David Natanael Andersson', 'birthdate': '1891-06-18', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Dick Georg Andersson', 'birthdate': '1943-11-13', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Harry Frans Einar Andersson', 'birthdate': '1885-10-21', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Erik Valdemar Andersson', 'birthdate': '1898-01-01', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Ernst Andersson', 'birthdate': '1909-03-26', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Sven Evald Andersson', 'birthdate': '1913-03-08', 'birthplace': None, 'position': 'försvarare', 'last_season': None}
# {'fullname': 'Fredrik Andersson', 'birthdate': '1981-05-28', 'birthplace': None, 'position': 'målvakt', 'last_season': '2000'}
# {'fullname': 'Nils Torsten Georg Andersson', 'birthdate': '1945-12-13', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1975'}
# {'fullname': 'Gösta Torvald Andersson', 'birthdate': '1907-03-18', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Hjalmar Göte Runar Andersson', 'birthdate': '1919-01-21', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Karl Gunnar Andersson', 'birthdate': '1928-08-14', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Jan Gustaf Andersson', 'birthdate': '1974-12-06', 'birthplace': None, 'position': 'anfallare', 'last_season': '2002'}
# {'fullname': 'Alfred Helge Julius Andersson', 'birthdate': '1899-06-15', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Henry Reinhold Andersson', 'birthdate': '1924-10-28', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': None, 'birthdate': None, 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': None, 'birthdate': None, 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'John Arvid Andersson', 'birthdate': '1902-05-29', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'John Hilmer Andersson', 'birthdate': '1914-08-21', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Karl W. Andersson', 'birthdate': None, 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Karl Andreas Andersson', 'birthdate': '1896-02-27', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Bernt Kennet Andersson', 'birthdate': '1967-10-06', 'birthplace': None, 'position': 'anfallare', 'last_season': '1991'}
# {'fullname': 'Kent Åke Andersson', 'birthdate': '1950-01-11', 'birthplace': None, 'position': None, 'last_season': '1974'}
# {'fullname': 'Kevin David Andersson', 'birthdate': '1996-11-18', 'birthplace': None, 'position': 'försvarare', 'last_season': '2015'}
# {'fullname': 'Stig Lars Hevi Andersson', 'birthdate': '1932-02-04', 'birthplace': None, 'position': 'målvakt', 'last_season': '1959'}
# {'fullname': 'Leif Arne Andersson', 'birthdate': '1952-02-20', 'birthplace': None, 'position': 'anfallare', 'last_season': '1974'}
# {'fullname': 'Stig Lennart Andersson', 'birthdate': '1931-07-19', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Lennart Gustav Andersson', 'birthdate': '1932-11-05', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Lindoff Andersson', 'birthdate': '1887-04-04', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Michael Östen Andersson', 'birthdate': '1959-08-24', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1988'}
# {'fullname': 'Erik Mikael Andersson', 'birthdate': '1990-05-09', 'birthplace': None, 'position': 'försvarare', 'last_season': '2009'}
# {'fullname': 'Nils Adolf Andersson', 'birthdate': '1887-03-10', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Johan Oscar Andersson', 'birthdate': '1976-02-21', 'birthplace': None, 'position': None, 'last_season': '1995'}
# {'fullname': 'Otto August Andersson', 'birthdate': '1910-05-07', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Göran Patric Andersson', 'birthdate': '1979-04-01', 'birthplace': None, 'position': 'anfallare', 'last_season': '2004'}
# {'fullname': 'Bengt Peter Göran Andersson', 'birthdate': '1962-10-11', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1985'}
# {'fullname': 'Kent Raymond Andersson', 'birthdate': '1950-05-20', 'birthplace': None, 'position': 'försvarare', 'last_season': '1975'}
# {'fullname': 'Per Robert Andersson', 'birthdate': '1971-08-22', 'birthplace': None, 'position': 'anfallare', 'last_season': '1998'}
# {'fullname': None, 'birthdate': None, 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': None, 'birthdate': None, 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Erik Stefan Andersson', 'birthdate': '1951-01-18', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1975'}
# {'fullname': 'Stellan Teodor Andersson', 'birthdate': '1902-10-25', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Sven Erland Andersson', 'birthdate': '1928-05-28', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Tage Elof Andersson', 'birthdate': '1926-06-11', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Anders Teodor Andersson', 'birthdate': '1889-12-01', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Leif Thomas Andersson', 'birthdate': '1973-03-05', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1993'}
# {'fullname': 'Verner Reinhold Andersson', 'birthdate': '1904-06-03', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Johan Viktor Andersson', 'birthdate': '2004-03-30', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Conny Lars Andreasson', 'birthdate': '1927-08-14', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Leif Kenny Andrén', 'birthdate': '1952-01-09', 'birthplace': None, 'position': None, 'last_season': '1971'}
# {'fullname': 'Johan Ove Anegrund', 'birthdate': '1973-03-01', 'birthplace': None, 'position': 'försvarare', 'last_season': '1999'}
# {'fullname': 'Ioannis Anestis', 'birthdate': '1991-03-09', 'birthplace': None, 'position': 'målvakt', 'last_season': '2021'}
# {'fullname': 'Jakob Svarrer Ankersen', 'birthdate': '1990-09-22', 'birthplace': None, 'position': None, 'last_season': '2016'}
# {'fullname': 'Erik Henry Antfors', 'birthdate': '1909-05-18', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Hans Mikael Antonsson', 'birthdate': '1981-05-31', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2004'}
# {'fullname': 'Arne Gunnar Appelgren', 'birthdate': '1922-03-24', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Joel Benjamin Appelgren', 'birthdate': '1893-07-02', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Sven Valdemar Appelgren', 'birthdate': '1927-09-08', 'birthplace': None, 'position': 'försvarare', 'last_season': None}
# {'fullname': 'Gunnar Lambert Arcadius', 'birthdate': '1891-12-24', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Lars Erik Arvelin', 'birthdate': '1945-03-23', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Jan Nicklas Asp', 'birthdate': '1986-01-10', 'birthplace': None, 'position': 'anfallare', 'last_season': '2005'}
# {'fullname': None, 'birthdate': None, 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'William Philip Siros Atashkadeh', 'birthdate': '1992-04-12', 'birthplace': None, 'position': 'anfallare', 'last_season': '2010'}
# {'fullname': 'Bernt Villy Attemalm', 'birthdate': '1937-04-28', 'birthplace': None, 'position': None, 'last_season': '1960'}
# {'fullname': 'Hans Carl Ludwig Augustinsson', 'birthdate': '1994-05-21', 'birthplace': None, 'position': None, 'last_season': '2014'}
# {'fullname': 'Kenth Arvid Augustsson', 'birthdate': '1946-12-29', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1973'}
# {'fullname': 'Anders Harald Torsten Augustsson', 'birthdate': '1901-02-18', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Karl Levi Jonathan Azulay', 'birthdate': '1993-05-05', 'birthplace': None, 'position': None, 'last_season': '2014'}
# {'fullname': 'Nikolai Baden Frederiksen', 'birthdate': '2000-05-18', 'birthplace': None, 'position': 'anfallare', 'last_season': '2024'}
# {'fullname': 'Jonas Valentin Bager', 'birthdate': '1996-07-18', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Ulf Mikael Bång', 'birthdate': '1967-03-08', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1991'}
# {'fullname': 'Mats Johan Edward Bångsbo', 'birthdate': '2003-02-10', 'birthplace': None, 'position': None, 'last_season': '2024'}
# {'fullname': 'Nicklas Robert Bärkroth', 'birthdate': '1992-01-19', 'birthplace': None, 'position': 'anfallare', 'last_season': '2012'}
# {'fullname': 'Stefan Arne Bärlin', 'birthdate': '1976-05-31', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1999'}
# {'fullname': 'Elis Emanuel Barlind', 'birthdate': '2007-01-05', 'birthplace': None, 'position': 'försvarare', 'last_season': None}
# {'fullname': 'Junes Barny', 'birthdate': '1989-11-04', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2019'}
# {'fullname': 'Lee Stuart Baxter', 'birthdate': '1976-06-17', 'birthplace': None, 'position': 'målvakt', 'last_season': '2004'}
# {'fullname': 'Jan Erik Bender', 'birthdate': '1947-06-10', 'birthplace': None, 'position': 'försvarare', 'last_season': '1972'}
# {'fullname': 'Adam Ingi Benediktsson', 'birthdate': '2002-10-28', 'birthplace': None, 'position': 'målvakt', 'last_season': '2024'}
# {'fullname': 'Jan Åke Bengtsson', 'birthdate': '1940-03-31', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Algot Sigfrid Bengtsson', 'birthdate': '1900-09-16', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Jan Patrik Bengtsson', 'birthdate': '1971-03-09', 'birthplace': None, 'position': 'anfallare', 'last_season': '1995'}
# {'fullname': 'Sture Vilhelm Bengtsson', 'birthdate': '1936-11-22', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Bror Holger Bennhov', 'birthdate': '1912-11-03', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Lion Beqiri', 'birthdate': '2006-05-27', 'birthplace': None, 'position': 'anfallare', 'last_season': '2024'}
# {'fullname': 'Bror David Berg', 'birthdate': '1917-02-28', 'birthplace': None, 'position': 'mittfältare', 'last_season': None}
# {'fullname': 'Fritz Gustaf Berg', 'birthdate': '1909-11-03', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Anders Kenneth Jonatan Berg', 'birthdate': '1985-05-09', 'birthplace': None, 'position': 'anfallare', 'last_season': '2008'}
# {'fullname': 'Kent Owe Berg', 'birthdate': '1936-06-04', 'birthplace': None, 'position': 'försvarare', 'last_season': '1960'}
# {'fullname': 'Bengt Erik Markus Berg', 'birthdate': '1986-08-17', 'birthplace': None, 'position': 'anfallare', 'last_season': '2023'}
# {'fullname': 'John Harry Bergelin', 'birthdate': '1890-07-03', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Hans Magnus Bergendahl', 'birthdate': '1954-01-01', 'birthplace': None, 'position': 'målvakt', 'last_season': '1972'}
# {'fullname': 'Fred Erik Berglin', 'birthdate': '2000-07-19', 'birthplace': None, 'position': None, 'last_season': '2019'}
# {'fullname': 'Lars Olof Berglund', 'birthdate': '1947-09-17', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Gösta Evert Bergman', 'birthdate': '1909-12-02', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Karl Jakob Lennart Bergman', 'birthdate': '1996-01-02', 'birthplace': None, 'position': 'försvarare', 'last_season': '2015'}
# {'fullname': 'Uno Morgan Bergman', 'birthdate': '1911-11-18', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Carl Adam Bergmark Wiberg', 'birthdate': '1997-05-07', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Sven Erik Gustav Bergqvist', 'birthdate': '1922-03-05', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Algot Natanael Bergström', 'birthdate': '1909-12-23', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Johan Erik Vitalis Eugén Bergström', 'birthdate': '1886-01-06', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Johan Henrik Froster Bergström', 'birthdate': '1889-01-19', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Ralph Edor Bergström', 'birthdate': '1946-02-19', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Bengt Ryno Berndtsson', 'birthdate': '1933-01-26', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Elis Leonard Berndtsson', 'birthdate': '1902-06-30', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Oskar Harry Berndtsson', 'birthdate': '1906-02-11', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Anders Harry Berndtsson', 'birthdate': '1915-01-09', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Per Olof Berndtsson', 'birthdate': '1920-03-10', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Per Anders Samuel Bernmar', 'birthdate': '1917-09-30', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Fritz Algot Berntsson', 'birthdate': '1889-01-22', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Bengt Ingvar Tommy Bertilsson', 'birthdate': '1949-03-21', 'birthplace': None, 'position': 'målvakt', 'last_season': '1971'}
# {'fullname': 'Elis Stefan Bishesari', 'birthdate': '2005-05-19', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Theodór Elmar Bjarnason', 'birthdate': '1987-03-04', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2011'}
# {'fullname': 'Nils Erik Mattias Bjärsmyr', 'birthdate': '1986-01-03', 'birthplace': None, 'position': None, 'last_season': '2022'}
# {'fullname': 'Bill Sven-Ove Björklund', 'birthdate': '1941-12-24', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Joachim Björklund', 'birthdate': '1971-03-15', 'birthplace': None, 'position': None, 'last_season': '1995'}
# {'fullname': 'Leif Gunnar Björkman', 'birthdate': '1924-10-11', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Petter Johannes Björlund', 'birthdate': '1989-06-05', 'birthplace': None, 'position': None, 'last_season': '2009'}
# {'fullname': 'Sam Thomas Bjur', 'birthdate': '1966-09-12', 'birthplace': None, 'position': 'anfallare', 'last_season': '1986'}
# {'fullname': 'Henrik Rørvik Bjørdal', 'birthdate': '1997-02-04', 'birthplace': None, 'position': None, 'last_season': '2017'}
# {'fullname': 'Ralf Göran Blom', 'birthdate': '1947-05-30', 'birthplace': None, 'position': 'mittfältare', 'last_season': None}
# {'fullname': 'Hans Fredrik Blomqvist', 'birthdate': '1975-03-17', 'birthplace': None, 'position': 'anfallare', 'last_season': '2003'}
# {'fullname': 'Lars Jesper Blomqvist', 'birthdate': '1974-02-05', 'birthplace': None, 'position': 'anfallare', 'last_season': '1996'}
# {'fullname': 'Rolf Oskar Vilhelm Blomqvist', 'birthdate': '1947-03-04', 'birthplace': None, 'position': 'målvakt', 'last_season': '1975'}
# {'fullname': 'Karl Fredrik Bohm', 'birthdate': '1995-08-24', 'birthplace': None, 'position': None, 'last_season': '2015'}
# {'fullname': 'Rolf Gösta Alexius Bohman', 'birthdate': '1911-08-27', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Darijan Bojanic', 'birthdate': '1994-12-28', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2014'}
# {'fullname': 'Ernst Anders Mikael Boman', 'birthdate': '1988-07-14', 'birthplace': None, 'position': 'anfallare', 'last_season': '2017'}
# {'fullname': 'Hans Lennart Bomb', 'birthdate': '1921-05-10', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Nils David Casper Boo Wiklander', 'birthdate': '1984-10-03', 'birthplace': None, 'position': None, 'last_season': '2018'}
# {'fullname': 'Alfons Borén', 'birthdate': '2006-09-13', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Alfred Georg Borg', 'birthdate': '1913-03-09', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Åke Harald Börjesson', 'birthdate': '1940-02-21', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Erik Oskar Börjesson', 'birthdate': '1886-12-01', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Reino Erik Börjesson', 'birthdate': '1929-02-04', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Rolf Anders Vilhelm Borssén', 'birthdate': '1895-10-22', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Gert Roberth Börve', 'birthdate': '1972-10-11', 'birthplace': None, 'position': 'anfallare', 'last_season': '1992'}
# {'fullname': 'Harry Douglas Eugen Branting', 'birthdate': '1895-02-13', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Benjamin Brantlind', 'birthdate': '2008-08-15', 'birthplace': None, 'position': 'mittfältare', 'last_season': None}
# {'fullname': 'Tobias Sebastian Bratt', 'birthdate': '1993-03-19', 'birthplace': None, 'position': 'försvarare', 'last_season': '2012'}
# {'fullname': 'Bror Josef Andersson (Brink)', 'birthdate': '1892-09-26', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Rolf Yngve Brodd', 'birthdate': '1930-06-09', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Oliwer Niklas Brodin', 'birthdate': '2004-07-20', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2023'}
# {'fullname': 'Allan Isidor Brufelt', 'birthdate': '1927-02-25', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Hans Andreas Brunbäck', 'birthdate': '1975-07-12', 'birthplace': None, 'position': None, 'last_season': '1994'}
# {'fullname': 'Hans Erland Brunbäck', 'birthdate': '1932-12-17', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Hans Arne Fredrik Bryngelsson', 'birthdate': '1975-04-10', 'birthplace': None, 'position': None, 'last_season': '1994'}
# {'fullname': 'Lars Peter Caban', 'birthdate': '1971-08-24', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1991'}
# {'fullname': 'André Jack Calisir', 'birthdate': '1990-06-13', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2020'}
# {'fullname': 'Diego Gerardo Calvo Fonseca', 'birthdate': '1991-03-25', 'birthplace': None, 'position': None, 'last_season': '2014'}
# {'fullname': 'Ulf Benny Canefur', 'birthdate': '1961-02-22', 'birthplace': None, 'position': 'anfallare', 'last_season': '1980'}
# {'fullname': 'Bo Sören Canefur', 'birthdate': '1956-04-24', 'birthplace': None, 'position': 'försvarare', 'last_season': None}
# {'fullname': 'Adam Erik Carlén', 'birthdate': '2000-06-27', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2025'}
# {'fullname': 'Ulf Anders Einar Carlgren', 'birthdate': '1962-08-20', 'birthplace': None, 'position': 'försvarare', 'last_season': '1985'}
# {'fullname': 'Thomas Alexander Carlsson', 'birthdate': '2007-08-02', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Algot Edvin Gottfrid Carlsson', 'birthdate': '1901-05-12', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': None, 'birthdate': None, 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Bror Oskar Eugén Carlsson', 'birthdate': '1897-06-28', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': None, 'birthdate': None, 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': None, 'birthdate': None, 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Björn Jerry Carlsson', 'birthdate': '1953-11-21', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1987'}
# {'fullname': 'John Osvald Hilding Carlsson', 'birthdate': '1893-04-05', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Karl Gustaf Lennart Carlsson', 'birthdate': '1909-05-12', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Per Mats Ola Carlsson', 'birthdate': '1961-01-28', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1988'}
# {'fullname': 'Lars Nicklas Carlsson', 'birthdate': '1979-11-13', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2010'}
# {'fullname': 'Jan Kent Carlstedt', 'birthdate': '1937-02-26', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Linus Casper Carlstrand', 'birthdate': '2004-08-31', 'birthplace': None, 'position': 'anfallare', 'last_season': '2025'}
# {'fullname': 'Karl Viktor Carlund', 'birthdate': '1906-02-05', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Hussein Carneil', 'birthdate': '2003-05-09', 'birthplace': None, 'position': 'anfallare', 'last_season': '2025'}
# {'fullname': 'Kim Christensen', 'birthdate': '1979-07-16', 'birthplace': None, 'position': 'målvakt', 'last_season': '2010'}
# {'fullname': 'Rolf Bertil Morgan Christensson', 'birthdate': '1912-12-26', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Tage Harry Christoffersson', 'birthdate': '1952-07-26', 'birthplace': None, 'position': 'målvakt', 'last_season': '1979'}
# {'fullname': 'Leif Knut-Inge Klasson', 'birthdate': '1940-12-17', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Staffan Rickard Claesson', 'birthdate': '1977-03-19', 'birthplace': None, 'position': 'målvakt', 'last_season': '2004'}
# {'fullname': 'Rune Ingvar Klasson', 'birthdate': '1924-02-02', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Sebastian Senna Hounou Clemmensen', 'birthdate': '2003-09-01', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Tiago de Freitas Guimarães Coimbra', 'birthdate': '2004-01-17', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Mats Dan Erling Corneliusson', 'birthdate': '1961-10-02', 'birthplace': None, 'position': 'anfallare', 'last_season': '1983'}
# {'fullname': 'Nelson Martín Crossa', 'birthdate': '1977-02-02', 'birthplace': None, 'position': 'anfallare', 'last_season': '2003'}
# {'fullname': 'Patrick dos Santos Cruz', 'birthdate': '1993-04-01', 'birthplace': None, 'position': 'anfallare', 'last_season': '2015'}
# {'fullname': 'Kristopher Santos Da Graca', 'birthdate': '1998-01-16', 'birthplace': None, 'position': None, 'last_season': '2020'}
# {'fullname': 'Patrik Carl Olof Dahbo', 'birthdate': '1979-12-27', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1998'}
# {'fullname': 'Lennart Folke Dahlberg', 'birthdate': '1938-05-25', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Pontus Jacob Ragne Dahlberg', 'birthdate': '1999-01-21', 'birthplace': None, 'position': 'målvakt', 'last_season': '2025'}
# {'fullname': 'Erik Axel Dahlin', 'birthdate': '1989-04-28', 'birthplace': None, 'position': 'målvakt', 'last_season': '2019'}
# {'fullname': 'Edvin Thomas Dahlqvist', 'birthdate': '1999-06-14', 'birthplace': None, 'position': 'försvarare', 'last_season': '2019'}
# {'fullname': 'Jan Fredrik Dahlqvist', 'birthdate': '1976-11-12', 'birthplace': None, 'position': 'försvarare', 'last_season': '1996'}
# {'fullname': 'Isak Mikael Dahlqvist', 'birthdate': '2001-09-25', 'birthplace': None, 'position': None, 'last_season': '2021'}
# {'fullname': 'Erik Valdemar Dahlström', 'birthdate': '1889-02-14', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Bo Lennart Danielsson', 'birthdate': '1939-02-18', 'birthplace': None, 'position': None, 'last_season': '1960'}
# {'fullname': 'Sten Erwing Danielsson', 'birthdate': '1948-06-14', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Sven Ingemar Danielsson', 'birthdate': '1934-10-04', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Emil Ferdinand Davidsson', 'birthdate': '1883-07-12', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Francisco Javier de Pedro Falque', 'birthdate': '1973-08-04', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2005'}
# {'fullname': 'Marcus Gustav Degerlund', 'birthdate': '1998-03-16', 'birthplace': None, 'position': None, 'last_season': '2018'}
# {'fullname': 'Mamadou Diallo Sebane', 'birthdate': '1971-08-28', 'birthplace': None, 'position': 'anfallare', 'last_season': '2003'}
# {'fullname': 'Mikkel Morgenstar Pålssønn Diskerud', 'birthdate': '1990-10-02', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2018'}
# {'fullname': 'Rolf Axel Dönell', 'birthdate': '1929-10-05', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Andreas Staffan Drugge', 'birthdate': '1983-01-20', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2011'}
# {'fullname': 'Tord Arvid Dubar', 'birthdate': '1941-06-04', 'birthplace': None, 'position': 'anfallare', 'last_season': '1960'}
# {'fullname': 'Mikael Bertil Dyrestam', 'birthdate': '1991-12-10', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2013'}
# {'fullname': 'Patrick Robin Dyrestam', 'birthdate': '1996-03-11', 'birthplace': None, 'position': None, 'last_season': '2015'}
# {'fullname': 'Gustaf Franklin Edenholm', 'birthdate': '1891-11-29', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Ralf Sigvard Edström', 'birthdate': '1952-10-07', 'birthplace': None, 'position': 'anfallare', 'last_season': '1979'}
# {'fullname': 'Sten Vilgot Edström', 'birthdate': '1931-03-03', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Victor Kaj Edvardsen', 'birthdate': '1996-01-14', 'birthplace': None, 'position': 'anfallare', 'last_season': '2015'}
# {'fullname': 'Erik Vilhelm Eiserman', 'birthdate': '1892-08-09', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Nils Bertil Ekeroth', 'birthdate': '1930-04-28', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Rolf David Gunnar Eklöf', 'birthdate': '1938-07-24', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Ernst Håkan Eklund', 'birthdate': '1941-12-18', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Björn Olof Rune Ekman', 'birthdate': '1949-05-04', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Karl Vilhelm Ekman', 'birthdate': '1885-09-26', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Dan Heimer Ekner', 'birthdate': '1927-07-05', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Johnny Douglas Ekström', 'birthdate': '1965-03-05', 'birthplace': None, 'position': 'anfallare', 'last_season': '1998'}
# {'fullname': 'Josef Robin El Dana', 'birthdate': '1981-06-23', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2001'}
# {'fullname': 'Karl Erik Ingvar Eliasson', 'birthdate': '1916-04-22', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Bengt Göran Jonas Elovsson', 'birthdate': '1958-04-29', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1980'}
# {'fullname': 'Rune Verner Emanuelsson', 'birthdate': '1923-10-08', 'birthplace': None, 'position': 'mittfältare', 'last_season': None}
# {'fullname': 'Ove Bertil Engström', 'birthdate': '1947-03-06', 'birthplace': None, 'position': None, 'last_season': '1971'}
# {'fullname': 'Gustav Per Fredrik Engvall', 'birthdate': '1996-04-29', 'birthplace': None, 'position': 'anfallare', 'last_season': '2018'}
# {'fullname': 'Erhan Erdogan', 'birthdate': '1988-03-16', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2007'}
# {'fullname': 'Olof Vilhelm Erik Erickson', 'birthdate': '1884-11-21', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': None, 'birthdate': None, 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Martin Kjell Henrik Ericsson', 'birthdate': '1980-09-04', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2003'}
# {'fullname': 'Kjell Pär Oskar Ericsson', 'birthdate': '1988-07-21', 'birthplace': None, 'position': 'anfallare', 'last_season': '2012'}
# {'fullname': 'Björn Åke Eriksson', 'birthdate': '1943-09-10', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Bo Daniel Eriksson', 'birthdate': '1969-10-09', 'birthplace': None, 'position': None, 'last_season': '1988'}
# {'fullname': 'Axel Elis Erland Eriksson', 'birthdate': '1902-12-10', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Felix David William Eriksson', 'birthdate': '2004-05-21', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Bo-Gösta Valdemar Eriksson', 'birthdate': '1922-01-01', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Lars Erik Vilhelm Eriksson', 'birthdate': '1925-03-06', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Nils Bertil Eriksson', 'birthdate': '1916-03-02', 'birthplace': None, 'position': 'försvarare', 'last_season': None}
# {'fullname': 'Per-Erik Eriksson', 'birthdate': '1945-09-15', 'birthplace': None, 'position': 'anfallare', 'last_season': '1975'}
# {'fullname': 'Bertil Peter Eriksson', 'birthdate': '1969-05-18', 'birthplace': None, 'position': 'anfallare', 'last_season': '2002'}
# {'fullname': 'Rolf Helmer Eriksson', 'birthdate': '1932-03-14', 'birthplace': None, 'position': 'mittfältare', 'last_season': None}
# {'fullname': 'Sebastian Anders Fredrik Eriksson', 'birthdate': '1989-01-31', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2023'}
# {'fullname': 'Jan August Erlingmark', 'birthdate': '1998-04-22', 'birthplace': None, 'position': 'mittfältare', 'last_season': None}
# {'fullname': 'Per Magnus Erlingmark', 'birthdate': '1968-07-08', 'birthplace': None, 'position': 'anfallare', 'last_season': '2004'}
# {'fullname': 'Gabriel Elias Ersoy', 'birthdate': '2005-06-07', 'birthplace': None, 'position': 'försvarare', 'last_season': None}
# {'fullname': 'Kaj Matti Juhani Eskelinen', 'birthdate': '1969-02-21', 'birthplace': None, 'position': 'anfallare', 'last_season': '1992'}
# {'fullname': 'Mathias Etéus', 'birthdate': '1990-06-07', 'birthplace': None, 'position': 'anfallare', 'last_season': '2009'}
# {'fullname': 'Bert Eilert Tage Fagerman', 'birthdate': '1932-02-20', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Arvid Fagrell', 'birthdate': '1888-08-10', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Sven Fagrell', 'birthdate': '1891-01-26', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Stig Erik Falk', 'birthdate': '1945-12-27', 'birthplace': None, 'position': 'anfallare', 'last_season': '1971'}
# {'fullname': 'Tage Lennart Falkenström', 'birthdate': '1926-05-23', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Alexander Daniel Faltsetas', 'birthdate': '1987-07-04', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2011'}
# {'fullname': 'Alexander Hans Christian Farnerud', 'birthdate': '1984-05-01', 'birthplace': None, 'position': 'anfallare', 'last_season': '2020'}
# {'fullname': 'Hans Pontus Farnerud', 'birthdate': '1980-06-04', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2013'}
# {'fullname': 'Nils Axel Emanuel Färnström', 'birthdate': '1925-11-20', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Emil Carl Olof Fasth', 'birthdate': '2008-05-05', 'birthplace': None, 'position': 'försvarare', 'last_season': None}
# {'fullname': 'Reine Arnold Feldt', 'birthdate': '1945-09-29', 'birthplace': None, 'position': 'mittfältare', 'last_season': None}
# {'fullname': 'Max Johannes Whitta Fenger', 'birthdate': '2001-08-07', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Gunnar Roland Ferm', 'birthdate': '1938-03-10', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Bo Lars Åke Fernell', 'birthdate': '1943-10-10', 'birthplace': None, 'position': None, 'last_season': '1968'}
# {'fullname': 'Yaqub Hassan Muse Finey', 'birthdate': '2003-09-24', 'birthplace': None, 'position': 'anfallare', 'last_season': '2022'}
# {'fullname': 'Hugo Lennart Flink', 'birthdate': '1927-08-31', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Rolf Werner Douglas Flobrant', 'birthdate': '1950-08-27', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1973'}
# {'fullname': 'Johan Peter Flykt-Rosén', 'birthdate': '1974-04-28', 'birthplace': None, 'position': 'försvarare', 'last_season': '1993'}
# {'fullname': 'Carl Fredrik Stefan Folcker', 'birthdate': '1964-01-30', 'birthplace': None, 'position': 'försvarare', 'last_season': '1983'}
# {'fullname': 'Stig Bertil Forsberg', 'birthdate': '1952-05-20', 'birthplace': None, 'position': 'anfallare', 'last_season': '1973'}
# {'fullname': 'Karl Gunnar Osvald Forsberg', 'birthdate': '1911-03-17', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Leif Folke Enar Forsberg', 'birthdate': '1963-04-15', 'birthplace': None, 'position': 'anfallare', 'last_season': '1989'}
# {'fullname': 'José Carlos Fortes', 'birthdate': '1968-03-20', 'birthplace': None, 'position': None, 'last_season': '1988'}
# {'fullname': 'Folke Potens Manne Gottfrid Franzén', 'birthdate': '1888-02-05', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': None, 'birthdate': None, 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Stig Daniel Fredriksson', 'birthdate': '1956-03-06', 'birthplace': None, 'position': 'försvarare', 'last_season': '1988'}
# {'fullname': 'Gustaf Harry Friberg', 'birthdate': '1904-02-04', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Sven Richard Friberg', 'birthdate': '1895-02-07', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Per Olof Frise', 'birthdate': '1893-12-06', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Dan Nils-Olov Fröberg', 'birthdate': '1964-08-13', 'birthplace': None, 'position': 'anfallare', 'last_season': '1988'}
# {'fullname': 'Otto Niclas Galle', 'birthdate': '1973-08-31', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1993'}
# {'fullname': 'Stephen David Gardner', 'birthdate': '1958-10-07', 'birthplace': None, 'position': 'anfallare', 'last_season': '1984'}
# {'fullname': 'Rolf Henry Gedda', 'birthdate': '1908-08-21', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Ali Ngon Gerba', 'birthdate': '1981-09-04', 'birthplace': None, 'position': 'anfallare', 'last_season': '2007'}
# {'fullname': 'Mats Gösta Gerdtham', 'birthdate': '1952-07-15', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1976'}
# {'fullname': 'Nordin Gerzic', 'birthdate': '1983-11-09', 'birthplace': None, 'position': 'anfallare', 'last_season': '2014'}
# {'fullname': 'Alai Hussain Ghasem', 'birthdate': '2003-02-16', 'birthplace': None, 'position': None, 'last_season': '2024'}
# {'fullname': 'Gillis Valerius Gillås', 'birthdate': '1895-02-20', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Erik Allan Glader', 'birthdate': '1920-02-02', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Arne Vilgott Göransson', 'birthdate': '1918-01-30', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Kurt Egon Verner Göransson', 'birthdate': '1928-11-30', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Knut Evert Grahn', 'birthdate': '1921-05-21', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Erik Gustaf Valfrid Granath', 'birthdate': '1910-10-12', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Bo Krister Granbom', 'birthdate': '1941-04-09', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Tryggve Stefan Granqvist', 'birthdate': '1925-12-25', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Olof Bertil Gren', 'birthdate': '1918-12-02', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Johan Gunnar Gren', 'birthdate': '1920-10-31', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Mats Åke Gren', 'birthdate': '1963-12-20', 'birthplace': None, 'position': 'anfallare', 'last_season': '1985'}
# {'fullname': 'Helge Georg Grönwall', 'birthdate': '1929-11-02', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Carl Sune Roland Grundén', 'birthdate': '1942-05-30', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Hans Erik Gunnarsson', 'birthdate': '1999-02-08', 'birthplace': None, 'position': None, 'last_season': '2019'}
# {'fullname': 'Fritz Ingvar Hilding Gunnesson', 'birthdate': '1921-11-09', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Gustaf Torvald Gustafsson', 'birthdate': '1902-11-06', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Erik Joel Gustafsson', 'birthdate': '1986-09-24', 'birthplace': None, 'position': None, 'last_season': '2005'}
# {'fullname': 'Per Magnus Gustafsson', 'birthdate': '1967-01-24', 'birthplace': None, 'position': 'anfallare', 'last_season': '1995'}
# {'fullname': 'Steve Oskar Robert Gustafsson', 'birthdate': '1988-02-22', 'birthplace': None, 'position': None, 'last_season': '2007'}
# {'fullname': None, 'birthdate': None, 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Stig Gustaf Gustafsson', 'birthdate': '1931-09-15', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Åke Yngve Gustavsson', 'birthdate': '1935-03-10', 'birthplace': None, 'position': None, 'last_season': '1963'}
# {'fullname': 'David Fausto Gutierrez Arvidsson', 'birthdate': '1994-10-20', 'birthplace': None, 'position': 'försvarare', 'last_season': '2014'}
# {'fullname': 'Olof Einar Haak', 'birthdate': '1901-04-15', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Jan Ronald Lennart Hafstrand', 'birthdate': '1944-04-22', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Karl Harry Hagberg', 'birthdate': '1925-11-12', 'birthplace': None, 'position': 'anfallare', 'last_season': None}
# {'fullname': 'Elias Kristoffersen Hagen', 'birthdate': '2000-01-20', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2023'}
# {'fullname': 'Per Ruben Hägglund', 'birthdate': '1951-01-09', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1971'}
# {'fullname': 'Philip Thomas Jesper Haglund', 'birthdate': '1987-03-22', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2014'}
# {'fullname': 'Warner Lloyd Hahn', 'birthdate': '1992-06-15', 'birthplace': None, 'position': 'målvakt', 'last_season': '2022'}
# {'fullname': 'Hans Kim Håkansson', 'birthdate': '1978-08-11', 'birthplace': None, 'position': 'målvakt', 'last_season': '1995'}
# {'fullname': 'Nils Johan Tage Håkansson Lind', 'birthdate': '1891-02-09', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Gustaf Åke Linus Hallman', 'birthdate': '1912-11-12', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Marek Hamšík', 'birthdate': '1987-07-27', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2021'}
# {'fullname': 'Nils Harry Hansén', 'birthdate': '1920-04-18', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Åke Rolf Hansson', 'birthdate': '1903-04-16', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Gustaf Henry Hansson', 'birthdate': '1924-05-02', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Holger Valdemar Hansson', 'birthdate': '1927-01-26', 'birthplace': None, 'position': 'mittfältare', 'last_season': None}
# {'fullname': None, 'birthdate': None, 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Erik Per Olof Hansson', 'birthdate': '1932-03-24', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Jan Thomas Hansson', 'birthdate': '1962-08-23', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Karl Viktor Hansson', 'birthdate': '1893-08-26', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Jasin Hasani', 'birthdate': '2003-12-28', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2024'}
# {'fullname': 'Sebastian Lund Hausner', 'birthdate': '2000-04-11', 'birthplace': None, 'position': None, 'last_season': '2024'}
# {'fullname': 'Yngve Rudolf Hedelin', 'birthdate': '1909-03-27', 'birthplace': None, 'position': None, 'last_season': None}
# ...
# {'fullname': 'Einar Harald Smith', 'birthdate': '1929-03-24', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Daniel Lopes da Silva', 'birthdate': '1983-02-10', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2014'}
# {'fullname': 'Robin Mikael Söder', 'birthdate': '1991-04-01', 'birthplace': None, 'position': 'anfallare', 'last_season': '2021'}
# {'fullname': 'Ole Petter Söderberg', 'birthdate': '1990-07-20', 'birthplace': None, 'position': 'målvakt', 'last_season': '2021'}
# {'fullname': 'Oskar Daniel Söderberg', 'birthdate': '1892-12-02', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Oskar Algot Söderqvist', 'birthdate': '1890-10-29', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Erik Sorga', 'birthdate': '1999-07-08', 'birthplace': None, 'position': 'anfallare', 'last_season': '2022'}
# {'fullname': 'Moses Ssewankambo', 'birthdate': '1988-07-26', 'birthplace': None, 'position': 'anfallare', 'last_season': '2006'}
# {'fullname': 'Sven Edvard Helge Ståhlfors', 'birthdate': '1899-09-14', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Karl Torsten Valdemar Ståhlfors', 'birthdate': '1894-09-14', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Carl Anders Theodor Starfelt', 'birthdate': '1995-06-01', 'birthplace': None, 'position': None, 'last_season': '2019'}
# {'fullname': 'David Johan Christer Stenman', 'birthdate': '1988-10-08', 'birthplace': None, 'position': 'målvakt', 'last_season': '2008'}
# {'fullname': 'Sven Börje Stensson', 'birthdate': '1955-09-23', 'birthplace': None, 'position': 'målvakt', 'last_season': '1974'}
# {'fullname': 'Hannes Stiller', 'birthdate': '1978-07-03', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2013'}
# {'fullname': 'Zoran Stojcevski', 'birthdate': '1971-03-04', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1993'}
# {'fullname': 'John Olof Natanael Stolt', 'birthdate': '1897-10-11', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': None, 'birthdate': None, 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Glenn Peter Strömberg', 'birthdate': '1960-01-05', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1982'}
# {'fullname': 'Kjell Gunnar Sundh', 'birthdate': '1950-06-21', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1974'}
# {'fullname': 'Nils Kenneth Sundin', 'birthdate': '1959-04-23', 'birthplace': None, 'position': 'försvarare', 'last_season': '1978'}
# {'fullname': 'Verner Napoleon Sundvall', 'birthdate': '1899-06-19', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Gösta Allan Svantesson', 'birthdate': '1928-06-01', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Ulf Bjarne Svärd', 'birthdate': '1948-12-07', 'birthplace': None, 'position': 'anfallare', 'last_season': '1969'}
# {'fullname': 'Erik Peter Tommy Svärdegård', 'birthdate': '1958-02-25', 'birthplace': None, 'position': 'anfallare', 'last_season': '1976'}
# {'fullname': None, 'birthdate': None, 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': None, 'birthdate': None, 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Göte Ingvald Svensson', 'birthdate': '1933-09-17', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Karl Gustav Johan Svensson', 'birthdate': '1987-02-07', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2025'}
# {'fullname': 'Göran Harry Svensson', 'birthdate': '1945-06-11', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1971'}
# {'fullname': 'Karl Olof Henning Svensson', 'birthdate': '1891-10-13', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Bernt Ingvar Svenson', 'birthdate': '1939-12-16', 'birthplace': None, 'position': 'anfallare', 'last_season': '1968'}
# {'fullname': 'Sten Jan-Åke Svensson', 'birthdate': '1947-02-24', 'birthplace': None, 'position': 'anfallare', 'last_season': '1973'}
# {'fullname': 'Oskar Jonathan Svensson', 'birthdate': '1988-12-11', 'birthplace': None, 'position': 'försvarare', 'last_season': '2007'}
# {'fullname': 'Karl Svensson', 'birthdate': '1984-03-21', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2011'}
# {'fullname': None, 'birthdate': None, 'birthplace': None, 'position': 'mittfältare', 'last_season': None}
# {'fullname': 'Mats Åke Svensson', 'birthdate': '1940-03-13', 'birthplace': None, 'position': None, 'last_season': '1964'}
# {'fullname': 'Mats Ola Oldin Svensson', 'birthdate': '1964-04-06', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1994'}
# {'fullname': 'Ragnar Emil Bertil Svensson', 'birthdate': '1902-08-12', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Erik Ruben Svensson', 'birthdate': '1953-09-28', 'birthplace': None, 'position': 'försvarare', 'last_season': '1986'}
# {'fullname': 'Sami Valentin Svensson', 'birthdate': '1931-06-07', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Torsten Roland Svensson', 'birthdate': '1901-10-08', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Gillis Urban Svensson', 'birthdate': '1909-12-01', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Gösta Valdemar Swerin', 'birthdate': '1920-04-21', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Gerhard Clarence Täll', 'birthdate': '1925-09-24', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'John Olof Albert Tell', 'birthdate': '1892-06-16', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Björn Ove Tengberg', 'birthdate': '1961-07-28', 'birthplace': None, 'position': 'målvakt', 'last_season': '1979'}
# {'fullname': 'Jan Tengwall', 'birthdate': '1982-03-18', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2002'}
# {'fullname': 'Emmanuel Tetteh', 'birthdate': '1974-12-25', 'birthplace': None, 'position': 'anfallare', 'last_season': '1999'}
# {'fullname': 'Erik Lennart Thelander', 'birthdate': '1925-01-17', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Hans Ove Thelin', 'birthdate': '1929-04-09', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Johan Simon Thern', 'birthdate': '1992-09-18', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2023'}
# {'fullname': 'Kolbeinn Þórðarson', 'birthdate': '2000-03-12', 'birthplace': None, 'position': 'mittfältare', 'last_season': None}
# {'fullname': 'Fredrik Olof Thorén', 'birthdate': '1983-09-09', 'birthplace': None, 'position': 'försvarare', 'last_season': '2003'}
# {'fullname': 'Oliver Lennart Thoreson', 'birthdate': '2006-02-05', 'birthplace': None, 'position': 'försvarare', 'last_season': None}
# {'fullname': 'Karl Fredrik Valdemar Thorin', 'birthdate': '1904-05-30', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Torsten Odd Thorstenson', 'birthdate': '1888-07-22', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Erik Thorstvedt', 'birthdate': '1962-10-28', 'birthplace': None, 'position': 'målvakt', 'last_season': '1988'}
# {'fullname': 'Carl Olof Thunberg', 'birthdate': '1922-05-11', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': None, 'birthdate': None, 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Adil Titi', 'birthdate': '1999-08-20', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2021'}
# {'fullname': 'Lars Ove Tobiasson', 'birthdate': '1962-10-27', 'birthplace': None, 'position': 'målvakt', 'last_season': '1987'}
# {'fullname': 'Nzuzi Bundebele Toko', 'birthdate': '1990-11-20', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2020'}
# {'fullname': 'Noah Klas Tolf', 'birthdate': '2005-08-13', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Jesper Mikael Tolinsson', 'birthdate': '2003-02-28', 'birthplace': None, 'position': None, 'last_season': '2021'}
# {'fullname': 'Konrad Emanuel Törnqvist', 'birthdate': '1888-07-17', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Lars Roland Torstensson', 'birthdate': '1961-09-03', 'birthplace': None, 'position': 'målvakt', 'last_season': '1980'}
# {'fullname': 'Arne Gösta Valter Tranberg', 'birthdate': '1914-10-05', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Anders Trondsen', 'birthdate': '1995-03-30', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2025'}
# {'fullname': 'Tuomo Turunen', 'birthdate': '1987-08-30', 'birthplace': None, 'position': None, 'last_season': '2010'}
# {'fullname': 'Jens Vilmer Tyrén', 'birthdate': '2005-05-03', 'birthplace': None, 'position': 'mittfältare', 'last_season': None}
# {'fullname': 'Eric Verner Uhlén', 'birthdate': '1897-01-12', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Erik Martin Ulander', 'birthdate': '1976-02-23', 'birthplace': None, 'position': None, 'last_season': '2005'}
# {'fullname': 'Hjörtur Logi Valgardsson', 'birthdate': '1988-09-27', 'birthplace': None, 'position': None, 'last_season': '2013'}
# {'fullname': 'Tim Johannes Barend Aloysius van Assema', 'birthdate': '2002-01-31', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2022'}
# {'fullname': 'Andrés Javier Vasquez Rueda Pinto', 'birthdate': '1987-07-16', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2007'}
# {'fullname': 'Per Magnus Verdin', 'birthdate': '1970-04-24', 'birthplace': None, 'position': 'målvakt', 'last_season': '1990'}
# {'fullname': 'Lasse Vibe', 'birthdate': '1987-02-22', 'birthplace': None, 'position': 'anfallare', 'last_season': '2019'}
# {'fullname': 'Jan Robert Vilahamn', 'birthdate': '1983-01-02', 'birthplace': None, 'position': 'anfallare', 'last_season': '2003'}
# {'fullname': 'Bernardo Vilar Estevão Jeronimo', 'birthdate': '1998-02-12', 'birthplace': None, 'position': None, 'last_season': '2022'}
# {'fullname': 'Oscar Ingemar Kristoffer Vilhelmsson', 'birthdate': '2003-10-02', 'birthplace': None, 'position': 'anfallare', 'last_season': '2022'}
# {'fullname': 'Erik Valdemar Vingner', 'birthdate': '1894-02-08', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Ulf Erik Wahlstedt', 'birthdate': '1976-04-16', 'birthplace': None, 'position': 'anfallare', 'last_season': '1996'}
# {'fullname': 'Anders Jonas Wallerstedt', 'birthdate': '1978-03-18', 'birthplace': None, 'position': 'anfallare', 'last_season': '2008'}
# {'fullname': 'Bror Justus Wallin', 'birthdate': '1889-09-02', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Jan Erik Wallin', 'birthdate': '1970-04-23', 'birthplace': None, 'position': None, 'last_season': '1990'}
# {'fullname': 'Lennart Wallin', 'birthdate': '1942-09-29', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1974'}
# {'fullname': 'Nils Holger Wallin', 'birthdate': '1913-10-08', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Viktor Hugo Wallin', 'birthdate': '1911-12-30', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Karl Erik Sixten Wallman', 'birthdate': '1915-08-06', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Nils Stefan Wättring', 'birthdate': '1953-11-09', 'birthplace': None, 'position': 'försvarare', 'last_season': '1974'}
# {'fullname': 'Jake Jeffrey Weisbrod', 'birthdate': '2000-05-14', 'birthplace': None, 'position': 'försvarare', 'last_season': '2019'}
# {'fullname': 'Åke Joakim Wendt', 'birthdate': '1958-06-24', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1981'}
# {'fullname': 'Leif Hans Erik Wendt', 'birthdate': '1936-03-07', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Leif Gunnar Sigurd Wendt', 'birthdate': '1942-03-05', 'birthplace': None, 'position': None, 'last_season': '1964'}
# {'fullname': 'Oscar Joakim Wendt', 'birthdate': '1985-10-24', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2024'}
# {'fullname': 'Nils Gunnar Stellan Wenzel', 'birthdate': '1898-09-27', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Nils Holger Wenzel', 'birthdate': '1914-03-30', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Gösta Elof Rune Wenzel', 'birthdate': '1901-01-04', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Pontus Anders Mikael Wernbloom', 'birthdate': '1986-06-25', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2021'}
# {'fullname': 'Tor Gustaf Bernhard Werner', 'birthdate': '1911-11-27', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Lars Sivert Werner', 'birthdate': '1935-11-22', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Thomas Eric Ivar Wernersson', 'birthdate': '1955-06-15', 'birthplace': None, 'position': 'målvakt', 'last_season': '1989'}
# {'fullname': 'Victor Christoffer Wernersson', 'birthdate': '1995-07-06', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2020'}
# {'fullname': 'Gustaf Daniel Westlin', 'birthdate': '1980-01-24', 'birthplace': None, 'position': 'anfallare', 'last_season': '2002'}
# {'fullname': 'Knut Gustav Westlund', 'birthdate': '1904-05-12', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Tonie Einar Wiklander', 'birthdate': '1945-04-04', 'birthplace': None, 'position': 'målvakt', 'last_season': '1972'}
# {'fullname': 'Bengt Kenneth Östen Wikström', 'birthdate': '1940-05-08', 'birthplace': None, 'position': 'målvakt', 'last_season': None}
# {'fullname': 'Rasmus Erik Wikström', 'birthdate': '2001-03-18', 'birthplace': None, 'position': None, 'last_season': '2021'}
# {'fullname': 'Axel Per Wingård', 'birthdate': '1982-02-02', 'birthplace': None, 'position': None, 'last_season': '2002'}
# {'fullname': 'Samuel Kwicompae Wowoah', 'birthdate': '1976-06-17', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2006'}
# {'fullname': 'Carl Magnus Wygler', 'birthdate': '1978-06-05', 'birthplace': None, 'position': None, 'last_season': '1999'}
# {'fullname': 'Kjetil Wæhler', 'birthdate': '1976-03-16', 'birthplace': None, 'position': None, 'last_season': '2014'}
# {'fullname': 'Kevin Enkido Yakob', 'birthdate': '2000-10-10', 'birthplace': None, 'position': 'anfallare', 'last_season': '2022'}
# {'fullname': 'Malick Junior Yalcouyé', 'birthdate': '2005-11-01', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2024'}
# {'fullname': 'Rockson Yeboah', 'birthdate': '2004-08-02', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Alhassan Yusuf Abdullahi', 'birthdate': '2000-07-18', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2021'}
# {'fullname': 'Gunnar Henry Zacharoff', 'birthdate': '1902-01-06', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Harry Zacharias Zachrisson', 'birthdate': '1906-06-21', 'birthplace': None, 'position': None, 'last_season': None}
# {'fullname': 'Karl Hampus Zackrisson', 'birthdate': '1994-08-24', 'birthplace': None, 'position': 'mittfältare', 'last_season': '2014'}
# {'fullname': 'Benjamin Yapi Zalo', 'birthdate': '1998-02-19', 'birthplace': None, 'position': 'försvarare', 'last_season': '2017'}
# {'fullname': 'Lars Åke Zetterlund', 'birthdate': '1964-02-11', 'birthplace': None, 'position': 'mittfältare', 'last_season': '1989'}
# {'fullname': 'Walker Dwain Zimmerman', 'birthdate': '1993-05-19', 'birthplace': None, 'position': 'försvarare', 'last_season': '2016'}
# {'fullname': 'Albin Kenneth Dahrup Zohore', 'birthdate': '1994-01-31', 'birthplace': None, 'position': 'anfallare', 'last_season': '2014'}
# Wikidata entries: 589
# Matchade: 586
# Saknas: 427
# CSV skapad: ifkdb_mixnmatch.csv

# %%
matched.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1013 entries, 0 to 1012
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   full_id      1013 non-null   object
#  1   numeric_id   1013 non-null   object
#  2   name         1013 non-null   object
#  3   fullname     957 non-null    object
#  4   birthdate    955 non-null    object
#  5   birthplace   0 non-null      object
#  6   position     559 non-null    object
#  7   last_season  505 non-null    object
#  8   item         586 non-null    object
#  9   desc         1013 non-null   object
#  10  type         1013 non-null   object
#  11  q            586 non-null    object
#  12  descEn       1013 non-null   object
# dtypes: object(13)
# memory usage: 103.0+ KB

# %%
position_map = {
    "försvarare": "defender",
    "mittfältare": "midfielder",
    "målvakt": "goalkeeper",
    "anfallare" : "attacker"
}

def make_descEn(row):

    parts = []

    # Full name
    if pd.notna(row["fullname"]):
        parts.append(row["fullname"])

    # Birthdate
    if pd.notna(row["birthdate"]):
        parts.append(f"(born {row['birthdate']})")

    # Position translation
    pos = None
    if pd.notna(row["position"]):
        pos = position_map.get(row["position"].lower(), row["position"])

    # Football info
    if pos and pd.notna(row["last_season"]):
        parts.append(f"{pos} in IFK Göteborg, last season {row['last_season']}")
    elif pd.notna(row["last_season"]):
        parts.append(f"IFK Göteborg player, last season {row['last_season']}")
    else:
        parts.append("IFK Göteborg player stated in ifkdb.se")

    return " ".join(parts)

matched["descEn"] = matched.apply(make_descEn, axis=1)

dfMixEn = matched[["full_id", "name", "descEn", "type", "q"]].rename(columns={
    "full_id": "id",
    "descEn": "desc"
})

fileEncsv = "ifkdb_mixnmatch_en_v2.csv"
dfMixEn.to_csv(fileEncsv, index=False, encoding="utf-8")

print(f"CSV skapad: {fileEncsv}")
# Out:
# CSV skapad: ifkdb_mixnmatch_en_v2.csv

# %%
dfMixEn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1013 entries, 0 to 1012
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      1013 non-null   object
#  1   name    1013 non-null   object
#  2   desc    1013 non-null   object
#  3   type    1013 non-null   object
#  4   q       586 non-null    object
# dtypes: object(5)
# memory usage: 39.7+ KB

# %%
# --------------------------------------------------
# 6. AVANCERAD HTML-RAPPORT
# --------------------------------------------------

import urllib.parse

total = len(matched)
matched_count = matched["item"].notna().sum()
unmatched = matched[matched["item"].isna()].copy()
unmatched_count = len(unmatched)

match_percent = round((matched_count / total) * 100, 2)

print("Totalt:", total)
print("Matchade:", matched_count)
print("Saknade:", unmatched_count)


# --------------------------------------------------
# DUBBELTTEST (samma namn flera gånger i IFKDB)
# --------------------------------------------------

name_counts = matched["name"].value_counts()
duplicate_names = set(name_counts[name_counts > 1].index)

unmatched["duplicate"] = unmatched["name"].isin(duplicate_names)

# --------------------------------------------------
# SKAPA LÄNKER
# --------------------------------------------------

unmatched["ifkdb_url"] = (
    "https://ifkdb.se/spelare/" + unmatched["full_id"]
)

unmatched["wd_search"] = unmatched["name"].apply(
    lambda n: "https://www.wikidata.org/w/index.php?search=" +
              urllib.parse.quote(n)
)

# --------------------------------------------------
# GENERERA HTML
# --------------------------------------------------

html = f"""
<!DOCTYPE html>
<html>
<head>
<meta charset="UTF-8">
<title>IFKDB – Wikidata matchrapport</title>

<style>
body {{ font-family: Arial, sans-serif; }}
table {{ border-collapse: collapse; width: 100%; }}
th, td {{ border: 1px solid #ccc; padding: 6px; }}
th {{ background-color: #f2f2f2; cursor: pointer; }}
tr:nth-child(even) {{ background-color: #f9f9f9; }}
.duplicate {{ background-color: #ffe0e0; }}
.summary {{ margin-bottom: 20px; }}
a {{ text-decoration: none; color: #0645AD; }}
</style>

<script>
// Enkel tabellsortering
function sortTable(n) {{
  var table = document.getElementById("reportTable");
  var rows = Array.from(table.rows).slice(1);
  var asc = table.getAttribute("data-sort") !== "asc";
  rows.sort(function(a, b) {{
    var x = a.cells[n].innerText.toLowerCase();
    var y = b.cells[n].innerText.toLowerCase();
    return asc ? x.localeCompare(y) : y.localeCompare(x);
  }});
  table.setAttribute("data-sort", asc ? "asc" : "desc");
  rows.forEach(row => table.appendChild(row));
}}
</script>

</head>
<body>

<h2>IFKDB → Wikidata matchrapport</h2>

<div class="summary">
<p><strong>Totalt:</strong> {total}</p>
<p><strong>Matchade:</strong> {matched_count}</p>
<p><strong>Saknade:</strong> {unmatched_count}</p>
<p><strong>Matchningsgrad:</strong> {match_percent}%</p>
<p><strong>GitHub Issue:</strong>
<a href="https://github.com/salgo60/ifkdb/issues/32" target="_blank">
Issue #32
</a></p>
</div>

<table id="reportTable" data-sort="asc">
<tr>
<th onclick="sortTable(0)">ID</th>
<th onclick="sortTable(1)">Namn</th>
<th>IFKDB</th>
<th>Wikidata-sök</th>
</tr>
"""

for _, row in unmatched.iterrows():

    duplicate_class = "duplicate" if row["duplicate"] else ""

    html += f"""
<tr class="{duplicate_class}">
<td>{row['full_id']}</td>
<td>{row['name']}</td>
<td><a href="{row['ifkdb_url']}" target="_blank">Öppna</a></td>
<td><a href="{row['wd_search']}" target="_blank">Sök</a></td>
</tr>
"""

html += """
</table>

<p style="margin-top:20px;">
Röd markering = potentiell namndubblett i IFKDB.
</p>

</body>
</html>
"""

with open("ifkdb_wikidata_report.html", "w", encoding="utf-8") as f:
    f.write(html)

print("HTML-rapport skapad: ifkdb_wikidata_report.html")
# Out:
# Totalt: 1013
# Matchade: 579
# Saknade: 434
# HTML-rapport skapad: ifkdb_wikidata_report.html

# %%
# End timer
end_time = datetime.now()
duration = end_time - start_time

print("\n--- Execution Summary ---")
print(f"End time:      {end_time:%Y-%m-%d %H:%M:%S}")
print(f"Duration:      {duration}")
print(f"Total seconds: {duration.total_seconds():.2f}")
print(f"Python ver:    {sys.version.split()[0]}")
print(f"Platform:      {platform.system()} {platform.release()}")
print(f"Process ID:    {os.getpid()}")
# Out:
# --- Execution Summary ---
# End time:      2026-03-03 16:52:05
# Duration:      0:00:02.272284
# Total seconds: 2.27
# Python ver:    3.12.2
# Platform:      Darwin 25.3.0
# Process ID:    57438
