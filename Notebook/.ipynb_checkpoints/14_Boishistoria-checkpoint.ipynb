# %% [markdown]
# * [#14](https://github.com/salgo60/ifkdb/issues/14) Boishistoria
# * Notebook [14_Boishistoria.ipynb](https://github.com/salgo60/ifkdb/blob/main/Notebook/14_Boishistoria.ipynb)

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2026-03-28 08:12:46.087315

# %%
import requests

url = "https://boishistoria.se/wp/wp-admin/admin-ajax.php"

payload = {
    "action": "REPLACE_WITH_REAL_ACTION",
    # ev. fler parametrar som paged=1, letter=A etc
}

headers = {
    "User-Agent": "Mozilla/5.0",
    "X-Requested-With": "XMLHttpRequest",
}

r = requests.post(url, data=payload, headers=headers)

print("Status:", r.status_code)
print("Length:", len(r.text))

# Spara för inspektion
with open("bois_raw.html", "w", encoding="utf-8") as f:
    f.write(r.text)
# Out:
# Status: 400
# Length: 1

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(r.text, "html.parser")

players = []

for a in soup.find_all("a"):
    name = a.get_text(strip=True)
    if name:
        players.append(name)

print("Antal:", len(players))
players[:20]
# Out:
# Antal: 0
# []

# %%
import requests

url = "https://boishistoria.se/wp/wp-admin/admin-ajax.php"

payload = {
    "action": "bois_historia",
    "security": "db140b297c",
    "params[0][name]": "sortera",
    "params[0][value]": "efternamn",
    "params[1][name]": "namn",
    "params[1][value]": "",
    "params[2][name]": "aktiv",
    "params[2][value]": "1915,2026",
    "params[3][name]": "fodd",
    "params[3][value]": "1889,2026",
    "params[4][name]": "vad",
    "params[4][value]": "spelare",
    "params[5][name]": "link",
    "params[5][value]": "visa-data",
}

headers = {
    "User-Agent": "Mozilla/5.0",
    "X-Requested-With": "XMLHttpRequest",
    "Referer": "https://boishistoria.se/spelare/"
}

r = requests.post(url, data=payload, headers=headers)

print("Status:", r.status_code)
print("Length:", len(r.text))
print(r.text[:1000])
# Out:
# Status: 200
# Length: 100971
# <!-- Sökning efter spelare (incs/sok_spelare.php)(1) -->
# <!-- Sökning efter spelare (incs/sok_spelare.php)(2) -->
# ...

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(r.text, "html.parser")

players = []

# Justera selektor efter hur HTML faktiskt ser ut
for a in soup.find_all("a"):
    name = a.get_text(strip=True)
    if name:
        players.append(name)

print("Antal spelare:", len(players))
players[:20]
# Out:
# Antal spelare: 967
# ['Abo-Shark, Mohamed',
#  'Adelstam, Mattias',
#  'Afzelius, Jan',
#  'Aganovic, Admir',
#  'Aguiar, Fernando',
#  'Ahl, Fredrik',
#  'Ahmetovic, Enis',
#  'Ahnelöv, Sten',
#  'Ajakpoloho, Christian',
#  'Akpoveta, Ojevwe',
#  'al Kurdi, Raslan',
#  'Al-Karkhi, Ramy',
#  'Albrechtsson, Gunnar',
#  'Alcalde Tieles, Donato "Tati"',
#  'Algerbo, Lars-Göran',
#  'Alin, Kevin',
#  'Alm, Lars',
#  'Alm, Rasmus',
#  'Alm, Simon',
#  'Almadjed, Sumar']

# %%
len(players), len(set(players))
# Out:
# (967, 960)

# %%
from bs4 import BeautifulSoup
from urllib.parse import urljoin, parse_qs, urlparse

base = "https://boishistoria.se"

soup = BeautifulSoup(r.text, "html.parser")

players = []

for a in soup.find_all("a", href=True):
    href = a["href"]
    if "what=spelare" in href:
        name = a.get_text(strip=True)
        
        # extrahera id
        parsed = urlparse(href)
        qs = parse_qs(parsed.query)
        player_id = qs.get("id", [None])[0]

        players.append({
            "name": name,
            "id": player_id,
            "url": urljoin(base, href)
        })

len(players), players[:5]
# Out:
# (967,
#  [{'name': 'Abo-Shark, Mohamed',
#    'id': '569',
#    'url': 'https://boishistoria.se/visa-data/?what=spelare&id=569&link=visa-data'},
#   {'name': 'Adelstam, Mattias',
#    'id': '549',
#    'url': 'https://boishistoria.se/visa-data/?what=spelare&id=549&link=visa-data'},
#   {'name': 'Afzelius, Jan',
#    'id': '347',
#    'url': 'https://boishistoria.se/visa-data/?what=spelare&id=347&link=visa-data'},
#   {'name': 'Aganovic, Admir',
#    'id': '6',
#    'url': 'https://boishistoria.se/visa-data/?what=spelare&id=6&link=visa-data'},
#   {'name': 'Aguiar, Fernando',
#    'id': '211',
#    'url': 'https://boishistoria.se/visa-data/?what=spelare&id=211&link=visa-data'}])

# %%
import requests
from bs4 import BeautifulSoup

def fetch_birthdate(player):
    r = requests.get(player["url"])
    soup = BeautifulSoup(r.text, "html.parser")
    
    strong = soup.find("strong", string="Född:")
    if strong:
        td = strong.find_parent("td").find_next_sibling("td")
        if td:
            return td.get_text(strip=True)
    
    return None

# testa första spelaren
test = players[0]
birth = fetch_birthdate(test)
print(test["name"], birth)
# Out:
# Abo-Shark, Mohamed 1994-01-29

# %%
import json
import os
import time

CACHE_FILE = "bois_birth_cache.json"
rerunBOIS = False   # <-- sätt True om du vill tvinga omkörning

if os.path.exists(CACHE_FILE) and not rerunBOIS:
    with open(CACHE_FILE, "r", encoding="utf-8") as f:
        birth_cache = json.load(f)
    print("Cache laddad:", len(birth_cache), "poster")
else:
    birth_cache = {}
    print("Ny cache startad")
# Out:
# Cache laddad: 967 poster

# %%
for i, p in enumerate(players):
    
    pid = p["id"]
    
    # Om finns i cache → använd den
    if pid in birth_cache and not rerunBOIS:
        p["birth"] = birth_cache[pid]
        continue
    
    try:
        birth = fetch_birthdate(p)
        p["birth"] = birth
        birth_cache[pid] = birth
        
        time.sleep(0.3)
        
    except Exception:
        p["birth"] = None
        birth_cache[pid] = None
    
    # Spara cache var 50:e spelare
    if i % 50 == 0:
        with open(CACHE_FILE, "w", encoding="utf-8") as f:
            json.dump(birth_cache, f, ensure_ascii=False, indent=2)
        print("Processed", i)

# Slutsparning
with open(CACHE_FILE, "w", encoding="utf-8") as f:
    json.dump(birth_cache, f, ensure_ascii=False, indent=2)

print("Klar. Totalt spelare:", len(players))
# Out:
# Klar. Totalt spelare: 967

# %%
players
# Out:
# [{'name': 'Abo-Shark, Mohamed',
#   'id': '569',
#   'url': 'https://boishistoria.se/visa-data/?what=spelare&id=569&link=visa-data',
#   'birth': '1994-01-29'},
#  {'name': 'Adelstam, Mattias',
#   'id': '549',
#   'url': 'https://boishistoria.se/visa-data/?what=spelare&id=549&link=visa-data',
#   'birth': '1982-03-07'},
#  {'name': 'Afzelius, Jan',
#   'id': '347',
#   'url': 'https://boishistoria.se/visa-data/?what=spelare&id=347&link=visa-data',
#   'birth': '1952-03-02'},
#  {'name': 'Aganovic, Admir',
#   'id': '6',
#   'url': 'https://boishistoria.se/visa-data/?what=spelare&id=6&link=visa-data',
#   'birth': '1986-08-25'},
#  {'name': 'Aguiar, Fernando',
#   'id': '211',
#   'url': 'https://boishistoria.se/visa-data/?what=spelare&id=211&link=visa-data',
#   'birth': '1972-03-18'},
#  {'name': 'Ahl, Fredrik',
#   'id': '221',
#   'url': 'https://boishistoria.se/visa-data/?what=spelare&id=221&link=visa-data',
#   'birth': '1987-06-08'},
#  {'name': 'Ahmetovic, Enis',
# ...

# %%
# Hämta WD
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

query = """
SELECT ?item ?itemLabel ?birth ?death WHERE {
  # ?item wdt:P54 wd:Q863273 .
  OPTIONAL { ?item wdt:P569 ?birth . }
  OPTIONAL { ?item wdt:P570 ?death . }
  SERVICE wikibase:label {
    bd:serviceParam wikibase:language "sv,en,mul" .
  }
}
"""

sparql.setQuery(query)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

wd_players = []

for r in results["results"]["bindings"]:
    wd_players.append({
        "qid": r["item"]["value"].split("/")[-1],
        "name": r["itemLabel"]["value"],
        "birth": r.get("birth", {}).get("value"),
        "death": r.get("death", {}).get("value")
    })

len(wd_players), wd_players[:5]
# Out:
# (283,
#  [{'qid': 'Q30064081',
#    'name': 'Melvin Frithzell',
#    'birth': '1996-08-09T00:00:00Z',
#    'death': None},
#   {'qid': 'Q30586199',
#    'name': 'Alfons Sampsted',
#    'birth': '1998-04-06T00:00:00Z',
#    'death': None},
#   {'qid': 'Q30612091',
#    'name': 'Jonathan Levi',
#    'birth': '1996-01-23T00:00:00Z',
#    'death': None},
#   {'qid': 'Q42393771',
#    'name': 'Oscar Petersson',
#    'birth': '1999-02-26T00:00:00Z',
#    'death': None},
#   {'qid': 'Q47506164',
#    'name': 'Nikola Ladan',
#    'birth': '1993-03-15T00:00:00Z',
#    'death': None}])

# %%
#normaliser   
import re

def normalize_bois(name):
    name = re.sub(r'"[^"]+"', '', name)
    name = re.sub(r'\([^)]*\)', '', name)
    name = re.sub(r'\b\d{2,4}\b$', '', name)
    name = name.strip()
    
    if "," in name:
        last, first = name.split(",", 1)
        name = first.strip() + " " + last.strip()
    
    return " ".join(name.split())

bois_clean = []
for p in players:
    bois_clean.append({
        "name": normalize_bois(p["name"]),
        "birth": p.get("birth")
    })

len(bois_clean)
# Out:
# 967

# %%
# matcha   
wd_index = {}
for w in wd_players:
    key = (w["name"], w["birth"])
    wd_index[key] = w["qid"]

matches = []
missing = []

for p in bois_clean:
    key = (p["name"], p["birth"])
    if key in wd_index:
        matches.append(p)
    else:
        missing.append(p)

len(matches), len(missing)
# Out:
# (0, 967)

# %%
# normalisera birth    
from datetime import datetime

def normalize_wd_birth(b):
    if not b:
        return None
    return b[:10]   # snabbaste och säkraste

for w in wd_players:
    w["birth"] = normalize_wd_birth(w["birth"]) 

wd_players[:5]
# Out:
# [{'qid': 'Q30064081',
#   'name': 'Melvin Frithzell',
#   'birth': '1996-08-09',
#   'death': None},
#  {'qid': 'Q30586199',
#   'name': 'Alfons Sampsted',
#   'birth': '1998-04-06',
#   'death': None},
#  {'qid': 'Q30612091',
#   'name': 'Jonathan Levi',
#   'birth': '1996-01-23',
#   'death': None},
#  {'qid': 'Q42393771',
#   'name': 'Oscar Petersson',
#   'birth': '1999-02-26',
#   'death': None},
#  {'qid': 'Q47506164',
#   'name': 'Nikola Ladan',
#   'birth': '1993-03-15',
#   'death': None}]

# %%
wd_index = {
    (w["name"], w["birth"]): w["qid"]
    for w in wd_players
}

matches = []
missing = []

for p in bois_clean:
    key = (p["name"], p["birth"])
    if key in wd_index:
        matches.append(p)
    else:
        missing.append(p)

len(matches), len(missing)
# Out:
# (213, 754)

# %%
bois_clean
# Out:
# [{'name': 'Mohamed Abo-Shark', 'birth': '1994-01-29'},
#  {'name': 'Mattias Adelstam', 'birth': '1982-03-07'},
#  {'name': 'Jan Afzelius', 'birth': '1952-03-02'},
#  {'name': 'Admir Aganovic', 'birth': '1986-08-25'},
#  {'name': 'Fernando Aguiar', 'birth': '1972-03-18'},
#  {'name': 'Fredrik Ahl', 'birth': '1987-06-08'},
#  {'name': 'Enis Ahmetovic', 'birth': '1992-01-26'},
#  {'name': 'Sten Ahnelöv', 'birth': '1926-01-18'},
#  {'name': 'Christian Ajakpoloho', 'birth': '1993-01-01'},
#  {'name': 'Ojevwe Akpoveta', 'birth': '1993-07-15'},
#  {'name': 'Raslan al Kurdi', 'birth': '1989-04-23'},
#  {'name': 'Ramy Al-Karkhi', 'birth': None},
#  {'name': 'Gunnar Albrechtsson', 'birth': '1908-07-08'},
#  {'name': 'Donato Alcalde Tieles', 'birth': '1964-01-22'},
#  {'name': 'Lars-Göran Algerbo', 'birth': '1969-12-07'},
#  {'name': 'Kevin Alin', 'birth': '1996-10-07'},
#  {'name': 'Lars Alm', 'birth': '1954-04-01'},
#  {'name': 'Rasmus Alm', 'birth': '1995-08-17'},
# ...

# %%
# namn matcha   
wd_name_index = {w["name"]: w for w in wd_players}

name_only_matches = []
still_missing = []

for p in bois_clean:
    if p["name"] in wd_name_index:
        name_only_matches.append(p)
    else:
        still_missing.append(p)

len(name_only_matches), len(still_missing)
# Out:
# (239, 728)

# %%
wd_without_birth = [w for w in wd_players if not w["birth"]]
len(wd_without_birth)
# Out:
# 2

# %%
from rapidfuzz import process, fuzz

fuzzy_strict = []
fuzzy_flagged = []

wd_names = [w["name"] for w in wd_players]

for p in still_missing:
    match, score, _ = process.extractOne(
        p["name"],
        wd_names,
        scorer=fuzz.token_sort_ratio
    )
    
    if score >= 92:
        wd_obj = next(w for w in wd_players if w["name"] == match)
        
        if wd_obj["birth"] and p["birth"]:
            if wd_obj["birth"] == p["birth"]:
                fuzzy_strict.append(p)
        else:
            fuzzy_flagged.append(p)

len(fuzzy_strict), len(fuzzy_flagged)
# Out:
# (16, 0)

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.bar(
    ["Exakt", "Namn-only", "Fuzzy säkra", "Saknas WD"],
    [
        len(matches),
        len(name_only_matches),
        len(fuzzy_strict),
        len(still_missing)
    ]
)
plt.xticks(rotation=45)
plt.ylabel("Antal")
plt.show()

# %%
import requests
import time

S = requests.Session()
S.headers.update({
    "User-Agent": "BoIS-POC/1.0 (https://github.com/yourrepo; contact: salgo60@msn.com)"
})

URL = "https://sv.wikipedia.org/w/api.php"

def get_category_members():
    members = []
    
    params = {
        "action": "query",
        "list": "categorymembers",
        "cmtitle": "Kategori:Fotbollsspelare i Landskrona BoIS",
        "cmlimit": "500",
        "format": "json",
        "formatversion": "2"
    }

    while True:
        r = S.get(URL, params=params, timeout=30)
        r.raise_for_status()
        data = r.json()
        
        members.extend(data["query"]["categorymembers"])
        
        if "continue" in data:
            params.update(data["continue"])
            time.sleep(0.5)
        else:
            break

    return members

wiki_members = get_category_members()
wiki_titles = [m["title"] for m in wiki_members]

len(wiki_titles), wiki_titles[:10]
# Out:
# (216,
#  ['Mattias Adelstam',
#   'Admir Aganović',
#   'Fernando Aguiar',
#   'Enis Ahmetovic',
#   'Lars Alm',
#   'Rasmus Alm',
#   'Knut Almqvist (fotbollsspelare)',
#   'Stefan Alvén',
#   'Kevin Amuneke',
#   'John Anderberg'])

# %%
def get_qids(titles):
    qids = {}
    
    for title in titles:
        params = {
            "action": "query",
            "prop": "pageprops",
            "titles": title,
            "format": "json",
            "formatversion": "2"
        }
        
        r = S.get(URL, params=params)
        data = r.json()
        
        pages = data["query"]["pages"]
        if pages and "pageprops" in pages[0]:
            qid = pages[0]["pageprops"].get("wikibase_item")
            if qid:
                qids[title] = qid
        
        time.sleep(0.2)
    
    return qids

wiki_qids = get_qids(wiki_titles)
len(wiki_qids)
# Out:
# 215

# %%
def normalize_wiki(name):
    return " ".join(name.strip().split())

wiki_clean = [normalize_wiki(t) for t in wiki_titles]
len(wiki_clean)
# Out:
# 216

# %%
# Wikipedia vs Wikidata
wd_names_set = set([w["name"] for w in wd_players])
wiki_set = set(wiki_clean)

wiki_not_in_wd = wiki_set - wd_names_set
wd_not_in_wiki = wd_names_set - wiki_set

len(wiki_not_in_wd), len(wd_not_in_wiki)
# Out:
# (34, 98)

# %%
# B) BoIS vs Wikipedia   
# Detta visar hur elitfokuserad Wikipedia är.
bois_set = set([p["name"] for p in bois_clean])

bois_in_wiki = bois_set & wiki_set
bois_not_in_wiki = bois_set - wiki_set

len(bois_in_wiki), len(bois_not_in_wiki)
# Out:
# (156, 775)

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.bar(
    ["BoIS", "Wikidata", "Wikipedia"],
    [len(bois_set), len(wd_names_set), len(wiki_set)]
)
plt.ylabel("Antal spelare")
plt.show()

# %%
# Fuzzy match mot Wikipedia  
from rapidfuzz import process, fuzz

wiki_names = list(wiki_set)

wiki_fuzzy = []
wiki_still_missing = []

for name in bois_not_in_wiki:
    match, score, _ = process.extractOne(
        name,
        wiki_names,
        scorer=fuzz.token_sort_ratio
    )
    
    if score >= 93:
        wiki_fuzzy.append((name, match, score))
    else:
        wiki_still_missing.append(name)

len(wiki_fuzzy), len(wiki_still_missing)
# Out:
# (6, 769)

# %%
wiki_fuzzy
# Out:
# [('Mirza Selimovic', 'Mirza Selimović', 93.33333333333333),
#  ('Bahrudin Atajic', 'Bahrudin Atajić', 93.33333333333333),
#  ('Johnny Kongsbög', 'Johnny Kongsbøg', 93.33333333333333),
#  ('Morten Nordbeck', 'Mårten Nordbeck', 93.33333333333333),
#  ('Viktor Karlsson', 'Victor Karlsson', 93.33333333333333),
#  ('John Jönsson', 'Jon Jönsson', 95.65217391304348)]

# %%
wiki_clean[:5]
# Out:
# ['Mattias Adelstam',
#  'Admir Aganović',
#  'Fernando Aguiar',
#  'Enis Ahmetovic',
#  'Lars Alm']

# %%
bois_set = set([p["name"] for p in bois_clean])
wiki_set = set(wiki_clean)

wiki_exact = bois_set & wiki_set
len(wiki_exact)
# Out:
# 156

# %%
print("Exakt:", len(wiki_exact))
print("Fuzzy:", len(wiki_fuzzy))
print("Saknas:", len(wiki_still_missing))
# Out:
# Exakt: 156
# Fuzzy: 6
# Saknas: 769

# %%
bois_not_in_wiki = bois_set - wiki_set
wiki_not_in_bois = wiki_set - bois_set

len(bois_not_in_wiki), len(wiki_not_in_bois)
# Out:
# (775, 60)

# %%
from rapidfuzz import process, fuzz

wiki_names = list(wiki_set)

wiki_fuzzy = []
wiki_still_missing = []

for name in bois_not_in_wiki:
    match, score, _ = process.extractOne(
        name,
        wiki_names,
        scorer=fuzz.token_sort_ratio
    )
    
    if score >= 93:
        wiki_fuzzy.append((name, match, score))
    else:
        wiki_still_missing.append(name)

len(wiki_fuzzy), len(wiki_still_missing)
# Out:
# (6, 769)

# %%
wiki_qids = get_qids(wiki_titles)
len(wiki_qids)
# Out:
# 215

# %%
total_bois = len(bois_set)
total_wiki = len(wiki_set)
total_p54 = len(wd_names_set)

missing_p54 = total_wiki - len(wd_names_set & wiki_set)
coverage_percent = round((total_p54 / total_bois) * 100, 1)

# %%
wiki_to_qid = wiki_qids  # title -> QID

wd_qids = set([w["qid"] for w in wd_players])

# %%
import pandas as pd

rows = []

for title in wiki_titles:
    qid = wiki_to_qid.get(title)
    
    rows.append({
        "wikipedia_sv": title,
        "wikipedia_url": f"https://sv.wikipedia.org/wiki/{title.replace(' ', '_')}",
        "wikidata_url": f"https://www.wikidata.org/wiki/{qid}" if qid else None,
        "bois_url": None,  # kan fyllas om du vill koppla mot BoIS-id
        "has_P54_BOIS": qid in wd_qids if qid else False
    })

df_wiki = pd.DataFrame(rows)

# %%
df_wiki.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   wikipedia_sv   216 non-null    object
#  1   wikipedia_url  216 non-null    object
#  2   wikidata_url   215 non-null    object
#  3   bois_url       0 non-null      object
#  4   has_P54_BOIS   216 non-null    bool
# dtypes: bool(1), object(4)
# memory usage: 7.1+ KB

# %%
report = f"""
# Statusrapport Landskrona BoIS – Wikipedia / Wikidata / BoIS-historia

Klubb: Landskrona BoIS  
Wikipedia-kategori: {total_wiki} spelare  
BoIS-historia: {total_bois} spelare  

## Wikidata-struktur (P54 → Landskrona BoIS)

- Har korrekt P54: {total_p54}
- Wikipedia-artiklar utan P54: {missing_p54}
- Total täckning (BoIS → WD): {coverage_percent} %

---

## Detaljlista (Wikipedia-kategori)

| Namn | Wikipedia | Wikidata | P54 |
|------|------------|------------|------|
"""

for _, row in df_wiki.iterrows():
    report += f"| {row['wikipedia_sv']} | "
    report += f"[Wiki]({row['wikipedia_url']}) | "
    report += f"[WD]({row['wikidata_url']}) | " if row['wikidata_url'] else "| – | "
    report += f"{'✅' if row['has_P54_BOIS'] else '❌'} |\n"

print(report)
# Out:
# # Statusrapport Landskrona BoIS – Wikipedia / Wikidata / BoIS-historia
#
# Klubb: Landskrona BoIS
# Wikipedia-kategori: 216 spelare
# BoIS-historia: 931 spelare
#
# ## Wikidata-struktur (P54 → Landskrona BoIS)
#
# - Har korrekt P54: 280
# - Wikipedia-artiklar utan P54: 34
# - Total täckning (BoIS → WD): 30.1 %
#
# ---
#
# ## Detaljlista (Wikipedia-kategori)
#
# | Namn | Wikipedia | Wikidata | P54 |
# |------|------------|------------|------|
# | Mattias Adelstam | [Wiki](https://sv.wikipedia.org/wiki/Mattias_Adelstam) | [WD](https://www.wikidata.org/wiki/Q3375080) | ✅ |
# | Admir Aganović | [Wiki](https://sv.wikipedia.org/wiki/Admir_Aganović) | [WD](https://www.wikidata.org/wiki/Q2824652) | ✅ |
# | Fernando Aguiar | [Wiki](https://sv.wikipedia.org/wiki/Fernando_Aguiar) | [WD](https://www.wikidata.org/wiki/Q3069432) | ✅ |
# | Enis Ahmetovic | [Wiki](https://sv.wikipedia.org/wiki/Enis_Ahmetovic) | [WD](https://www.wikidata.org/wiki/Q19787867) | ✅ |
# ...

# %%
from datetime import datetime
from pathlib import Path
datum = datetime.now().strftime("%Y%m%d")
Boisreport = Path(f"BOISreport_{datum}.md")

with open(Boisreport, "w", encoding="utf-8") as f:
    f.write(report)

print("Skapat", Boisreport.resolve())
# Out:
# Skapat /Users/salgo/Documents/GitHub/ifkdb/Notebook/BOISreport_20260328.md

# %% [markdown]
# ## MixandMatch

# %%
import pandas as pd

# --- 1. Indexera Wikidata ---
wd_index = {}
for p in wd_players:
    key = (p['name'].lower(), p['birth'])
    wd_index[key] = p['qid']

# --- 2. Indexera original players (för id + url) ---
players_index = {}
for p in players:
    # konvertera "Efternamn, Förnamn" → "Förnamn Efternamn"
    parts = p['name'].split(", ")
    clean_name = f"{parts[1]} {parts[0]}" if len(parts) == 2 else p['name']
    
    key = (clean_name.lower(), p['birth'])
    players_index[key] = p

# --- 3. Bygg Mix'n'Match rows ---
rows = []

for i, p in enumerate(bois_clean, start=1):
    key = (p['name'].lower(), p['birth'])
    
    wd_qid = wd_index.get(key, "")
    source = players_index.get(key, {})
    
    rows.append({
        "id": source.get("id", i),
        "name": p["name"],
        "desc": f"Swedish association football player, played for BoIS, active ?, born {p['birth']}",
        "type": "Q5",
        "url": source.get("url", ""),
        "wikidata": wd_qid
    })

# --- 4. Skapa DataFrame ---
df = pd.DataFrame(rows)

# --- 5. Export ---
output_file = "bois_mixnmatch.csv"
df.to_csv(output_file, index=False)

print(f"Export klar: {output_file}")
df.head()
# Out:
# Export klar: bois_mixnmatch.csv
#     id               name                                               desc  \
# 0  569  Mohamed Abo-Shark  Swedish association football player, played fo...
# 1  549   Mattias Adelstam  Swedish association football player, played fo...
# 2  347       Jan Afzelius  Swedish association football player, played fo...
# 3    6     Admir Aganovic  Swedish association football player, played fo...
# 4  211    Fernando Aguiar  Swedish association football player, played fo...
#
#   type                                                url  wikidata
# 0   Q5  https://boishistoria.se/visa-data/?what=spelar...
# 1   Q5  https://boishistoria.se/visa-data/?what=spelar...  Q3375080
# 2   Q5  https://boishistoria.se/visa-data/?what=spelar...
# 3   Q5  https://boishistoria.se/visa-data/?what=spelar...
# 4   Q5  https://boishistoria.se/visa-data/?what=spelar...

# %% [markdown]
# ## Quickstatement

# %%
qs_rows = []

for row in rows:
    qid = row["wikidata"]
    
    if qid:  # bara de med Wikidata match
        bois_id = row["id"]
        url = row["url"]
        
        # QuickStatements rad
        # Format: QID	Pxxx	"value"
        qs = f'{qid}\tP14210\t"{bois_id}"'
        
        # med referens (valfritt)
        # qs = f'{qid}\tP14210\t"{bois_id}"\tS854\t"{url}"'
        
        qs_rows.append(qs)

# skriv till fil
with open("bois_quickstatements.txt", "w", encoding="utf-8") as f:
    for line in qs_rows:
        f.write(line + "\n")

print("QuickStatements-fil skapad: bois_quickstatements.txt")
print("\nExempel:")
print("\n".join(qs_rows[:5]))
# Out:
# QuickStatements-fil skapad: bois_quickstatements.txt
#
# Exempel:
# Q3375080	P14210	"549"
# Q19787867	P14210	"182"
# Q116807981	P14210	"452"
# Q49104410	P14210	"666"
# Q116808239	P14210	"441"

# %%
end_time = datetime.now()

duration = end_time - start_time

print("\n===== Körningsrapport =====")
print("Starttid :", start_time.strftime("%Y-%m-%d %H:%M:%S"))
print("Sluttid  :", end_time.strftime("%Y-%m-%d %H:%M:%S"))

total_seconds = int(duration.total_seconds())
hours = total_seconds // 3600
minutes = (total_seconds % 3600) // 60
seconds = total_seconds % 60

print(f"Körtid   : {hours}h {minutes}m {seconds}s")
print("===========================\n")
# Out:
# ===== Körningsrapport =====
# Starttid : 2026-03-28 08:12:46
# Sluttid  : 2026-03-28 08:15:32
# Körtid   : 0h 2m 46s
# ...
