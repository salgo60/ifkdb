# %% [markdown]
# ### snokadb.se
# * [#13](https://github.com/salgo60/ifkdb/issues/13)
# * Notebook [13_snokadb_se](https://github.com/salgo60/ifkdb/blob/main/Notebook/13_snokadb_se.ipynb)

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2026-03-29 07:22:57.532885

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import asyncio
import re
import pandas as pd
from playwright.async_api import async_playwright

async def scrape_players():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        await page.goto(
            "https://snokadb.se/spelare",
            wait_until="domcontentloaded",
            timeout=60000
        )

        # ge React lite tid
        await page.wait_for_timeout(2000)

        await page.wait_for_selector("table")

        rows = await page.query_selector_all("table tbody tr")
        data = []

        for row in rows:
            cols = await row.query_selector_all("td")
            if len(cols) < 4:
                continue

            raw_name = await cols[0].inner_text()
            name = raw_name.strip()

            seasons = (await cols[1].inner_text()).strip()
            matches = (await cols[2].inner_text()).strip()
            goals = (await cols[3].inner_text()).strip()

            link = await row.query_selector("a")
            href = await link.get_attribute("href") if link else ""
            slug = href.split("/")[-1] if href else ""

            data.append({
                "snokadb_id": slug,
                "name": name,
                "seasons": seasons,
                "matches": matches,
                "goals": goals
            })

        await browser.close()

    return pd.DataFrame(data)

df = asyncio.run(scrape_players())
df.head(), len(df)
# Out:
# (           snokadb_id                  name                 seasons matches  \
#  0      abdoulie-tamba      🇬🇦Abdoulie Tamba                    2025       5
#  1  alexander-fransson  🇸🇪Alexander Fransson     2013 och 7 säsonger     201
#  2      anton-eriksson      🇸🇪Anton Eriksson  2022, 2023, 2024, 2025      79
#  3        axel-bronner        🇸🇪Axel Brönner                    2025      16
#  4   christoffer-nyman   🇸🇪Christoffer Nyman    2010 och 13 säsonger     329
#
#    goals
#  0     0
#  1    17
#  2     0
#  3     0
#  4   112  ,
#  584)

# %%
import asyncio
import re
from playwright.async_api import async_playwright


async def fetch_birthdate(context, slug, semaphore):
    url = f"https://snokadb.se/spelare/{slug}"

    async with semaphore:
        page = await context.new_page()
        try:
            await page.goto("https://snokadb.se/spelare", wait_until="domcontentloaded", timeout=60000)
            # vänta lite extra (React)
            await page.wait_for_timeout(1000)

            content = await page.inner_text("body")

            match = re.search(r"Födelsedatum:\s*\"?(\d{4}-\d{2}-\d{2})\"?", content)

            birthdate = match.group(1) if match else ""
            print(slug, birthdate)

            return birthdate

        except Exception as e:
            print(f"Misslyckades för {slug}: {e}")
            return ""

        finally:
            await page.close()

        # liten paus mellan requests
        await asyncio.sleep(0.3)


async def enrich_parallel(df, max_concurrency=2):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        context = await browser.new_context()
        semaphore = asyncio.Semaphore(max_concurrency)

        tasks = [
            fetch_birthdate(context, slug, semaphore)
            for slug in df["snokadb_id"]
        ]

        results = await asyncio.gather(*tasks)
        await browser.close()

    df = df.copy()
    df["birthdate"] = results
    return df

# %%
df = await enrich_parallel(df)
# Out:
# alexander-fransson
# abdoulie-tamba
# anton-eriksson
# axel-bronner
# christoffer-nyman
# david-mitov-nilsson
# filip-dagerstal
# isak-andri-sigurgeirsson
# moutaz-neffati
# noel-sernelius
# stephan-bolma
# theo-krantz
# tim-prica
# ture-sandberg
# ake-andersson
# abbas-hassan
# abderahman-kabous
# abdulrazaq-ishaq
# adin-bukva
# alexander-jakobsen
# alexander-petras
# alexander-radesjo
# alexander-ostlund
# alfons-sampsted
# algot-wulff
# alhaji-kamara
# allan-hasselmark
# allan-johansson
# allan-pettersson
# amadeus-sogaard
# anders-wikstrom
# anders-whass
# andreas-alm
# andreas-blomqvist
# andreas-dahlen
# andreas-hadenius
# andreas-haglund
# andreas-johansson
# andreas-lindberg
# andreas-thomas
# andreas-vaikla
# andri-lucas-gudjohnsen
# antti-sumiala
# ari-freyr-skulason
# armando-ibrakovic
# armin-tankovic
# arne-andersson
# arne-eriksson
# arne-rehnberg
# arne-tornqvist
# arnor-traustason
# arnor-sigurdsson
# arthur-astrand
# astrit-ajdarevic
# axel-jansson
# axel-pressfeldt
# ...

# %%
df.to_csv("snokadb_players_raw.csv", index=False)

# %%
df
# Out:
#              snokadb_id                  name                  seasons  \
# 0        abdoulie-tamba      🇬🇦Abdoulie Tamba                     2025
# 1    alexander-fransson  🇸🇪Alexander Fransson      2013 och 7 säsonger
# 2        anton-eriksson      🇸🇪Anton Eriksson   2022, 2023, 2024, 2025
# 3          axel-bronner        🇸🇪Axel Brönner                     2025
# 4     christoffer-nyman   🇸🇪Christoffer Nyman     2010 och 13 säsonger
# ..                  ...                   ...                      ...
# 579          ake-brynje          🇸🇪Åke Brynje                  1939/40
# 580       ake-johansson       🇸🇪Åke Johansson  1949/50 och 15 säsonger
# 581         ake-larsson         🇸🇪Åke Larsson         1939/40, 1940/41
# 582          ake-skarin          🇸🇪Åke Skarin                  1939/40
# 583    orjan-martinsson    🇸🇪Örjan Martinsson      1959 och 8 säsonger
#
#     matches goals birthdate
# 0         5     0
# 1       201    17
# 2        79     0
# 3        16     0
# ...

# %%
import requests 
# Wikipedia/WIkidata  
import pandas as pd 
session = requests.Session()
session.headers.update({
    "User-Agent": "SnokaDB Wikidata research script (salgo60@msn.com)",
    "Accept": "application/sparql-results+json"
})
    
SPARQL = """
SELECT ?item ?itemLabel ?birthdate ?svwiki WHERE {
  # ?item wdt:P54 wd:Q329607
  OPTIONAL { ?item wdt:P569 ?birthdate }
  OPTIONAL {
    # ?svwiki schema:about ?item ;
            schema:isPartOf <https://sv.wikipedia.org/> .
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "sv,en". }
}
"""

url = "https://query.wikidata.org/sparql"
response = session.get(url, params={"query": SPARQL}, timeout=30)
response.raise_for_status()
data = response.json()

rows = []
for r in data["results"]["bindings"]: 
    rows.append({
        "wikidata_qid": r["item"]["value"].split("/")[-1],
        "name_wd": r["itemLabel"]["value"],
        "birthdate_wd": r.get("birthdate", {}).get("value", ""),
        "wikipedia_sv": r.get("svwiki", {}).get("value", "")
    })

wd_df = pd.DataFrame(rows)
wd_df.head(), len(wd_df)
# Out:
# (  wikidata_qid             name_wd          birthdate_wd wikipedia_sv
#  0      Q308080  Abderrahman Kabous  1983-04-24T00:00:00Z
#  1      Q576245    Kyle Lightbourne  1968-09-29T00:00:00Z
#  2      Q629453    Slobodan Marović  1964-07-13T00:00:00Z
#  3      Q634973      Janne Hietanen  1978-06-02T00:00:00Z
#  4      Q724829     Balázs Rabóczki  1978-01-09T00:00:00Z             ,
#  190)

# %%
# Matcha mot snokadb  
merged = df.merge(
    wd_df,
    left_on="name",
    right_on="name_wd",
    how="left"
)

merged[["snokadb_id","name","wikidata_qid","wikipedia_sv"]].head()
# Out:
#            snokadb_id                  name wikidata_qid wikipedia_sv
# 0      abdoulie-tamba      🇬🇦Abdoulie Tamba          NaN          NaN
# 1  alexander-fransson  🇸🇪Alexander Fransson          NaN          NaN
# 2      anton-eriksson      🇸🇪Anton Eriksson          NaN          NaN
# 3        axel-bronner        🇸🇪Axel Brönner          NaN          NaN
# 4   christoffer-nyman   🇸🇪Christoffer Nyman          NaN          NaN

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584 entries, 0 to 583
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   snokadb_id    584 non-null    object
#  1   name          584 non-null    object
#  2   seasons       584 non-null    object
#  3   matches       584 non-null    object
#  4   goals         584 non-null    object
#  5   birthdate     584 non-null    object
#  6   wikidata_qid  0 non-null      object
#  7   name_wd       0 non-null      object
#  8   birthdate_wd  0 non-null      object
#  9   wikipedia_sv  0 non-null      object
# dtypes: object(10)
# memory usage: 45.8+ KB

# %%
merged.head(20)
# Out:
#                   snokadb_id                        name  \
# 0             abdoulie-tamba            🇬🇦Abdoulie Tamba
# 1         alexander-fransson        🇸🇪Alexander Fransson
# 2             anton-eriksson            🇸🇪Anton Eriksson
# 3               axel-bronner              🇸🇪Axel Brönner
# 4          christoffer-nyman         🇸🇪Christoffer Nyman
# 5        david-mitov-nilsson     🇸🇪🇲🇰David Mitov Nilsson
# 6            filip-dagerstal           🇸🇪Filip Dagerstål
# 7   isak-andri-sigurgeirsson  🇮🇸Isak Andri Sigurgeirsson
# 8             moutaz-neffati          🇸🇪🇹🇳Moutaz Neffati
# 9             noel-sernelius            🇸🇪Noel Sernelius
# 10             stephan-bolma             🇬🇭Stephan Bolma
# 11               theo-krantz               🇸🇪Theo Krantz
# 12                 tim-prica                 🇸🇪Tim Prica
# 13             ture-sandberg             🇸🇪Ture Sandberg
# 14             ake-andersson             🇸🇪Åke Andersson
# ...

# %%
def normalize(n):
    return n.lower().replace('"','').strip()

df["name_norm"] = df["name"].apply(normalize)
wd_df["name_norm"] = wd_df["name_wd"].apply(normalize)

merged = df.merge(
    wd_df,
    on="name_norm",
    how="left"
)

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584 entries, 0 to 583
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   snokadb_id    584 non-null    object
#  1   name          584 non-null    object
#  2   seasons       584 non-null    object
#  3   matches       584 non-null    object
#  4   goals         584 non-null    object
#  5   birthdate     584 non-null    object
#  6   name_norm     584 non-null    object
#  7   wikidata_qid  0 non-null      object
#  8   name_wd       0 non-null      object
#  9   birthdate_wd  0 non-null      object
#  10  wikipedia_sv  0 non-null      object
# dtypes: object(11)
# memory usage: 50.3+ KB

# %%
final = merged[[
    "snokadb_id",
    "name",
    "wikidata_qid",
    "wikipedia_sv",
    "birthdate_wd"
]]

final.head()
# Out:
#            snokadb_id                  name wikidata_qid wikipedia_sv  \
# 0      abdoulie-tamba      🇬🇦Abdoulie Tamba          NaN          NaN
# 1  alexander-fransson  🇸🇪Alexander Fransson          NaN          NaN
# 2      anton-eriksson      🇸🇪Anton Eriksson          NaN          NaN
# 3        axel-bronner        🇸🇪Axel Brönner          NaN          NaN
# 4   christoffer-nyman   🇸🇪Christoffer Nyman          NaN          NaN
#
#   birthdate_wd
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584 entries, 0 to 583
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   snokadb_id    584 non-null    object
#  1   name          584 non-null    object
#  2   wikidata_qid  0 non-null      object
#  3   wikipedia_sv  0 non-null      object
#  4   birthdate_wd  0 non-null      object
# dtypes: object(5)
# memory usage: 22.9+ KB

# %% [markdown]
# ### Wikipedia / Wikidata
# * [Kategorin har 283](https://sv.wikipedia.org/w/index.php?title=Kategori:Fotbollsspelare_i_IFK_Norrk%C3%B6ping&pagefrom=Nilsson%2C+David+Mitov%0ADavid+Mitov+Nilsson#mw-pages)
# * [Wikidata 202](https://w.wiki/Hx5x)

# %%
import requests
import time

S = requests.Session()
S.headers.update({
    "User-Agent": "IFK-POC/1.0 (https://github.com/yourrepo; contact: your@email)"
})

URL = "https://sv.wikipedia.org/w/api.php"

def get_category_members():
    members = []
    params = {
        "action": "query",
        "list": "categorymembers",
        "cmtitle": "Kategori:Fotbollsspelare i IFK Norrköping",
        "cmlimit": "500",
        "format": "json",
        "formatversion": "2"
    }

    while True:
        r = S.get(URL, params=params, timeout=30)
        r.raise_for_status()

        # debug om något går fel
        if "application/json" not in r.headers.get("Content-Type", ""):
            print("Fick inte JSON:")
            print(r.text[:500])
            break

        data = r.json()

        members.extend(data["query"]["categorymembers"])

        if "continue" in data:
            params.update(data["continue"])
            time.sleep(0.5)  # snäll mot API:t
        else:
            break

    return [m["title"] for m in members]

titles = get_category_members()
len(titles)
# Out:
# 323

# %%
#titles

# %%
import requests
import time
import pandas as pd

WD_API = "https://www.wikidata.org/w/api.php"

session = requests.Session()
session.headers.update({
    "User-Agent": "IFK-Norrkoping-POC/1.0 (https://github.com/dittrepo; kontakt: salgö60@msn.com)"
})

# %%
# slå upp titles 
import requests
import pandas as pd
import time


def lookup_titles_in_batches(titles, batch_size=50):
    results = []

    for i in range(0, len(titles), batch_size):
        batch = titles[i:i+batch_size]
        titles_str = "|".join(batch)

        params = {
            "action": "wbgetentities",
            "sites": "svwiki",
            "titles": titles_str,
            "props": "claims|sitelinks",
            "redirects": "yes",
            "format": "json"
        }
        r = session.get(WD_API, params=params)
        r.raise_for_status()
        data = r.json()

        entities = data.get("entities", {})

        for title in batch:
            qid = None
            birthdate = None
            has_p54 = False

            # hitta rätt entity via sitelink
            for entity in entities.values():
                if entity.get("sitelinks", {}).get("svwiki", {}).get("title") == title:
                    qid = entity.get("id")
                    claims = entity.get("claims", {})

                    # birthdate
                    if "P569" in claims:
                        birthdate = claims["P569"][0]["mainsnak"]["datavalue"]["value"]["time"]

                    # P54 IFK
                    if "P54" in claims:
                        for c in claims["P54"]:
                            target = c["mainsnak"]["datavalue"]["value"]["id"]
                            if target == "Q329607":  # IFK Norrköping
                                has_p54 = True
                    break

            results.append({
                "wikipedia_sv": title,
                "wikidata_qid": qid,
                "birthdate_wd": birthdate,
                "has_P54_IFK": has_p54
            })

        time.sleep(0.5)  # var snäll mot API:t

    return pd.DataFrame(results)

df_wiki = lookup_titles_in_batches(titles)
df_wiki.head()
# Out:
#        wikipedia_sv wikidata_qid           birthdate_wd  has_P54_IFK
# 0  Ishaq Abdulrazak    Q96361469  +2002-05-05T00:00:00Z         True
# 1  Samuel Adegbenro    Q19152611  +1995-12-03T00:00:00Z        False
# 2   Viktor Agardius     Q5543358  +1989-10-23T00:00:00Z        False
# 3    Enis Ahmetovic    Q19787867  +1992-01-26T00:00:00Z        False
# 4  Astrit Ajdarević      Q751101  +1990-04-17T00:00:00Z         True

# %%
df_wiki.to_csv("ifkwikipedia.csv")

# %%
df_wiki["has_P54_IFK"].value_counts()
# Out:
# has_P54_IFK
# False    190
# True     133
# Name: count, dtype: int64

# %%
df_wiki.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 323 entries, 0 to 322
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   wikipedia_sv  323 non-null    object
#  1   wikidata_qid  323 non-null    object
#  2   birthdate_wd  323 non-null    object
#  3   has_P54_IFK   323 non-null    bool
# dtypes: bool(1), object(3)
# memory usage: 8.0+ KB

# %% [markdown]
# ## Quickstatement
# * new property P14243

# %%
qs_rows = []

for _, row in merged.iterrows():
    qid = row["wikidata_qid"]
    
    if isinstance(qid, str) and qid.strip():
        snokadb_id = row["snokadb_id"]
        
        # utan referens
        qs = f'{qid}\tP14243\t"{snokadb_id}"'
        
        qs_rows.append(qs)

# skriv till fil
with open("snokadb_quickstatements.txt", "w", encoding="utf-8") as f:
    for line in qs_rows:
        f.write(line + "\n")

print("QuickStatements-fil skapad: snokadb_quickstatements.txt")
print("\nExempel:")
print("\n".join(qs_rows[:5]))
# Out:
# QuickStatements-fil skapad: snokadb_quickstatements.txt
#
# Exempel:

# %% [markdown]
# ## Status rapport

# %%
import pandas as pd

# Wikipedia-länk
from urllib.parse import quote

df_wiki["wikipedia_url"] = df_wiki["wikipedia_sv"].apply(
    lambda x: "https://sv.wikipedia.org/wiki/" + quote(x.replace(" ", "_"))
)
# Wikidata-länk
df_wiki["wikidata_url"] = "https://www.wikidata.org/wiki/" + df_wiki["wikidata_qid"]

# SnokaDb-länk (matcha på namn)
name_to_slug = dict(zip(df["name"], df["snokadb_id"]))
df_wiki["snokadb_id"] = df_wiki["wikipedia_sv"].map(name_to_slug)
df_wiki["snokadb_url"] = "https://snokadb.se/spelare/" + df_wiki["snokadb_id"].fillna("")

# %%
total_snokadb = len(df)
total_wikipedia = len(df_wiki)
total_p54 = df_wiki["has_P54_IFK"].sum()
missing_p54 = total_wikipedia - total_p54

coverage_percent = round((total_p54 / total_wikipedia) * 100, 1)

# %%
# ================================
# HÄMTA WIKIDATA P54 – BOIS
# ================================
import requests


SPARQL = """
SELECT ?item ?itemLabel WHERE {
  # ?item wdt:P54 wd:Q863273 .
  SERVICE wikibase:label {
    bd:serviceParam wikibase:language "sv,en,mul" .
  }
}
"""
session = requests.Session()
session.headers.update({
    "User-Agent": "SnokaDB Wikidata research script (salgo60@msn.com)",
    "Accept": "application/sparql-results+json"
})


url = "https://query.wikidata.org/sparql"
response = session.get(url, params={"query": SPARQL}, timeout=30)
response.raise_for_status()
data = response.json()

wd_players = []
for r in data["results"]["bindings"]:
    wd_players.append({
        "qid": r["item"]["value"].split("/")[-1],
        "name": r["itemLabel"]["value"]
    })

print("Wikidata P54 spelare:", len(wd_players))
# Out:
# Wikidata P54 spelare: 281

# %%
wd_players
# Out:
# [{'qid': 'Q128845', 'name': 'Lee Baxter'},
#  {'qid': 'Q151373', 'name': 'Babis Stefanidis'},
#  {'qid': 'Q176721', 'name': 'André Schei Lindbæk'},
#  {'qid': 'Q177434', 'name': 'Jörgen Pettersson'},
#  {'qid': 'Q195874', 'name': 'Joakim Nilsson'},
#  {'qid': 'Q256861', 'name': 'Mikael Dahlgren'},
#  {'qid': 'Q278734', 'name': 'Rade Prica'},
#  {'qid': 'Q312379', 'name': 'Jonas Olsson'},
#  {'qid': 'Q359016', 'name': 'Andreas Dahl'},
#  {'qid': 'Q361101', 'name': 'Ajsel Kujović'},
#  {'qid': 'Q440904', 'name': 'Rasmus Lindgren'},
#  {'qid': 'Q445724', 'name': 'Mats Aronsson'},
#  {'qid': 'Q498468', 'name': 'Andreas Jakobsson'},
#  {'qid': 'Q501307', 'name': 'Andreas Yngvesson'},
#  {'qid': 'Q515599', 'name': 'Viktor Noring'},
#  {'qid': 'Q526682', 'name': 'Pontus Farnerud'},
#  {'qid': 'Q535027', 'name': 'Jonas Thern'},
#  {'qid': 'Q550939', 'name': 'Emir Kujović'},
#  {'qid': 'Q587865', 'name': 'Matthias Eklund'},
#  {'qid': 'Q596509', 'name': 'Curt Bergsten'},
# ...

# %%
import requests
import pandas as pd
import mwclient
from datetime import datetime

# =====================================
# 1. HÄMTA WIKIDATA (P54 )
# =====================================

SPARQL = """
SELECT ?player ?playerLabel WHERE {
  # ?player wdt:P54 wd:Q329607 .
  SERVICE wikibase:label {
    bd:serviceParam wikibase:language "sv,en,mul".
  }
}
"""

session = requests.Session()
session.headers.update({
    "User-Agent": "SnokaDB Wikidata research script (salgo60@msn.com)",
    "Accept": "application/sparql-results+json"
})

url = "https://query.wikidata.org/sparql"
response = session.get(url, params={"query": SPARQL}, timeout=30)
response.raise_for_status()
data = response.json()

wd_rows = []
for item in data["results"]["bindings"]:
    wd_rows.append({
        "wikidata_id": item["player"]["value"].split("/")[-1],
        "wd_label": item["playerLabel"]["value"]
    })

df_wd = pd.DataFrame(wd_rows)
wd_qids = set(df_wd["wikidata_id"])

# =====================================
# 2. HÄMTA WIKIPEDIA-KATEGORI
# =====================================

site = mwclient.Site("sv.wikipedia.org")
category = site.categories["Fotbollsspelare i IFK Norrköping"]

def chunked(lst, size):
    for i in range(0, len(lst), size):
        yield lst[i:i + size]

pages = [p for p in category.members() if p.namespace == 0]
titles = [p.name for p in pages]

wiki_rows = []

for batch in chunked(titles, 50):
    result = site.api(
        action="query",
        titles="|".join(batch),
        prop="pageprops",
        ppprop="wikibase_item",
        format="json"
    )
    for page in result["query"]["pages"].values():
        wiki_rows.append({
            "wiki_name": page.get("title"),
            "wikidata_id": page.get("pageprops", {}).get("wikibase_item")
        })

df_wiki = pd.DataFrame(wiki_rows)

wiki_titles = list(df_wiki["wiki_name"])
wiki_qids = dict(zip(df_wiki["wiki_name"], df_wiki["wikidata_id"]))

wiki_with_p54 = {
    title for title in wiki_titles
    if wiki_qids.get(title) in wd_qids
}

wiki_without_p54 = [
    title for title in wiki_titles
    if wiki_qids.get(title) not in wd_qids
]

# =====================================
# 3. NYCKELTAL
# =====================================

total_wiki = len(wiki_titles)
total_p54 = len(wd_qids)
missing_p54 = len(wiki_without_p54)
coverage_percent = round((len(wiki_with_p54) / total_wiki) * 100, 1) if total_wiki else 0

# =====================================
# 4. BYGG HTML-RAPPORT
# =====================================

html = f"""
<html>
<head>
<meta charset="utf-8">
<title>Statusrapport AIK – Wikipedia / Wikidata</title>
<style>
body {{ font-family: Arial, sans-serif; }}
table {{ border-collapse: collapse; width: 100%; }}
th, td {{ border: 1px solid #ccc; padding: 6px; }}
th {{ background-color: #f2f2f2; }}
.bad {{ background-color: #ffe6e6; }}
.good {{ background-color: #e6ffe6; }}
</style>
</head>
<body>

<h1>Statusrapport AIK – Wikipedia / Wikidata</h1>
<p>Genererad: {datetime.now().strftime('%Y-%m-%d %H:%M')}</p>

<h2>Nyckeltal</h2>
<ul>
<li>Wikipedia-kategori: {total_wiki} spelare</li>
<li>Wikidata P54 AIK: {total_p54} spelare</li>
<li>Wikipedia-artiklar utan P54: {missing_p54}</li>
<li>Täckning (Wikipedia → WD P54): {coverage_percent} %</li>
</ul>

<hr>

<h2>Wikipedia-kategori – Identifieringsstatus</h2>

<table>
<tr>
<th>Spelare</th>
<th>Wikidata</th>
<th>P54</th>
</tr>
"""

# Sortera så ❌ kommer först
sorted_titles = sorted(
    wiki_titles,
    key=lambda t: t in wiki_with_p54
)

for title in sorted_titles:
    wiki_link = f'<a href="https://sv.wikipedia.org/wiki/{title.replace(" ", "_")}" target="_blank">{title}</a>'
    
    qid = wiki_qids.get(title)
    
    if qid:
        wd_link = f'<a href="https://www.wikidata.org/wiki/{qid}" target="_blank">{qid}</a>'
        has_p54 = qid in wd_qids
    else:
        wd_link = "–"
        has_p54 = False
    
    status = "✅" if has_p54 else "❌"
    row_class = "good" if has_p54 else "bad"
    
    html += f"""
    <tr class="{row_class}">
        <td>{wiki_link}</td>
        <td>{wd_link}</td>
        <td>{status}</td>
    </tr>
    """

html += """
</table>
</body>
</html>
"""
from datetime import datetime

today_str = datetime.now().strftime("%Y%m%d")
output_file = f"snokadb_statusrapport_{today_str}.html"

with open(output_file, "w", encoding="utf-8") as f:
    f.write(html)

print("Rapport skapad:", output_file)
# Out:
# Rapport skapad: snokadb_statusrapport_20260329.html

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584 entries, 0 to 583
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   snokadb_id  584 non-null    object
#  1   name        584 non-null    object
#  2   seasons     584 non-null    object
#  3   matches     584 non-null    object
#  4   goals       584 non-null    object
#  5   birthdate   584 non-null    object
#  6   name_norm   584 non-null    object
# dtypes: object(7)
# memory usage: 32.1+ KB

# %%
# Out:
# 0
# 1
# 2
# 3
# 4
#       ..
# 579
# 580
# 581
# 582
# 583
# Name: birthdate, Length: 584, dtype: object

# %% [markdown]
# ## MixandMatch
# id,name,desc,type,url,wikidata

# %%
import pandas as pd

def build_mixnmatch(df):
    rows = []

    for _, row in df.iterrows():
        snokadb_id = str(row["snokadb_id"])
        name = row["name"]
        birthdate = row.get("birthdate", "")
        seasons = row.get("seasons", "")
        matches = row.get("matches", "")
        goals = row.get("goals", "")
        qid = row.get("wikidata_qid", "")

        # beskrivning
        desc_parts = ["Swedish association football player"]

        if seasons:
            desc_parts.append(f"played seasons {seasons}")
        if matches:
            desc_parts.append(f"{matches} matches")
        if goals:
            desc_parts.append(f"{goals} goals")
        if birthdate:
            desc_parts.append(f"born {birthdate}")

        desc = ", ".join(desc_parts)

        url = f"https://snokadb.se/spelare/{snokadb_id}"

        rows.append({
            "id": snokadb_id,
            "name": name,
            "desc": desc,
            "type": "Q5",
            "url": url,
            "wikidata": qid if isinstance(qid, str) else ""
        })

    return pd.DataFrame(rows)

# %%
mnm_df = build_mixnmatch(df) 
def remove_flags(text):
    return re.sub(r'[\U0001F1E6-\U0001F1FF]{2}', '', text).strip()

mnm_df["name"] = mnm_df["name"].str.replace(
    r'[\U0001F1E6-\U0001F1FF]{2}', '', regex=True
).str.strip() 

#mnm_df["name"] = mnm_df["name"].apply(remove_flags)
from datetime import datetime

# skapa datumsträng
today_str = datetime.now().strftime("%Y%m%d")

filename = f"snokadb_mixnmatch_{today_str}.csv"

mnm_df.to_csv(filename, index=False)

print("Sparad fil:", filename)
mnm_df.head()
# Out:
# Sparad fil: snokadb_mixnmatch_20260329.csv
#                    id                name  \
# 0      abdoulie-tamba      Abdoulie Tamba
# 1  alexander-fransson  Alexander Fransson
# 2      anton-eriksson      Anton Eriksson
# 3        axel-bronner        Axel Brönner
# 4   christoffer-nyman   Christoffer Nyman
#
#                                                 desc type  \
# 0  Swedish association football player, played se...   Q5
# 1  Swedish association football player, played se...   Q5
# 2  Swedish association football player, played se...   Q5
# 3  Swedish association football player, played se...   Q5
# 4  Swedish association football player, played se...   Q5
#
#                                              url wikidata
# 0      https://snokadb.se/spelare/abdoulie-tamba
# 1  https://snokadb.se/spelare/alexander-fransson
# 2      https://snokadb.se/spelare/anton-eriksson
# 3        https://snokadb.se/spelare/axel-bronner
# 4   https://snokadb.se/spelare/christoffer-nyman

# %%
from datetime import datetime
end_time = datetime.now()

duration = end_time - start_time

print("\n===== Körningsrapport =====")
print("Starttid :", start_time.strftime("%Y-%m-%d %H:%M:%S"))
print("Sluttid  :", end_time.strftime("%Y-%m-%d %H:%M:%S"))

total_seconds = int(duration.total_seconds())
hours = total_seconds // 3600
minutes = (total_seconds % 3600) // 60
seconds = total_seconds % 60

print(f"Körtid   : {hours}h {minutes}m {seconds}s")
print("===========================\n")
# Out:
# ===== Körningsrapport =====
# Starttid : 2026-03-29 07:22:57
# Sluttid  : 2026-03-29 07:31:42
# Körtid   : 0h 8m 44s
# ...
